# %% [markdown]
# # In this notebook we will apply data augmentation to increase the number of records we have in the input dataset . The dataset has already undergone preprocessing.
# ### We already know there is data imbalance. GRP_0 has many more records than other groups. We need to explore techniques for data augmentation so other GROUPS have a better representation. In this notebook, we will do data augmentation with the help of synonyms. We use KNN to find the words nearest to the original word. We also use Part of Speech Tagging as another technique to find synonyms.
#
# #### Then we iterate over the dataset and identify synonyms of one or more words found in each ticket - keeping the tickets relationship with the group intact.
#
# #### We add the new ticket description and the Group back to the dataset .
# #### We go through this process a couple of times after leaving out the GRP_0 which already has enough representation in the dataset

# %%
#!pip install wordcloud
#!pip install langdetect
#!pip install googletrans
#!pip install textblob
#!pip install spacy
#!python -m spacy download en
#!python -m spacy download en_core_web_sm
#!python -m spacy download en_core_web_md
#!python -m spacy download en_core_web_lg
#!pip install langid
#!pip install google_trans_new
#!pip uninstall googletrans
#!pip install gensim

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import re
import nltk
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from wordcloud import WordCloud, STOPWORDS 
#from langdetect import detect
from itertools import cycle
#import googletrans
#from googletrans import Translator
from google_trans_new import google_translator 
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn import metrics
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score, f1_score
from sklearn import model_selection
from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline
#from textblob import TextBlob
#from textblob.translate import NotTranslated
import random
import operator
import math
import tqdm
import time
import spacy
import json
import tensorflow as tf
#import langid

# %% [markdown]
# ### This section below contains  Useful Functions
# - As we find new functions, we will create them here.

# %%
## Tokenizing sentence into token for finding synonym.
def make_tokenizer(texts):
    from keras.preprocessing.text import Tokenizer
    t = Tokenizer()
    t.fit_on_texts(texts)
    return t


def loadEmbeddingMatrix(typeToLoad, vocab_dict):
    import gensim.models.keyedvectors as word2vec
    import gc

    # load different embedding file from Kaggle depending on which embedding
    # matrix we are going to experiment with
    if (typeToLoad == "gloveTwitter50d"):
        EMBEDDING_FILE = 'embeddings\glove-twitter-27b-50d/glove.twitter.27B.50d.txt'
        embed_size = 50
    elif (typeToLoad == "word2vec"):
        word2vecDict = word2vec.KeyedVectors.load_word2vec_format( "embeddings\GoogleNews-vectors-negative300/GoogleNews-vectors-negative300.bin", binary=True)
        embed_size = 300
    elif (typeToLoad == "fasttext"):
        EMBEDDING_FILE = 'embeddings\\fasttext/wiki.simple.vec'
        embed_size = 300
    elif (typeToLoad == "glove840B300D"):
        EMBEDDING_FILE = 'embeddings\glove.840B.300d/glove.840B.300d.txt'
        embed_size = 300
    elif (typeToLoad == "glove6B300D"):
        EMBEDDING_FILE = 'embeddings\glove.6B\glove.6B.300d.txt'
        embed_size = 300
    elif (typeToLoad == "paragram"):
        EMBEDDING_FILE = 'embeddings\paragram_300_sl999\paragram_300_sl999.txt'
        embed_size = 300
    elif (typeToLoad == "wikiNews"):
        EMBEDDING_FILE = "embeddings\wiki-news-300d-1M\wiki-news-300d-1M.vec"
        embed_size = 300

    def get_coefs(word, *arr):
        return word, np.asarray(arr, dtype='float32')

    if (typeToLoad in ["gloveTwitter50d", "fasttext"]):
        embeddings_index = dict()
        # Transfer the embedding weights into a dictionary by iterating through every line of the file.
        f = open(EMBEDDING_FILE)
        for line in f:
            # split up line into an indexed array
            values = line.rstrip().rsplit(' ')  # line.split()
            # first index is word
            word = values[0]
            # store the rest of the values in the array as a new array
            coefs = np.asarray(values[1:], dtype='float32')
            embeddings_index[word] = coefs  # 50 dimensions
        f.close()
    elif (typeToLoad in ["glove840B300D", "paragram", "glove6B300D"]):
        embeddings_index = dict(get_coefs(*o.split(" ")) for o in open(EMBEDDING_FILE, encoding='latin'))
    elif (typeToLoad in ["wikiNews"]):
        embeddings_index = dict(get_coefs(*o.split(" ")) for o in open(EMBEDDING_FILE) if len(o) > 100)
    else:
        embeddings_index = dict()
        for word in word2vecDict.wv.vocab:
            embeddings_index[word] = word2vecDict.word_vec(word)
    print('Loaded %s word vectors.' % len(embeddings_index))

    gc.collect()
    # We get the mean and standard deviation of the embedding weights so that we could maintain the
    # same statistics for the rest of our own random generated weights.
    all_embs = np.stack(list(embeddings_index.values()))
    emb_mean, emb_std = all_embs.mean(), all_embs.std()

    nb_words = len(vocab_dict)
    # We are going to set the embedding size to the pretrained dimension as we are replicating it.
    # the size will be Number of Words in Vocab X Embedding Size
    embedding_matrix = np.random.normal(emb_mean, emb_std, (nb_words, embed_size))
    gc.collect()

    # With the newly created embedding matrix, we'll fill it up with the words that we have in both
    # our own dictionary and loaded pretrained embedding.
    embeddedCount = 0
    for word, i in vocab_dict.items():
        #i -= 1
        # then we see if this word is in glove's dictionary, if yes, get the corresponding weights
        embedding_vector = embeddings_index.get(word)
        # and store inside the embedding matrix that we will train later on.
        if embedding_vector is not None:
            try :
                embedding_matrix[i] = embedding_vector
                embeddedCount += 1
            except IndexError:
                pass
    print('total embedded:', embeddedCount, 'common words')

    del embeddings_index
    gc.collect()

    # finally, return the embedding matrix
    return embedding_matrix

# %%
dfObj = pd.DataFrame(columns=['Algorithm', 'Accuracy', 'f1', 'Precision Score', 'Recall Score'])
#Panda option settings that will be applicable through out this notebook
pd.set_option('max_colwidth', 80)

# Some useful functions
# given a dataframe and a sort sequence, return back the sorted dataframe
def sort_df(df, arr):
    df.sort_values(by=arr, inplace=True, ascending=False)
    df = df.reset_index()
    df = df.drop('index', 1)
    df.index += 1
    return df

# given a sequence of attributes and a dataframe, return dataframe sorted by descending order of importance
def imp_df(column_names, importances):
    df = pd.DataFrame({'feature': column_names,
                       'feature_importance': importances}).sort_values('feature_importance',
                        ascending = False).reset_index(drop = True)
    return df

# %%
mydata = pd.read_csv('datasets/input_data_after_preprocessing_for_ml.csv')
#mydata = pd.read_excel("datasets/input_data.xlsx")
#mydata = pd.read_pickle('datasets/preprocesseddata_mldl.pkl')

# %%
mydata.head()
# Out:
#    Unnamed: 0  \
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4
#
#                                                       Combined Description Cleaned  \
# 0  login issue user manager name checked the name in ad and reset password advi...
# 1  outlook received from hello team my are not in calendar can somebody please ...
# 2                               cannot log in to received from hi i cannot on best
# 3                                                       unable to access tool page
# 4                                                                            error
#
#   Assignment group
# 0            GRP_0
# 1            GRP_0
# 2            GRP_0
# 3            GRP_0
# 4            GRP_0

# %% [markdown]
# ### Here we are setting the baseline accuracy for the original dataset after data cleansing but before any Data Augmentation. We use LR scores as the base.

# %%
df_assignment_group_dist = mydata['Assignment group'].value_counts().reset_index()
df_assignment_group_dist['percentage'] = (df_assignment_group_dist['Assignment group']/df_assignment_group_dist['Assignment group'].sum())*100
df_assignment_group_dist.head(20)
# Out:
#      index  Assignment group  percentage
# 0    GRP_0              3976   46.776471
# 1    GRP_8               661    7.776471
# 2   GRP_24               289    3.400000
# 3   GRP_12               257    3.023529
# 4    GRP_9               252    2.964706
# 5    GRP_2               241    2.835294
# 6   GRP_19               215    2.529412
# 7    GRP_3               200    2.352941
# 8    GRP_6               184    2.164706
# 9   GRP_13               145    1.705882
# 10  GRP_10               140    1.647059
# 11   GRP_5               129    1.517647
# 12  GRP_14               118    1.388235
# 13  GRP_25               116    1.364706
# 14  GRP_33               107    1.258824
# 15   GRP_4               100    1.176471
# 16  GRP_29                97    1.141176
# 17  GRP_18                88    1.035294
# 18  GRP_16                85    1.000000
# 19  GRP_17                81    0.952941

# %%
# Plot to visualize the percentage data distribution across different groups
sns.set(style="whitegrid")
plt.figure(figsize=(20,5))
order = mydata["Assignment group"].value_counts().index

ax = sns.countplot(x="Assignment group", data=mydata, order=order, linewidth=2,
                  edgecolor = "k"*len(order), palette='Set1')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
for p in ax.patches:
  ax.annotate(str(format(p.get_height()/len(mydata.index)*100, '.2f')+"%"), 
              (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 'bottom',
              rotation=90, xytext = (0, 10), textcoords = 'offset points')
# Out:
# c:\programdata\anaconda3\envs\tfnightly_py38\lib\site-packages\seaborn\categorical.py:1604: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated since 3.2 and will be removed two minor releases later. Use an explicit list instead.
#   barfunc(barpos, self.statistic, self.width,

# %%
df2 = mydata
le = preprocessing.LabelEncoder()
df2["LabelEncodings"] = le.fit_transform(df2["Assignment group"])
y_classes_len = len(le.classes_)
le.classes_
print(y_classes_len)
# Out:
# 74

# %%
y = np.asarray(df2['LabelEncodings'])

# %%
mydata.isna().apply(pd.value_counts)
# Out:
#        Unnamed: 0  Combined Description Cleaned  Assignment group  \
# False        8500                          8500              8500
#
#        LabelEncodings
# False            8500

# %%
#mydata.rename(columns = {'Combined description_ml':'Combined Description Cleaned'}, inplace = True)

# %%
mydata['Combined Description Cleaned'] = mydata['Combined Description Cleaned'].replace(np.nan, '', regex=True)

# %%
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(mydata['Combined Description Cleaned'])
print(X_train_counts.shape)
# Out:
# (8500, 3481)

# %%
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
print(X_train_tfidf.shape)
# Out:
# (8500, 3481)

# %%
test_size=0.3
X_train, X_test, y_train, y_test = train_test_split(X_train_tfidf, y, test_size=test_size)

# %%
print(len(count_vect.vocabulary_))
# Out:
# 3481

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (5950, 3481)
# (5950,)

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (2550, 3481)
# (2550,)

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(solver='lbfgs', max_iter=1000, multi_class='multinomial').fit(X_train, y_train)
y_pred = clf.predict(X_test)

# %%
acc_score = accuracy_score(y_test, y_pred)
#print("Logistic Regression Score: ", acc_score)
f1_score = metrics.f1_score(y_test, y_pred, average='weighted', labels=np.unique(y_pred))
#print("Logistic Regression F1 Score: ", f1_score)
precision_score = metrics.precision_score(y_test, y_pred, average='weighted', labels=np.unique(y_pred))
recall_score = metrics.recall_score(y_test, y_pred, average='weighted', labels=np.unique(y_pred))
#print('f1 score: {:.2%}'.format(f1_score))
#print('Precison Score : {:.2%}'.format(precision_score))
#print('Recall score: {:.2%}'.format(recall_score))
dfObj = pd.DataFrame(columns=['Algorithm', 'Accuracy', 'f1', 'Precision Score', 'Recall Score'])
accuracy = accuracy_score(y_test, y_pred)
dfObj = dfObj.append({'Algorithm' : 'LR   {:.0%}'.format(test_size) + ' Raw Test Data after Cleansing' ,
                      'Accuracy': '{:.2%}'.format(accuracy),
                      'f1':'{:.2%}'.format(f1_score),
                      'Precision Score': '{:.2%}'.format(precision_score),
                      'Recall Score': '{:.2%}'.format(recall_score) 
                     } , ignore_index=True)

sort_by=['Accuracy', 'f1']
dfObj = sort_df(dfObj,sort_by)
dfObj
# Out:
#                                 Algorithm Accuracy      f1 Precision Score  \
# 1  LR   30% Raw Test Data after Cleansing   62.12%  56.91%          61.34%
#
#   Recall Score
# 1       67.72%

# %% [markdown]
# ### Data Augmentation using Word Embeddings

# %%
mydata['Combined Description Cleaned'] = mydata['Combined Description Cleaned'].astype(str)

tokenizer = make_tokenizer(mydata['Combined Description Cleaned'])

# %%
## Dictionary of word index
index_word = {}
for word in tokenizer.word_index.keys():
    index_word[tokenizer.word_index[word]] = word

vocab_dict = tokenizer.word_index

# %%
vocab_dict
# Out:
# {'to': 1,
#  'from': 2,
#  'the': 3,
#  'in': 4,
#  'job': 5,
#  'received': 6,
#  'is': 7,
#  'not': 8,
#  'please': 9,
#  'on': 10,
#  'and': 11,
#  'for': 12,
#  'at': 13,
#  'password': 14,
#  'i': 15,
#  'a': 16,
#  'it': 17,
#  'of': 18,
#  'tool': 19,
#  'with': 20,
#  'schedule': 21,
#  'no': 22,
#  'this': 23,
#  'reset': 24,
#  'issue': 25,
#  'unable': 26,
#  'you': 27,
#  'have': 28,
#  'user': 29,
#  'my': 30,
#  'error': 31,
#  'access': 32,
#  'hello': 33,
#  'be': 34,
#  'account': 35,
#  'can': 36,
#  'that': 37,
#  'working': 38,
#  'company': 39,
#  'help': 40,
#  'ticket': 41,
#  'am': 42,
#  'when': 43,
#  'network': 44,
#  'are': 45,
#  'system': 46,
#  'cannot': 47,
#  'login': 48,
#  'need': 49,
#  'outlook': 50,
#  'as': 51,
#  'but': 52,
#  'vendor': 53,
#  'message': 54,
#  'power': 55,
#  'we': 56,
#  'was': 57,
#  'does': 58,
#  'me': 59,
#  'do': 60,
#  'an': 61,
#  'all': 62,
#  'below': 63,
#  'see': 64,
#  'able': 65,
#  'hi': 66,
#  'or': 67,
#  'new': 68,
#  'if': 69,
#  'team': 70,
#  'locked': 71,
#  'out': 72,
#  'down': 73,
#  'outage': 74,
#  'best': 75,
#  'name': 76,
#  'check': 77,
#  'number': 78,
#  'update': 79,
#  'up': 80,
#  'id': 81,
#  'contact': 82,
#  'will': 83,
#  'na': 84,
#  'customer': 85,
#  'since': 86,
#  'time': 87,
#  'sent': 88,
#  'circuit': 89,
#  'engineering': 90,
#  'plant': 91,
#  'manager': 92,
#  'server': 93,
#  'get': 94,
#  'request': 95,
#  'open': 96,
#  'what': 97,
#  'problem': 98,
#  'log': 99,
#  'site': 100,
#  'work': 101,
#  'by': 102,
#  'yes': 103,
#  'your': 104,
#  'management': 105,
#  'attached': 106,
#  'there': 107,
#  'did': 108,
#  'change': 109,
#  'phone': 110,
#  'computer': 111,
#  'any': 112,
#  'printer': 113,
#  'been': 114,
#  'after': 115,
#  'connect': 116,
#  'subject': 117,
#  'type': 118,
#  'into': 119,
#  'so': 120,
#  'platform': 121,
#  'start': 122,
#  'collaboration': 123,
#  'following': 124,
#  'call': 125,
#  'he': 126,
#  'language': 127,
#  'order': 128,
#  'same': 129,
#  'our': 130,
#  'could': 131,
#  'getting': 132,
#  'global': 133,
#  'screen': 134,
#  'now': 135,
#  'other': 136,
#  'dear': 137,
#  'unlock': 138,
#  'data': 139,
#  'production': 140,
#  'also': 141,
#  'active': 142,
#  'explorer': 143,
#  'device': 144,
#  'only': 145,
#  'use': 146,
#  'remote': 147,
#  'telephone': 148,
#  'available': 149,
#  'information': 150,
#  'backup': 151,
#  'office': 152,
#  'which': 153,
#  'create': 154,
#  'x': 155,
#  'one': 156,
#  'business': 157,
#  'maintenance': 158,
#  'print': 159,
#  'additional': 160,
#  'connection': 161,
#  'top': 162,
#  'address': 163,
#  'needs': 164,
#  'back': 165,
#  'tried': 166,
#  'would': 167,
#  'equipment': 168,
#  'link': 169,
#  'provider': 170,
#  'specify': 171,
#  'report': 172,
#  'application': 173,
#  'dialing': 174,
#  'notified': 175,
#  'provide': 176,
#  'maint': 177,
#  'diagnostics': 178,
#  'connected': 179,
#  'portal': 180,
#  'know': 181,
#  'trying': 182,
#  'delivery': 183,
#  'possible': 184,
#  'again': 185,
#  'file': 186,
#  'some': 187,
#  'client': 188,
#  'its': 189,
#  'e': 190,
#  'should': 191,
#  'eu': 192,
#  'used': 193,
#  'resolved': 194,
#  'view': 195,
#  'let': 196,
#  'how': 197,
#  'install': 198,
#  'still': 199,
#  'folder': 200,
#  'today': 201,
#  'note': 202,
#  'like': 203,
#  'then': 204,
#  'us': 205,
#  'kindly': 206,
#  'support': 207,
#  'blocked': 208,
#  'urgent': 209,
#  'morning': 210,
#  'drive': 211,
#  'enter': 212,
#  'add': 213,
#  'service': 214,
#  'ad': 215,
#  'confirmed': 216,
#  'status': 217,
#  'try': 218,
#  'location': 219,
#  'they': 220,
#  'had': 221,
#  'his': 222,
#  'just': 223,
#  'through': 224,
#  'find': 225,
#  'mobile': 226,
#  'than': 227,
#  'set': 228,
#  're': 229,
#  'good': 230,
#  'more': 231,
#  'implant': 232,
#  'process': 233,
#  'august': 234,
#  'summary': 235,
#  'resolve': 236,
#  'while': 237,
#  'showing': 238,
#  'c': 239,
#  'these': 240,
#  'per': 241,
#  'agent': 242,
#  'via': 243,
#  'mail': 244,
#  'look': 245,
#  'f': 246,
#  'may': 247,
#  'employee': 248,
#  'before': 249,
#  'slow': 250,
#  'advise': 251,
#  'last': 252,
#  'center': 253,
#  'page': 254,
#  'longer': 255,
#  'very': 256,
#  'correct': 257,
#  'due': 258,
#  'telephony': 259,
#  'were': 260,
#  'over': 261,
#  'got': 262,
#  'high': 263,
#  'security': 264,
#  'too': 265,
#  'caller': 266,
#  'being': 267,
#  'interface': 268,
#  'attachment': 269,
#  'code': 270,
#  'setup': 271,
#  'times': 272,
#  'printing': 273,
#  'material': 274,
#  'checked': 275,
#  'fix': 276,
#  'list': 277,
#  'missing': 278,
#  'machine': 279,
#  'full': 280,
#  'm': 281,
#  'send': 282,
#  'event': 283,
#  'under': 284,
#  'ethics': 285,
#  'make': 286,
#  'many': 287,
#  'found': 288,
#  'excel': 289,
#  'group': 290,
#  'ticketing': 291,
#  'receive': 292,
#  'because': 293,
#  'running': 294,
#  'why': 295,
#  'complete': 296,
#  'run': 297,
#  'd': 298,
#  'click': 299,
#  'old': 300,
#  'mi': 301,
#  'hand': 302,
#  'warning': 303,
#  'wrong': 304,
#  'about': 305,
#  'space': 306,
#  'want': 307,
#  'blank': 308,
#  'day': 309,
#  'them': 310,
#  'document': 311,
#  'notification': 312,
#  'opening': 313,
#  'where': 314,
#  'delete': 315,
#  'warehouse': 316,
#  'automatically': 317,
#  'kind': 318,
#  'ess': 319,
#  'distribution': 320,
#  'transaction': 321,
#  'two': 322,
#  'monitor': 323,
#  'assist': 324,
#  'date': 325,
#  'evening': 326,
#  'few': 327,
#  'local': 328,
#  'multiple': 329,
#  'she': 330,
#  'model': 331,
#  'fine': 332,
#  'go': 333,
#  'already': 334,
#  's': 335,
#  'show': 336,
#  'priority': 337,
#  'product': 338,
#  'unlocked': 339,
#  'meeting': 340,
#  'review': 341,
#  'correctly': 342,
#  'hard': 343,
#  'works': 344,
#  'action': 345,
#  'item': 346,
#  'volume': 347,
#  'disk': 348,
#  'their': 349,
#  'defective': 350,
#  'dell': 351,
#  'several': 352,
#  'supply': 353,
#  'distributor': 354,
#  'select': 355,
#  'even': 356,
#  'next': 357,
#  'installation': 358,
#  'sir': 359,
#  'another': 360,
#  'days': 361,
#  'external': 362,
#  'driver': 363,
#  'currently': 364,
#  'attach': 365,
#  'load': 366,
#  'shot': 367,
#  'thank': 368,
#  'yesterday': 369,
#  'display': 370,
#  'search': 371,
#  'off': 372,
#  'during': 373,
#  'sincerely': 374,
#  'version': 375,
#  'total': 376,
#  'g': 377,
#  'related': 378,
#  'every': 379,
#  'hub': 380,
#  'activation': 381,
#  'sure': 382,
#  'submit': 383,
#  'home': 384,
#  'sign': 385,
#  'th': 386,
#  'expense': 387,
#  'internal': 388,
#  'week': 389,
#  'assign': 390,
#  'well': 391,
#  'who': 392,
#  'here': 393,
#  'without': 394,
#  'until': 395,
#  'take': 396,
#  'someone': 397,
#  'desk': 398,
#  'audio': 399,
#  'sync': 400,
#  'query': 401,
#  'added': 402,
#  'refer': 403,
#  'done': 404,
#  'line': 405,
#  'host': 406,
#  'advised': 407,
#  'him': 408,
#  'response': 409,
#  'hot': 410,
#  'ie': 411,
#  'b': 412,
#  'her': 413,
#  'immediately': 414,
#  'copy': 415,
#  'training': 416,
#  'both': 417,
#  'interaction': 418,
#  'save': 419,
#  'further': 420,
#  'engineer': 421,
#  'field': 422,
#  'net': 423,
#  'payroll': 424,
#  'u': 425,
#  'first': 426,
#  'description': 427,
#  'form': 428,
#  'po': 429,
#  'default': 430,
#  'finance': 431,
#  'scan': 432,
#  'approval': 433,
#  'failure': 434,
#  'reason': 435,
#  'communication': 436,
#  'logging': 437,
#  'prod': 438,
#  'stock': 439,
#  'chain': 440,
#  'give': 441,
#  'area': 442,
#  'web': 443,
#  'port': 444,
#  'end': 445,
#  'bob': 446,
#  'primary': 447,
#  'person': 448,
#  'welcome': 449,
#  'going': 450,
#  'right': 451,
#  'exchange': 452,
#  'directory': 453,
#  'investigate': 454,
#  'however': 455,
#  'incident': 456,
#  'read': 457,
#  'month': 458,
#  'nothing': 459,
#  'incorrect': 460,
#  'sender': 461,
#  'source': 462,
#  'solve': 463,
#  'importance': 464,
#  'either': 465,
#  'result': 466,
#  'daily': 467,
#  'restart': 468,
#  'alert': 469,
#  'certificate': 470,
#  'condition': 471,
#  'example': 472,
#  'coming': 473,
#  'switch': 474,
#  'loading': 475,
#  'printed': 476,
#  'needful': 477,
#  'confirm': 478,
#  'personal': 479,
#  'reply': 480,
#  'current': 481,
#  'remove': 482,
#  'enable': 483,
#  'south': 484,
#  'floor': 485,
#  'launch': 486,
#  'authorized': 487,
#  'explicit': 488,
#  'wireless': 489,
#  'cold': 490,
#  'transfer': 491,
#  'administrator': 492,
#  'different': 493,
#  'way': 494,
#  'went': 495,
#  'soon': 496,
#  'supervisor': 497,
#  'traffic': 498,
#  'assigned': 499,
#  'stopped': 500,
#  'temporarily': 501,
#  'above': 502,
#  'within': 503,
#  'seeing': 504,
#  'ewe': 505,
#  'calendar': 506,
#  'tab': 507,
#  'analysis': 508,
#  'once': 509,
#  'output': 510,
#  'wont': 511,
#  'project': 512,
#  'control': 513,
#  'must': 514,
#  'upgrade': 515,
#  'forward': 516,
#  'something': 517,
#  'law': 518,
#  'destination': 519,
#  'allow': 520,
#  'tax': 521,
#  'free': 522,
#  'impact': 523,
#  'shown': 524,
#  'fixed': 525,
#  'box': 526,
#  'case': 527,
#  'room': 528,
#  'cost': 529,
#  'quote': 530,
#  'recently': 531,
#  'describe': 532,
#  'threshold': 533,
#  'dynamics': 534,
#  'regarding': 535,
#  'always': 536,
#  'window': 537,
#  'contain': 538,
#  'mistake': 539,
#  'shipping': 540,
#  'detail': 541,
#  'price': 542,
#  'function': 543,
#  'lock': 544,
#  'valid': 545,
#  'keep': 546,
#  'facing': 547,
#  'write': 548,
#  'calling': 549,
#  'each': 550,
#  'reference': 551,
#  'outside': 552,
#  'lost': 553,
#  'post': 554,
#  'disconnected': 555,
#  'ping': 556,
#  't': 557,
#  'o': 558,
#  'long': 559,
#  'less': 560,
#  'approve': 561,
#  'strictly': 562,
#  'notify': 563,
#  'alternate': 564,
#  'browser': 565,
#  'blue': 566,
#  'notch': 567,
#  'past': 568,
#  'future': 569,
#  'value': 570,
#  'come': 571,
#  'button': 572,
#  'option': 573,
#  'made': 574,
#  'disclosure': 575,
#  'between': 576,
#  'conversation': 577,
#  'effective': 578,
#  'own': 579,
#  'provided': 580,
#  'shop': 581,
#  'german': 582,
#  'configuration': 583,
#  'activity': 584,
#  'share': 585,
#  'confidential': 586,
#  'applicable': 587,
#  'disclaimer': 588,
#  'shortly': 589,
#  'guest': 590,
#  'label': 591,
#  'close': 592,
#  'instead': 593,
#  'ship': 594,
#  'indicate': 595,
#  'inside': 596,
#  'average': 597,
#  'release': 598,
#  'drawing': 599,
#  'plan': 600,
#  'assistance': 601,
#  'manually': 602,
#  'master': 603,
#  'affected': 604,
#  'replacement': 605,
#  'repair': 606,
#  'forth': 607,
#  'mailbox': 608,
#  'organization': 609,
#  'r': 610,
#  'properly': 611,
#  'batch': 612,
#  'handle': 613,
#  'directly': 614,
#  'technical': 615,
#  'turn': 616,
#  'basis': 617,
#  'attendance': 618,
#  'starting': 619,
#  'yet': 620,
#  'visitor': 621,
#  'put': 622,
#  'lean': 623,
#  'edit': 624,
#  'operation': 625,
#  'domain': 626,
#  'recreate': 627,
#  'corresponding': 628,
#  'soc': 629,
#  'displayed': 630,
#  'partner': 631,
#  'doing': 632,
#  'confirmation': 633,
#  'returned': 634,
#  'assignment': 635,
#  'ex': 636,
#  'balancing': 637,
#  'size': 638,
#  'configure': 639,
#  'performance': 640,
#  'ask': 641,
#  'intended': 642,
#  'session': 643,
#  'urgently': 644,
#  'tomorrow': 645,
#  'sound': 646,
#  'lockout': 647,
#  'point': 648,
#  'fail': 649,
#  'license': 650,
#  'shipment': 651,
#  'side': 652,
#  'worked': 653,
#  'quality': 654,
#  'tracker': 655,
#  'anything': 656,
#  'replace': 657,
#  'necessary': 658,
#  'bit': 659,
#  'latitude': 660,
#  'handling': 661,
#  'count': 662,
#  'amar': 663,
#  'critical': 664,
#  'generating': 665,
#  'loaded': 666,
#  'sending': 667,
#  'activate': 668,
#  'cell': 669,
#  'card': 670,
#  'entering': 671,
#  'warm': 672,
#  'saved': 673,
#  'protection': 674,
#  'station': 675,
#  'return': 676,
#  'boot': 677,
#  'win': 678,
#  'antivirus': 679,
#  'setting': 680,
#  'disabled': 681,
#  'given': 682,
#  'profile': 683,
#  'command': 684,
#  'billing': 685,
#  'general': 686,
#  'discount': 687,
#  'logged': 688,
#  'department': 689,
#  'restore': 690,
#  'part': 691,
#  'thanks': 692,
#  'ensure': 693,
#  'wy': 694,
#  'lot': 695,
#  'travel': 696,
#  'course': 697,
#  'node': 698,
#  'aw': 699,
#  'respond': 700,
#  'behalf': 701,
#  'mouse': 702,
#  'move': 703,
#  'amount': 704,
#  'left': 705,
#  'comes': 706,
#  'closed': 707,
#  'people': 708,
#  'original': 709,
#  'authorization': 710,
#  'procedure': 711,
#  'van': 712,
#  'think': 713,
#  'bad': 714,
#  'hear': 715,
#  'differently': 716,
#  'repeat': 717,
#  'medium': 718,
#  'lan': 719,
#  'detailed': 720,
#  'mode': 721,
#  'outbound': 722,
#  'extend': 723,
#  'scanner': 724,
#  'path': 725,
#  'reinstall': 726,
#  'battery': 727,
#  'came': 728,
#  'termination': 729,
#  'financial': 730,
#  'image': 731,
#  'detect': 732,
#  'single': 733,
#  'recall': 734,
#  'seem': 735,
#  'content': 736,
#  'environment': 737,
#  'word': 738,
#  'os': 739,
#  'consider': 740,
#  'moment': 741,
#  'forgot': 742,
#  'least': 743,
#  'yours': 744,
#  'conference': 745,
#  'occurrence': 746,
#  'ago': 747,
#  'around': 748,
#  'reach': 749,
#  'format': 750,
#  'method': 751,
#  'recipient': 752,
#  'appear': 753,
#  'everything': 754,
#  'place': 755,
#  'senior': 756,
#  'azure': 757,
#  'requester': 758,
#  'em': 759,
#  'causing': 760,
#  'permission': 761,
#  'removed': 762,
#  'owner': 763,
#  'important': 764,
#  'determined': 765,
#  'key': 766,
#  'goes': 767,
#  'notice': 768,
#  'quick': 769,
#  'solely': 770,
#  'reproduction': 771,
#  'exist': 772,
#  'pick': 773,
#  'entry': 774,
#  'cause': 775,
#  'trouble': 776,
#  'controller': 777,
#  'arrange': 778,
#  'till': 779,
#  'afternoon': 780,
#  'connectivity': 781,
#  'tag': 782,
#  'input': 783,
#  'validate': 784,
#  'listed': 785,
#  'turned': 786,
#  'k': 787,
#  'h': 788,
#  'video': 789,
#  'conversion': 790,
#  'worthy': 791,
#  'sorry': 792,
#  'blocking': 793,
#  'deployment': 794,
#  'rule': 795,
#  'arc': 796,
#  'overview': 797,
#  'goods': 798,
#  'freezing': 799,
#  'said': 800,
#  'object': 801,
#  'happening': 802,
#  'appropriate': 803,
#  'incoming': 804,
#  'router': 805,
#  'unit': 806,
#  'synchronization': 807,
#  'secondary': 808,
#  'most': 809,
#  'solution': 810,
#  'previous': 811,
#  'quantity': 812,
#  'successfully': 813,
#  'step': 814,
#  'such': 815,
#  'light': 816,
#  'doc': 817,
#  'icon': 818,
#  'empty': 819,
#  'payment': 820,
#  'p': 821,
#  'determine': 822,
#  'registration': 823,
#  'match': 824,
#  'z': 825,
#  'null': 826,
#  'standard': 827,
#  'paper': 828,
#  'viewer': 829,
#  'noise': 830,
#  'cycle': 831,
#  'year': 832,
#  'continue': 833,
#  'q': 834,
#  'authentic': 835,
#  'automatic': 836,
#  'hall': 837,
#  'verify': 838,
#  'might': 839,
#  'impacted': 840,
#  'bank': 841,
#  'whenever': 842,
#  'sa': 843,
#  'task': 844,
#  'analyst': 845,
#  'informed': 846,
#  'whether': 847,
#  'adobe': 848,
#  'extension': 849,
#  'legitimate': 850,
#  'infection': 851,
#  'tablet': 852,
#  'taking': 853,
#  'utilization': 854,
#  'text': 855,
#  'agreement': 856,
#  'unavailable': 857,
#  'though': 858,
#  'v': 859,
#  'pull': 860,
#  'period': 861,
#  'purchase': 862,
#  'inform': 863,
#  'unmonitored': 864,
#  'never': 865,
#  'direct': 866,
#  'statistics': 867,
#  'russia': 868,
#  'stuck': 869,
#  'measuring': 870,
#  'cable': 871,
#  'extra': 872,
#  'include': 873,
#  'moving': 874,
#  'registered': 875,
#  'j': 876,
#  'refresh': 877,
#  'hardware': 878,
#  'true': 879,
#  'protocol': 880,
#  'sherlock': 881,
#  'inspector': 882,
#  'flash': 883,
#  'player': 884,
#  'known': 885,
#  'pay': 886,
#  'told': 887,
#  'de': 888,
#  'regional': 889,
#  'director': 890,
#  'vacation': 891,
#  'require': 892,
#  'accounting': 893,
#  'broken': 894,
#  'pa': 895,
#  'receipt': 896,
#  'credit': 897,
#  'none': 898,
#  'unfortunately': 899,
#  'feedback': 900,
#  'prompt': 901,
#  'perform': 902,
#  'operator': 903,
#  'normal': 904,
#  'based': 905,
#  'giving': 906,
#  'scanning': 907,
#  'sometimes': 908,
#  'route': 909,
#  'understand': 910,
#  'frequent': 911,
#  'virus': 912,
#  'visible': 913,
#  'frequently': 914,
#  'twice': 915,
#  'facility': 916,
#  'therefore': 917,
#  'asset': 918,
#  'corrected': 919,
#  'st': 920,
#  'cancel': 921,
#  'else': 922,
#  'requirement': 923,
#  'table': 924,
#  'assistant': 925,
#  'inquiry': 926,
#  'relevant': 927,
#  'transferred': 928,
#  'third': 929,
#  'bottom': 930,
#  'thing': 931,
#  'book': 932,
#  'saying': 933,
#  'zero': 934,
#  'myself': 935,
#  'lead': 936,
#  'hope': 937,
#  'against': 938,
#  'ran': 939,
#  'media': 940,
#  'across': 941,
#  'pop': 942,
#  'much': 943,
#  'attempt': 944,
#  'ce': 945,
#  'quarantine': 946,
#  'picture': 947,
#  'clear': 948,
#  'fe': 949,
#  'state': 950,
#  'prior': 951,
#  'stop': 952,
#  'took': 953,
#  'couple': 954,
#  'taken': 955,
#  'revert': 956,
#  'nor': 957,
#  'channel': 958,
#  'authentication': 959,
#  'creation': 960,
#  'generate': 961,
#  'map': 962,
#  'loud': 963,
#  'shift': 964,
#  'technology': 965,
#  'onto': 966,
#  'those': 967,
#  'forecast': 968,
#  'gone': 969,
#  'follow': 970,
#  'final': 971,
#  'posted': 972,
#  'believe': 973,
#  'really': 974,
#  'template': 975,
#  'correlation': 976,
#  'booking': 977,
#  'red': 978,
#  'question': 979,
#  'second': 980,
#  'according': 981,
#  'zebra': 982,
#  'sensor': 983,
#  'cache': 984,
#  'accept': 985,
#  'classification': 986,
#  'weaver': 987,
#  'score': 988,
#  'misconfiguration': 989,
#  'chat': 990,
#  'appreciate': 991,
#  'export': 992,
#  'clock': 993,
#  'limited': 994,
#  'carrier': 995,
#  'selected': 996,
#  'zip': 997,
#  'record': 998,
#  'charging': 999,
#  'level': 1000,
#  ...}

# %%
## Loading word embedding
from time import time
start = time()
embed_mat = loadEmbeddingMatrix("glove840B300D", vocab_dict)
end = time()
print("Embedding loaded in ", (end-start)/60, "min")
# Out:
# Loaded 2196017 word vectors.
# total embedded: 3497 common words
# Embedding loaded in  2.213473749160767 min

# %%
from sklearn.neighbors import NearestNeighbors

synonyms_number = 5
word_number = 20000

nn = NearestNeighbors(n_neighbors=synonyms_number+1).fit(embed_mat)

neighbours_mat = nn.kneighbors(embed_mat[1:word_number])[1]

synonyms = {x[0]: x[1:] for x in neighbours_mat}

# %%
#id_to_word = {id_: word for word, id_ in vocab_dict.items()}

# %%
#id_to_word

# %%
## Finding nearby synonym - Basically it's not actually synonym. It's near by words of targetted word. 
import nltk
from nltk.corpus import wordnet

synonym = {}
for x in range(0,len(index_word)):
    try :
        synonym.update({index_word[x] : [index_word[synonyms[x][i]] for i in range(synonyms_number-1)]})
    except :
        pass

# %%
synonym
# Out:
# {'to': ['able', 'way', 'can', 'make'],
#  'from': ['out', 'this', 'up', 'to'],
#  'the': ['of', 'one', 'same', 'that'],
#  'in': ['into', 'the', 'place', 'within'],
#  'job': ['work', 'working', 'looking', 'good'],
#  'received': ['receive', 'given', 'sent', 'previously'],
#  'is': ['which', 'be', 'one', 'only'],
#  'not': ['should', 'be', 'but', 'would'],
#  'please': ['ask', 'hesitate', 'here', 'you'],
#  'on': ['out', 'the', 'off', 'up'],
#  'and': ['well', 'both', 'with', 'as'],
#  'for': ['and', 'making', 'with', 'well'],
#  'at': ['time', 'as', 'up', 'around'],
#  'password': ['login', 'user', 'encrypted', 'authentication'],
#  'i': ['didnt', 'u', 'havent', 'dont'],
#  'a': ['another', 'one', 'is', 'the'],
#  'it': ['but', 'that', 'something', 'so'],
#  'of': ['the', 'and', 'one', 'all'],
#  'tool': ['easier', 'use', 'utility', 'easy'],
#  'with': ['and', 'both', 'well', 'up'],
#  'schedule': ['time', 'regular', 'resume', 'next'],
#  'no': ['without', 'not', 'nothing', 'there'],
#  'this': ['it', 'one', 'same', 'that'],
#  'reset': ['disable', 'restart', 'manually', 'disconnect'],
#  'issue': ['problem', 'question', 'concern', 'concerned'],
#  'unable': ['cannot', 'able', 'failing', 'however'],
#  'you': ['sure', 'want', 'can', 'know'],
#  'have': ['they', 'could', 'already', 'would'],
#  'user': ['login', 'automatically', 'functionality', 'interface'],
#  'my': ['me', 'myself', 'own', 'got'],
#  'error': ['incorrect', 'invalid', 'problem', 'exception'],
#  'access': ['accessible', 'allow', 'provide', 'secure'],
#  'hello': ['hi', 'hey', 'yes', 'dear'],
#  'be': ['should', 'being', 'not', 'will'],
#  'account': ['payment', 'personal', 'same', 'however'],
#  'can': ['you', 'able', 'will', 'need'],
#  'that': ['because', 'which', 'it', 'but'],
#  'working': ['work', 'worked', 'works', 'doing'],
#  'company': ['business', 'corporation', 'provider', 'partner'],
#  'help': ['helping', 'need', 'give', 'able'],
#  'ticket': ['ticketing', 'booking', 'check', 'get'],
#  'am': ['wondering', 'myself', 'think', 'glad'],
#  'when': ['because', 'then', 'once', 'before'],
#  'network': ['connection', 'connectivity', 'connected', 'connect'],
#  'are': ['be', 'have', 'they', 'were'],
#  'system': ['control', 'which', 'operating', 'same'],
#  'cannot': ['not', 'must', 'should', 'can'],
#  'login': ['password', 'user', 'logged', 'account'],
#  'need': ['want', 'can', 'should', 'needs'],
#  'outlook': ['forecast', 'change', 'reflect', 'concern'],
#  'as': ['well', 'but', 'both', 'that'],
#  'but': ['though', 'because', 'even', 'although'],
#  'vendor': ['customer', 'supplier', 'provider', 'product'],
#  'message': ['sending', 'send', 'address', 'sent'],
#  'power': ['control', 'supply', 'force', 'turn'],
#  'we': ['they', 'there', 'know', 'what'],
#  'was': ['had', 'been', 'came', 'took'],
#  'does': ['not', 'that', 'because', 'if'],
#  'me': ['tell', 'myself', 'know', 'something'],
#  'do': ['want', 'know', 'would', 'think'],
#  'an': ['another', 'one', 'is', 'a'],
#  'all': ['those', 'these', 'other', 'everything'],
#  'below': ['above', 'here', 'following', 'see'],
#  'see': ['seeing', 'there', 'know', 'sure'],
#  'able': ['can', 'could', 'need', 'to'],
#  'hi': ['hello', 'hey', 'thanks', 'yes'],
#  'or': ['either', 'any', 'if', 'instead'],
#  'new': ['newly', 'latest', 'first', 'the'],
#  'if': ['unless', 'sure', 'else', 'not'],
#  'team': ['staff', 'ahead', 'well', 'needs'],
#  'locked': ['lock', 'stuck', 'kept', 'once'],
#  'out': ['up', 'down', 'put', 'going'],
#  'down': ['up', 'out', 'back', 'off'],
#  'outage': ['interruption', 'shutdown', 'disruption', 'disaster'],
#  'best': ['most', 'good', 'great', 'better'],
#  'name': ['same', 'known', 'naming', 'as'],
#  'check': ['sure', 'checked', 'out', 'get'],
#  'number': ['one', 'given', 'many', 'same'],
#  'update': ['upgrade', 'latest', 'fix', 'wait'],
#  'up': ['out', 'down', 'put', 'over'],
#  'id': ['ie', 'tag', 'ref', 'else'],
#  'contact': ['please', 'information', 'call', 'email'],
#  'will': ['be', 'can', 'should', 'would'],
#  'na': ['po', 'ko', 'sa', 'eh'],
#  'customer': ['service', 'business', 'product', 'client'],
#  'since': ['last', 'because', 'though', 'although'],
#  'time': ['when', 'once', 'day', 'before'],
#  'sent': ['sending', 'send', 'received', 'came'],
#  'circuit': ['relay', 'switching', 'signal', 'switch'],
#  'engineering': ['engineer', 'technical', 'technology', 'construction'],
#  'plant': ['leaves', 'facility', 'produce', 'production'],
#  'manager': ['assistant', 'supervisor', 'administrator', 'management'],
#  'server': ['client', 'setup', 'configuration', 'configure'],
#  'get': ['getting', 'want', 'going', 'need'],
#  'request': ['submit', 'send', 'notified', 'notice'],
#  'open': ['closed', 'opening', 'close', 'up'],
#  'what': ['why', 'how', 'know', 'think'],
#  'problem': ['trouble', 'reason', 'question', 'there'],
#  'log': ['logging', 'logged', 'check', 'login'],
#  'site': ['web', 'link', 'links', 'page'],
#  'work': ['working', 'works', 'worked', 'done'],
#  'by': ['with', 'part', 'brought', 'another'],
#  'yes': ['guess', 'anyway', 'maybe', 'though'],
#  'your': ['you', 'our', 'own', 'yourself'],
#  'management': ['manage', 'consulting', 'development', 'business'],
#  'attached': ['attach', 'attachment', 'separate', 'either'],
#  'there': ['but', 'though', 'even', 'nothing'],
#  'did': ['would', 'never', 'thought', 'could'],
#  'change': ['way', 'need', 'same', 'possible'],
#  'phone': ['telephone', 'mobile', 'call', 'calling'],
#  'computer': ['system', 'hardware', 'remotely', 'monitor'],
#  'any': ['certain', 'if', 'other', 'anything'],
#  'printer': ['printers', 'printing', 'ink', 'scanner'],
#  'been': ['being', 'already', 'have', 'was'],
#  'after': ['before', 'when', 'later', 'shortly'],
#  'connect': ['connected', 'connection', 'communicate', 'reconnect'],
#  'subject': ['topic', 'particular', 'certain', 'regarding'],
#  'type': ['kind', 'sort', 'example', 'similar'],
#  'into': ['out', 'up', 'through', 'way'],
#  'so': ['too', 'but', 'it', 'though'],
#  'platform': ['launch', 'functionality', 'enable', 'support'],
#  'start': ['starting', 'begin', 'going', 'beginning'],
#  'collaboration': ['teaming', 'initiative', 'project', 'ongoing'],
#  'following': ['previous', 'the', 'given', 'after'],
#  'call': ['calling', 'us', 'ask', 'if'],
#  'he': ['him', 'himself', 'his', 'never'],
#  'language': ['spoken', 'grammar', 'word', 'translation'],
#  'order': ['to', 'purchase', 'possible', 'without'],
#  'same': ['one', 'only', 'but', 'even'],
#  'our': ['us', 'own', 'we', 'their'],
#  'could': ['would', 'might', 'they', 'even'],
#  'getting': ['get', 'got', 'going', 'already'],
#  'global': ['globally', 'international', 'world', 'leading'],
#  'screen': ['display', 'touch', 'window', 'picture'],
#  'now': ['already', 'still', 'soon', 'it'],
#  'other': ['those', 'various', 'many', 'all'],
#  'dear': ['thank', 'glad', 'hello', 'yours'],
#  'unlock': ['unlocking', 'unlocked', 'activate', 'locked'],
#  'data': ['information', 'mapping', 'indicate', 'statistics'],
#  'production': ['produce', 'demand', 'primarily', 'well'],
#  'also': ['which', 'however', 'that', 'well'],
#  'active': ['inactive', 'actively', 'activity', 'as'],
#  'explorer': ['discovery', 'ie', 'icon', 'browser'],
#  'device': ['interface', 'method', 'connected', 'controller'],
#  'only': ['one', 'not', 'just', 'even'],
#  'use': ['used', 'can', 'need', 'make'],
#  'remote': ['remotely', 'control', 'access', 'setup'],
#  'telephone': ['phone', 'dialing', 'call', 'landline'],
#  'available': ['limited', 'provided', 'only', 'be'],
#  'information': ['regarding', 'provided', 'specific', 'related'],
#  'backup': ['setup', 'upgrade', 'disk', 'sync'],
#  'office': ['desk', 'department', 'headquarters', 'appointment'],
#  'which': ['that', 'also', 'however', 'it'],
#  'create': ['make', 'generate', 'can', 'creation'],
#  'x': ['w', 'inch', 'm', 'h'],
#  'one': ['another', 'same', 'only', 'that'],
#  'business': ['company', 'corporate', 'enterprise', 'customer'],
#  'maintenance': ['maintain', 'necessary', 'improvement', 'installation'],
#  'print': ['printed', 'printing', 'poster', 'graphic'],
#  'additional': ['extra', 'addition', 'further', 'provide'],
#  'connection': ['connected', 'connect', 'disconnect', 'same'],
#  'top': ['bottom', 'tops', 'best', 'one'],
#  'address': ['email', 'message', 'inform', 'register'],
#  'needs': ['need', 'needing', 'should', 'necessary'],
#  'back': ['again', 'up', 'out', 'down'],
#  'tried': ['trying', 'try', 'decided', 'did'],
#  'would': ['could', 'might', 'should', 'did'],
#  'equipment': ['supply', 'maintenance', 'facility', 'gear'],
#  'link': ['links', 'linking', 'linked', 'page'],
#  'provider': ['service', 'company', 'providing', 'customer'],
#  'specify': ['assign', 'specific', 'appropriate', 'refer'],
#  'report': ['survey', 'summary', 'recent', 'noted'],
#  'application': ['apply', 'applied', 'use', 'process'],
#  'dialing': ['dial', 'telephone', 'phone', 'calling'],
#  'notified': ['notify', 'informed', 'inform', 'immediately'],
#  'provide': ['providing', 'provided', 'ensure', 'offer'],
#  'maint': ['maintenance', 'redo', 'imp', 'reg'],
#  'diagnostics': ['detection', 'diagnosis', 'testing', 'calibration'],
#  'connected': ['connect', 'connection', 'directly', 'one'],
#  'portal': ['web', 'site', 'where', 'platform'],
#  'know': ['think', 'what', 'tell', 'why'],
#  'trying': ['try', 'tried', 'going', 'wanting'],
#  'delivery': ['deliver', 'shipping', 'order', 'shipment'],
#  'possible': ['possibility', 'possibly', 'if', 'might'],
#  'again': ['once', 'then', 'soon', 'before'],
#  'file': ['files', 'folder', 'format', 'document'],
#  'some': ['few', 'there', 'those', 'many'],
#  'client': ['customer', 'instance', 'manage', 'working'],
#  'its': ['itself', 'the', 'it', 'that'],
#  'e': ['o', 'tra', 'l', 'da'],
#  'should': ['would', 'be', 'must', 'not'],
#  'eu': ['ta', 'ce', 'bom', 'o'],
#  'used': ['use', 'example', 'as', 'also'],
#  'resolved': ['resolve', 'unresolved', 'however', 'possible'],
#  'view': ['see', 'above', 'here', 'right'],
#  'let': ['want', 'you', 'tell', 'give'],
#  'how': ['what', 'why', 'know', 'understand'],
#  'install': ['installing', 'installation', 'reinstall', 'upgrade'],
#  'still': ['but', 'though', 'even', 'already'],
#  'folder': ['files', 'file', 'delete', 'copy'],
#  'today': ['now', 'yesterday', 'tomorrow', 'week'],
#  'note': ['notice', 'mention', 'there', 'however'],
#  'like': ['think', 'even', 'know', 'but'],
#  'then': ['when', 'once', 'again', 'before'],
#  'us': ['we', 'our', 'them', 'give'],
#  'kindly': ['ask', 'hesitate', 'grateful', 'suggestion'],
#  'support': ['supporting', 'provide', 'providing', 'allow'],
#  'blocked': ['blocking', 'unblocked', 'block', 'stopped'],
#  'urgent': ['urgently', 'immediate', 'urgency', 'concern'],
#  'morning': ['afternoon', 'evening', 'yesterday', 'day'],
#  'drive': ['hard', 'turn', 'way', 'run'],
#  'enter': ['entering', 'to', 'go', 'must'],
#  'add': ['added', 'make', 'put', 'want'],
#  'service': ['customer', 'provider', 'providing', 'provide'],
#  'ad': ['campaign', 'same', 'mention', 'similar'],
#  'confirmed': ['confirming', 'confirm', 'previously', 'stated'],
#  'status': ['regardless', 'priority', 'as', 'current'],
#  'try': ['trying', 'tried', 'want', 'go'],
#  'location': ['place', 'area', 'vicinity', 'where'],
#  'they': ['have', 'would', 'could', 'even'],
#  'had': ['came', 'was', 'did', 'have'],
#  'his': ['himself', 'him', 'he', 'own'],
#  'just': ['actually', 'going', 'it', 'really'],
#  'through': ['into', 'out', 'up', 'the'],
#  'find': ['finding', 'you', 'discover', 'sure'],
#  'mobile': ['phone', 'handset', 'smart', 'android'],
#  'than': ['less', 'even', 'least', 'more'],
#  'set': ['setting', 'put', 'will', 'one'],
#  're': ['ing', 'regarding', 'concerned', 'regard'],
#  'good': ['great', 'better', 'very', 'well'],
#  'more': ['less', 'much', 'than', 'some'],
#  'implant': ['procedure', 'placement', 'whereby', 'enhancement'],
#  'process': ['step', 'necessary', 'procedure', 'making'],
#  'august': ['june', 'sept', 'march', 'sometime'],
#  'summary': ['description', 'brief', 'overview', 'report'],
#  'resolve': ['resolved', 'solve', 'unresolved', 'rectify'],
#  'while': ['when', 'even', 'as', 'up'],
#  'showing': ['shown', 'show', 'seen', 'see'],
#  'c': ['b', 'd', 'f', 'j'],
#  'these': ['those', 'many', 'all', 'some'],
#  'per': ['each', 'minimum', 'depending', 'month'],
#  'agent': ['representative', 'as', 'whether', 'presence'],
#  'via': ['directly', 'through', 'from', 'direct'],
#  'mail': ['email', 'send', 'sending', 'postal'],
#  'look': ['see', 'looking', 'way', 'like'],
#  'f': ['r', 'b', 'j', 't'],
#  'may': ['be', 'might', 'can', 'should'],
#  'employee': ['worker', 'employment', 'workplace', 'supervisor'],
#  'before': ['after', 'when', 'then', 'again'],
#  'slow': ['fast', 'faster', 'too', 'but'],
#  'advise': ['advised', 'inform', 'advice', 'consult'],
#  'last': ['week', 'next', 'first', 'yesterday'],
#  'center': ['middle', 'central', 'outside', 'place'],
#  'page': ['link', 'links', 'click', 'here'],
#  'longer': ['even', 'long', 'still', 'not'],
#  'very': ['quite', 'extremely', 'so', 'too'],
#  'correct': ['correctly', 'incorrect', 'exact', 'wrong'],
#  'due': ['result', 'despite', 'because', 'however'],
#  'telephony': ['connectivity', 'landline', 'telephone', 'communication'],
#  'were': ['been', 'had', 'have', 'they'],
#  'over': ['up', 'out', 'almost', 'past'],
#  'got': ['getting', 'get', 'had', 'just'],
#  'high': ['low', 'higher', 'quality', 'well'],
#  'security': ['secure', 'protection', 'surveillance', 'policy'],
#  'too': ['so', 'much', 'but', 'quite'],
#  'caller': ['call', 'calling', 'phone', 'dialing'],
#  'being': ['be', 'been', 'not', 'already'],
#  'interface': ['functionality', 'module', 'user', 'configuration'],
#  'attachment': ['attached', 'attach', 'handle', 'extension'],
#  'code': ['example', 'specify', 'description', 'check'],
#  'setup': ['configuration', 'configure', 'upgrade', 'setting'],
#  'times': ['time', 'twice', 'once', 'last'],
#  'printing': ['print', 'printer', 'printed', 'printers'],
#  'material': ['provided', 'made', 'actual', 'particular'],
#  'checked': ['check', 'sure', 'already', 'once'],
#  'fix': ['fixing', 'problem', 'broken', 'bug'],
#  'list': ['listed', 'listing', 'check', 'find'],
#  'missing': ['broken', 'unfortunately', 'found', 'lost'],
#  'machine': ['hand', 'equipment', 'computer', 'same'],
#  'full': ['complete', 'all', 'up', 'fully'],
#  'm': ['f', 'd', 'l', 't'],
#  'send': ['sending', 'sent', 'email', 'ask'],
#  'event': ['venue', 'place', 'weekend', 'next'],
#  'under': ['the', 'as', 'up', 'over'],
#  'ethics': ['ethical', 'understanding', 'concerned', 'concern'],
#  'make': ['making', 'give', 'way', 'want'],
#  'many': ['those', 'several', 'few', 'most'],
#  'found': ['discovered', 'been', 'find', 'there'],
#  'excel': ['ie', 'ppt', 'able', 'workbook'],
#  'group': ['join', 'together', 'one', 'other'],
#  'ticketing': ['ticket', 'kiosk', 'booking', 'billing'],
#  'receive': ['received', 'given', 'will', 'send'],
#  'because': ['but', 'though', 'even', 'reason'],
#  'running': ['run', 'ran', 'up', 'going'],
#  'why': ['what', 'know', 'think', 'reason'],
#  'complete': ['full', 'entire', 'all', 'only'],
#  'run': ['running', 'ran', 'up', 'going'],
#  'd': ['h', 'c', 'b', 'f'],
#  'click': ['below', 'here', 'link', 'button'],
#  'old': ['older', 'still', 'little', 'same'],
#  'mi': ['fe', 'lo', 'ave', 'ti'],
#  'hand': ['hold', 'put', 'up', 'out'],
#  'warning': ['warn', 'alert', 'caution', 'concern'],
#  'wrong': ['mistake', 'nothing', 'obviously', 'why'],
#  'about': ['talking', 'what', 'there', 'know'],
#  'space': ['where', 'inside', 'place', 'beyond'],
#  'want': ['need', 'get', 'you', 'know'],
#  'blank': ['insert', 'same', 'empty', 'box'],
#  'day': ['days', 'week', 'time', 'every'],
#  'them': ['they', 'those', 'put', 'themselves'],
#  'document': ['documentation', 'contents', 'copy', 'text'],
#  'notification': ['notify', 'notified', 'notice', 'confirmation'],
#  'opening': ['open', 'end', 'first', 'closed'],
#  'where': ['there', 'that', 'when', 'which'],
#  'delete': ['duplicate', 'overwrite', 'remove', 'disable'],
#  'warehouse': ['store', 'shop', 'depot', 'factory'],
#  'automatically': ['manually', 'instantly', 'correctly', 'immediately'],
#  'kind': ['sort', 'thing', 'way', 'really'],
#  'ess': ['ey', 'sh', 'ger', 'tor'],
#  'distribution': ['distributed', 'distribute', 'depend', 'relation'],
#  'transaction': ['payment', 'buyer', 'asset', 'account'],
#  'two': ['three', 'four', 'five', 'six'],
#  'monitor': ['detect', 'periodically', 'control', 'computer'],
#  'assist': ['assistance', 'help', 'helping', 'provide'],
#  'date': ['time', 'last', 'before', 'prior'],
#  'evening': ['afternoon', 'night', 'morning', 'day'],
#  'few': ['some', 'several', 'many', 'couple'],
#  'local': ['locally', 'other', 'regional', 'where'],
#  'multiple': ['different', 'several', 'various', 'two'],
#  'she': ['her', 'he', 'herself', 'when'],
#  'model': ['modeling', 'prototype', 'example', 'similar'],
#  'fine': ['well', 'but', 'good', 'though'],
#  'go': ['going', 'get', 'way', 'out'],
#  'already': ['still', 'been', 'now', 'have'],
#  's': ['as', 'one', 'same', 'own'],
#  'show': ['seen', 'see', 'showing', 'shown'],
#  'priority': ['concern', 'regardless', 'concerned', 'needs'],
#  'product': ['brand', 'customer', 'quantity', 'supplier'],
#  'unlocked': ['unlock', 'unlocking', 'locked', 'lock'],
#  'meeting': ['meet', 'conference', 'met', 'next'],
#  'review': ['summary', 'overview', 'this', 'description'],
#  'correctly': ['properly', 'incorrectly', 'correct', 'differently'],
#  'hard': ['enough', 'so', 'way', 'too'],
#  'works': ['work', 'working', 'worked', 'well'],
#  'action': ['that', 'as', 'force', 'taking'],
#  'item': ['quantity', 'order', 'list', 'product'],
#  'volume': ['hence', 'quantity', 'reduced', 'same'],
#  'disk': ['drive', 'backup', 'boot', 'hard'],
#  'their': ['own', 'them', 'themselves', 'they'],
#  'defective': ['faulty', 'defect', 'failing', 'insufficient'],
#  'dell': ['tra', 'notebook', 'e', 'bios'],
#  'several': ['numerous', 'few', 'many', 'two'],
#  'supply': ['supplier', 'demand', 'provide', 'quantity'],
#  'distributor': ['supplier', 'manufacturer', 'company', 'supply'],
#  'select': ['choose', 'selected', 'option', 'specify'],
#  'even': ['but', 'though', 'because', 'actually'],
#  'next': ['last', 'coming', 'first', 'before'],
#  'installation': ['install', 'installing', 'maintenance', 'upgrade'],
#  'sir': ['hi', 'dear', 'hey', 'sorry'],
#  'another': ['one', 'a', 'first', 'same'],
#  'days': ['day', 'ago', 'month', 'time'],
#  'external': ['internal', 'internally', 'connected', 'directly'],
#  'driver': ['crash', 'car', 'drive', 'truck'],
#  'currently': ['presently', 'already', 'now', 'been'],
#  'attach': ['attached', 'attachment', 'pull', 'separately'],
#  'load': ['loading', 'loaded', 'up', 'pull'],
#  'shot': ['taken', 'took', 'got', 'hit'],
#  'thank': ['thanks', 'glad', 'grateful', 'hope'],
#  'yesterday': ['last', 'week', 'today', 'morning'],
#  'display': ['displayed', 'screen', 'shown', 'showing'],
#  'search': ['searching', 'find', 'finding', 'listing'],
#  'off': ['out', 'up', 'down', 'away'],
#  'during': ['after', 'before', 'prior', 'beginning'],
#  'sincerely': ['grateful', 'personally', 'appreciate', 'wish'],
#  'version': ['original', 'same', 'full', 'similar'],
#  'total': ['average', 'amount', 'combined', 'only'],
#  'g': ['c', 'f', 'b', 'j'],
#  'related': ['other', 'specific', 'similar', 'associated'],
#  'every': ['one', 'each', 'time', 'same'],
#  'hub': ['connected', 'connect', 'apart', 'connection'],
#  'activation': ['activate', 'deactivation', 'activity', 'key'],
#  'sure': ['know', 'you', 'if', 'really'],
#  'submit': ['request', 'publish', 'send', 'enter'],
#  'home': ['house', 'out', 'up', 'own'],
#  'sign': ['right', 'if', 'see', 'either'],
#  'th': ['t', 'the', 'r', 'place'],
#  'expense': ['paying', 'cost', 'pay', 'regardless'],
#  'internal': ['external', 'internally', 'core', 'separate'],
#  'week': ['month', 'last', 'day', 'yesterday'],
#  'assign': ['specify', 'assigned', 'modify', 'allocate'],
#  'well': ['but', 'especially', 'so', 'both'],
#  'who': ['whom', 'whose', 'never', 'have'],
#  'here': ['see', 'there', 'now', 'go'],
#  'without': ['no', 'not', 'either', 'any'],
#  'until': ['before', 'once', 'later', 'till'],
#  'take': ['taking', 'give', 'get', 'make'],
#  'someone': ['somebody', 'anyone', 'anybody', 'something'],
#  'desk': ['room', 'office', 'sitting', 'table'],
#  'audio': ['sound', 'video', 'recording', 'microphone'],
#  'sync': ['synchronization', 'synchronized', 'reset', 'setup'],
#  'query': ['queries', 'specify', 'instance', 'search'],
#  'added': ['add', 'addition', 'put', 'already'],
#  'refer': ['describe', 'assume', 'example', 'particular'],
#  'done': ['doing', 'sure', 'did', 'well'],
#  'line': ['same', 'end', 'point', 'along'],
#  'host': ['guest', 'show', 'present', 'as'],
#  'advised': ['advise', 'instructed', 'informed', 'consult'],
#  'him': ['himself', 'he', 'his', 'them'],
#  'response': ['respond', 'concern', 'suggestion', 'feedback'],
#  'hot': ['big', 'cold', 'hard', 'couple'],
#  'ie': ['hence', 'either', 'instead', 'whereas'],
#  'b': ['c', 'f', 'd', 'j'],
#  'her': ['herself', 'she', 'his', 'hers'],
#  'immediately': ['then', 'once', 'quickly', 'before'],
#  'copy': ['copied', 'duplicate', 'read', 'original'],
#  'training': ['trainer', 'practice', 'learning', 'course'],
#  'both': ['well', 'either', 'especially', 'same'],
#  'interaction': ['affect', 'understanding', 'dependent', 'dynamics'],
#  'save': ['saving', 'saved', 'go', 'you'],
#  'further': ['thus', 'however', 'present', 'possible'],
#  'engineer': ['engineering', 'technician', 'supervisor', 'consultant'],
#  'field': ['where', 'well', 'as', 'beyond'],
#  'net': ['profit', 'revenue', 'up', 'share'],
#  'payroll': ['accounting', 'salary', 'expense', 'billing'],
#  'u': ['i', 'dont', 'didnt', 'wouldnt'],
#  'first': ['second', 'one', 'third', 'another'],
#  'description': ['summary', 'describe', 'example', 'refer'],
#  'form': ['example', 'as', 'either', 'can'],
#  'po': ['sa', 'ko', 'ba', 'na'],
#  'default': ['specify', 'option', 'instance', 'configure'],
#  'finance': ['financial', 'banking', 'investment', 'accounting'],
#  'scan': ['scanning', 'scanner', 'detect', 'check'],
#  'approval': ['approve', 'acceptance', 'pending', 'proposal'],
#  'failure': ['failing', 'fail', 'result', 'cause'],
#  'reason': ['fact', 'because', 'why', 'doubt'],
#  'communication': ['communicating',
#   'communicate',
#   'understanding',
#   'connection'],
#  'logging': ['log', 'logged', 'instance', 'usage'],
#  'prod': ['push', 'put', 'fore', 'pull'],
#  'stock': ['stocks', 'selling', 'sold', 'price'],
#  'chain': ['ring', 'one', 'drop', 'pull'],
#  'give': ['giving', 'make', 'let', 'you'],
#  'area': ['vicinity', 'where', 'outside', 'within'],
#  'web': ['site', 'links', 'page', 'portal'],
#  'port': ['terminal', 'connection', 'connected', 'connect'],
#  'end': ['beginning', 'back', 'one', 'way'],
#  'bob': ['joe', 'amy', 'sam', 'lee'],
#  'primary': ['secondary', 'particular', 'main', 'same'],
#  'person': ['someone', 'one', 'if', 'only'],
#  'welcome': ['invite', 'thank', 'appreciate', 'everyone'],
#  'going': ['go', 'just', 'way', 'gone'],
#  'right': ['way', 'just', 'it', 'out'],
#  'exchange': ['currency', 'trade', 'commodity', 'foreign'],
#  'directory': ['listing', 'search', 'browse', 'resource'],
#  'investigate': ['investigating', 'examine', 'investigation', 'explain'],
#  'however': ['although', 'though', 'but', 'perhaps'],
#  'incident': ['accident', 'suspect', 'victim', 'unfortunate'],
#  'read': ['reading', 'write', 'see', 'writing'],
#  'month': ['week', 'year', 'last', 'day'],
#  'nothing': ['anything', 'something', 'but', 'even'],
#  'incorrect': ['correct', 'incorrectly', 'wrong', 'invalid'],
#  'sender': ['forwarding', 'mail', 'message', 'sending'],
#  'source': ['example', 'possible', 'reference', 'same'],
#  'solve': ['problem', 'resolve', 'explain', 'help'],
#  'importance': ['important', 'concern', 'regard', 'understanding'],
#  'either': ['or', 'not', 'except', 'if'],
#  'result': ['resulting', 'however', 'possible', 'hence'],
#  'daily': ['weekly', 'day', 'everyday', 'regularly'],
#  'restart': ['shutdown', 'reset', 'start', 'disable'],
#  'alert': ['warning', 'warn', 'whenever', 'reminder'],
#  'certificate': ['credential', 'requirement', 'registration', 'license'],
#  'condition': ['otherwise', 'due', 'normal', 'however'],
#  'example': ['instance', 'particular', 'same', 'similar'],
#  'coming': ['going', 'come', 'soon', 'out'],
#  'switch': ['switching', 'switched', 'disconnect', 'turn'],
#  'loading': ['load', 'loaded', 'loader', 'ie'],
#  'printed': ['print', 'printing', 'paper', 'blank'],
#  'needful': ['moreover', 'necessary', 'regard', 'imperative'],
#  'confirm': ['confirming', 'confirmed', 'confirmation', 'suggest'],
#  'personal': ['own', 'individual', 'any', 'your'],
#  'reply': ['comment', 'answer', 'post', 'suggestion'],
#  'current': ['previous', 'new', 'same', 'future'],
#  'remove': ['removing', 'removed', 'eliminate', 'replace'],
#  'enable': ['allow', 'facilitate', 'provide', 'utilize'],
#  'south': ['north', 'east', 'west', 'southeast'],
#  'floor': ['room', 'wall', 'house', 'sitting'],
#  'launch': ['new', 'latest', 'upcoming', 'next'],
#  'authorized': ['authorize', 'authorization', 'authority', 'permit'],
#  'explicit': ['explicitly', 'imply', 'context', 'strictly'],
#  'wireless': ['wired', 'connectivity', 'network', 'mobile'],
#  'cold': ['freezing', 'warm', 'heat', 'too'],
#  'transfer': ['transferring', 'transferred', 'exchange', 'direct'],
#  'administrator': ['manager', 'supervisor', 'administrative', 'assistant'],
#  'different': ['various', 'other', 'same', 'similar'],
#  'way': ['it', 'ways', 'just', 'going'],
#  'went': ['came', 'took', 'gone', 'got'],
#  'soon': ['again', 'finally', 'now', 'once'],
#  'supervisor': ['assistant', 'technician', 'manager', 'administrator'],
#  'traffic': ['road', 'lane', 'inbound', 'route'],
#  'assigned': ['assign', 'assignment', 'assumed', 'chosen'],
#  'stopped': ['turned', 'stopping', 'went', 'when'],
#  'temporarily': ['permanently', 'immediately', 'momentarily', 'initially'],
#  'above': ['below', 'same', 'example', 'the'],
#  'within': ['in', 'outside', 'the', 'beyond'],
#  'seeing': ['see', 'seen', 'thought', 'wondering'],
#  'ewe': ['fore', 'ger', 'rabbit', 'ey'],
#  'calendar': ['calander', 'schedule', 'date', 'reminder'],
#  'tab': ['button', 'click', 'page', 'scroll'],
#  'analysis': ['analyses', 'evaluation', 'analyze', 'assessment'],
#  'once': ['again', 'when', 'then', 'never'],
#  'output': ['input', 'signal', 'corresponding', 'generating'],
#  'wont': ['doesnt', 'wouldnt', 'dont', 'didnt'],
#  'project': ['development', 'progress', 'work', 'effort'],
#  'control': ['system', 'allow', 'power', 'operation'],
#  'must': ['should', 'be', 'cannot', 'not'],
#  'upgrade': ['install', 'update', 'setup', 'installing'],
#  'forward': ['back', 'ahead', 'move', 'again'],
#  'something': ['anything', 'nothing', 'it', 'what'],
#  'law': ['legal', 'legislation', 'federal', 'rule'],
#  'destination': ['location', 'route', 'trip', 'where'],
#  'allow': ['enable', 'to', 'able', 'can'],
#  'tax': ['pay', 'deduction', 'expense', 'exempt'],
#  'free': ['full', 'get', 'giving', 'give'],
#  'impact': ['affect', 'affecting', 'impacted', 'potential'],
#  'shown': ['indicate', 'showing', 'displayed', 'example'],
#  'fixed': ['fixing', 'fix', 'same', 'hence'],
#  'box': ['put', 'set', 'inside', 'one'],
#  'case': ['whether', 'if', 'however', 'fact'],
#  'room': ['floor', 'hall', 'desk', 'sitting'],
#  'cost': ['costing', 'price', 'pay', 'expense'],
#  'quote': ['quotation', 'note', 'mention', 'you'],
#  'recently': ['been', 'previously', 'already', 'had'],
#  'describe': ['explain', 'refer', 'understand', 'particular'],
#  'threshold': ['limit', 'determined', 'zero', 'cutoff'],
#  'dynamics': ['dynamic', 'evolution', 'interaction', 'understanding'],
#  'regarding': ['concerning', 'regard', 'concerned', 'concern'],
#  'always': ['never', 'really', 'definitely', 'sure'],
#  'window': ['windows', 'door', 'pane', 'screen'],
#  'contain': ['indicate', 'contents', 'are', 'which'],
#  'mistake': ['wrong', 'reason', 'obviously', 'doubt'],
#  'shipping': ['shipped', 'shipment', 'ship', 'purchase'],
#  'detail': ['detailed', 'description', 'attention', 'describe'],
#  'price': ['cost', 'priced', 'buy', 'purchase'],
#  'function': ['functionality', 'hence', 'necessary', 'parameter'],
#  'lock': ['locking', 'locked', 'pull', 'snap'],
#  'valid': ['invalid', 'validity', 'applicable', 'regardless'],
#  'keep': ['keeping', 'sure', 'kept', 'put'],
#  'facing': ['faced', 'face', 'behind', 'turning'],
#  'write': ['writing', 'read', 'written', 'tell'],
#  'calling': ['call', 'saying', 'talking', 'telling'],
#  'each': ['every', 'one', 'same', 'individual'],
#  'reference': ['refer', 'example', 'description', 'particular'],
#  'outside': ['inside', 'place', 'behind', 'around'],
#  'lost': ['losing', 'lose', 'gone', 'still'],
#  'post': ['posting', 'comment', 'posted', 'here'],
#  'disconnected': ['disconnect', 'disconnecting', 'connected', 'reconnect'],
#  'ping': ['fetch', 'lan', 'ie', 'ding'],
#  't': ['f', 'don', 'l', 'r'],
#  'o': ['e', 'q', 'eh', 'no'],
#  'long': ['short', 'longer', 'so', 'but'],
#  'less': ['than', 'more', 'much', 'rather'],
#  'approve': ['approval', 'authorize', 'agreed', 'proposal'],
#  'strictly': ['solely', 'necessarily', 'specifically', 'hence'],
#  'notify': ['notified', 'inform', 'notification', 'notice'],
#  'alternate': ['either', 'same', 'different', 'instead'],
#  'browser': ['web', 'browsing', 'user', 'functionality'],
#  'blue': ['red', 'purple', 'yellow', 'white'],
#  'notch': ['top', 'edge', 'decent', 'well'],
#  'past': ['last', 'coming', 'few', 'far'],
#  'future': ['possible', 'potential', 'bring', 'possibility'],
#  'value': ['equal', 'given', 'difference', 'quantity'],
#  'come': ['coming', 'they', 'go', 'we'],
#  'button': ['buttons', 'click', 'toggle', 'scroll'],
#  'option': ['choice', 'choose', 'opt', 'select'],
#  'made': ['making', 'make', 'that', 'brought'],
#  'disclosure': ['disclosed', 'confidentiality', 'regarding', 'regard'],
#  'between': ['both', 'same', 'where', 'around'],
#  'conversation': ['talk', 'talking', 'discussion', 'telling'],
#  'effective': ['effectively', 'proven', 'beneficial', 'efficient'],
#  'own': ['their', 'put', 'our', 'make'],
#  'provided': ['provide', 'providing', 'addition', 'given'],
#  'shop': ['store', 'shopping', 'go', 'place'],
#  'german': ['japan', 'russia', 'august', 'ie'],
#  'configuration': ['configure', 'setup', 'interface', 'module'],
#  'activity': ['active', 'involved', 'specific', 'particular'],
#  'share': ['own', 'to', 'other', 'bring'],
#  'confidential': ['confidentiality', 'disclosure', 'personal', 'anonymous'],
#  'applicable': ['appropriate', 'requirement', 'accordance', 'apply'],
#  'disclaimer': ['notice', 'imply', 'note', 'refer'],
#  'shortly': ['later', 'before', 'after', 'soon'],
#  'guest': ['welcome', 'host', 'special', 'room'],
#  'label': ['brand', 'name', 'branded', 'put'],
#  'close': ['far', 'just', 'up', 'place'],
#  'instead': ['rather', 'either', 'basically', 'simply'],
#  'ship': ['shipping', 'shipped', 'shipment', 'off'],
#  'indicate': ['suggest', 'indicative', 'imply', 'shown'],
#  'inside': ['outside', 'into', 'behind', 'out'],
#  'average': ['than', 'higher', 'less', 'total'],
#  'release': ['upcoming', 'latest', 'coming', 'new'],
#  'drawing': ['draw', 'showing', 'art', 'making'],
#  'plan': ['proposal', 'would', 'idea', 'consider'],
#  'assistance': ['aid', 'assist', 'help', 'provide'],
#  'manually': ['automatically', 'correctly', 'properly', 'reset'],
#  'master': ['one', 'as', 'well', 'once'],
#  'affected': ['affecting', 'impacted', 'affect', 'extent'],
#  'replacement': ['replace', 'spare', 'repair', 'upgrade'],
#  'repair': ['maintenance', 'replacement', 'restoration', 'fix'],
#  'forth': ['upon', 'out', 'as', 'thus'],
#  'mailbox': ['mail', 'retrieve', 'sending', 'address'],
#  'organization': ['organizational', 'responsible', 'effort', 'association'],
#  'r': ['n', 'f', 'u', 'l'],
#  'properly': ['correctly', 'proper', 'accordingly', 'differently'],
#  'batch': ['bulk', 'duplicate', 'same', 'filling'],
#  'handle': ['handled', 'pull', 'handling', 'need'],
#  'directly': ['either', 'direct', 'immediately', 'simply'],
#  'technical': ['knowledge', 'engineering', 'critical', 'extensive'],
#  'turn': ['turning', 'turns', 'way', 'then'],
#  'basis': ['based', 'solely', 'regardless', 'given'],
#  'attendance': ['attend', 'given', 'concerned', 'expect'],
#  'starting': ['start', 'beginning', 'begin', 'going'],
#  'yet': ['but', 'though', 'so', 'even'],
#  'visitor': ['visiting', 'visit', 'where', 'whenever'],
#  'put': ['up', 'out', 'it', 'just'],
#  'lean': ['rather', 'up', 'way', 'pull'],
#  'edit': ['delete', 'link', 'duplicate', 'click'],
#  'operation': ['operating', 'operate', 'operational', 'capability'],
#  'domain': ['address', 'web', 'site', 'name'],
#  'recreate': ['replicate', 'revisit', 'create', 'simulate'],
#  'corresponding': ['respective', 'indicate', 'respectively', 'identical'],
#  'soc': ['prof', 'tor', 'imp', 'fe'],
#  'displayed': ['display', 'shown', 'appear', 'marked'],
#  'partner': ['relationship', 'joining', 'teaming', 'both'],
#  'doing': ['done', 'going', 'trying', 'just'],
#  'confirmation': ['confirming', 'confirm', 'confirmed', 'receipt'],
#  'returned': ['return', 'came', 'immediately', 'once'],
#  'assignment': ['assigned', 'assign', 'task', 'given'],
#  'ex': ['ie', 'as', 'same', 'except'],
#  'balancing': ['balance', 'keeping', 'ease', 'dynamic'],
#  'size': ['sized', 'large', 'bigger', 'small'],
#  'configure': ['configuration', 'setup', 'disable', 'specify'],
#  'performance': ['perform', 'better', 'outstanding', 'well'],
#  'ask': ['tell', 'know', 'let', 'want'],
#  'intended': ['meant', 'specifically', 'purpose', 'solely'],
#  'session': ['sessions', 'meeting', 'next', 'workshop'],
#  'urgently': ['urgent', 'needing', 'advise', 'immediate'],
#  'tomorrow': ['tonight', 'today', 'next', 'yesterday'],
#  'sound': ['loud', 'hear', 'noise', 'music'],
#  'lockout': ['lock', 'shutdown', 'stoppage', 'locked'],
#  'point': ['way', 'one', 'there', 'far'],
#  'fail': ['failing', 'cannot', 'ignore', 'should'],
#  'license': ['permit', 'licensed', 'registration', 'permission'],
#  'shipment': ['shipped', 'shipping', 'consignment', 'bulk'],
#  'side': ['sides', 'front', 'along', 'right'],
#  'worked': ['working', 'work', 'works', 'did'],
#  'quality': ['high', 'best', 'superior', 'good'],
#  'tracker': ['tracked', 'locator', 'check', 'ie'],
#  'anything': ['something', 'nothing', 'else', 'anyone'],
#  'replace': ['replacement', 'instead', 'put', 'need'],
#  'necessary': ['sufficient', 'appropriate', 'require', 'proper'],
#  'bit': ['little', 'quite', 'too', 'much'],
#  'latitude': ['approximate', 'exact', 'extent', 'hence'],
#  'handling': ['handled', 'handle', 'dealing', 'loading'],
#  'count': ['if', 'one', 'twice', 'only'],
#  'amar': ['sab', 'sha', 'ana', 'raj'],
#  'critical': ['important', 'importance', 'concern', 'necessary'],
#  'generating': ['generate', 'produce', 'generator', 'corresponding'],
#  'loaded': ['load', 'loading', 'filled', 'same'],
#  'sending': ['send', 'sent', 'giving', 'when'],
#  'activate': ['activation', 'disable', 'initiate', 'enable'],
#  'cell': ['phone', 'mobile', 'normal', 'activation'],
#  'card': ['credit', 'stamp', 'one', 'greeting'],
#  'entering': ['enter', 'into', 'before', 'the'],
#  'warm': ['cold', 'soft', 'nice', 'very'],
#  'saved': ['saving', 'save', 'once', 'when'],
#  'protection': ['protect', 'prevent', 'safety', 'security'],
#  'station': ['radio', 'train', 'bus', 'vicinity'],
#  'return': ['returned', 'if', 'back', 'leave'],
#  'boot': ['boots', 'disk', 'running', 'hard'],
#  'win': ['won', 'winning', 'chance', 'losing'],
#  'antivirus': ['virus', 'anti', 'spam', 'uninstalled'],
#  'setting': ['set', 'where', 'same', 'when'],
#  'disabled': ['disable', 'enable', 'unable', 'affected'],
#  'given': ['same', 'however', 'be', 'taken'],
#  'profile': ['similar', 'well', 'same', 'below'],
#  'command': ['execute', 'task', 'assigned', 'force'],
#  'billing': ['billed', 'invoice', 'payment', 'reimbursement'],
#  'general': ['concerned', 'particular', 'concern', 'certain'],
#  'discount': ['purchase', 'buy', 'price', 'offer'],
#  'logged': ['logging', 'log', 'checked', 'login'],
#  'department': ['office', 'supervisor', 'staff', 'general'],
#  'restore': ['restoring', 'recover', 'rebuild', 'preserve'],
#  'part': ['the', 'one', 'whole', 'entire'],
#  'thanks': ['thank', 'glad', 'luck', 'hope'],
#  'ensure': ['provide', 'maintain', 'necessary', 'insure'],
#  'wy': ['wi', 'ak', 'fe', 'ar'],
#  'lot': ['lots', 'much', 'some', 'few'],
#  'travel': ['traveling', 'trip', 'booking', 'vacation'],
#  'course': ['well', 'one', 'meant', 'there'],
#  'node': ['parameter', 'corresponding', 'subset', 'configuration'],
#  'aw': ['oh', 'ey', 'sh', 'hey'],
#  'respond': ['response', 'inform', 'explain', 'answer'],
#  'behalf': ['solely', 'inform', 'representative', 'regard'],
#  'mouse': ['rabbit', 'cursor', 'keyboard', 'normal'],
#  'move': ['moving', 'push', 'way', 'to'],
#  'amount': ['quantity', 'sufficient', 'less', 'reduced'],
#  'left': ['right', 'leaving', 'back', 'leave'],
#  'comes': ['goes', 'is', 'that', 'it'],
#  'closed': ['open', 'close', 'shut', 'opening'],
#  'people': ['those', 'there', 'everyone', 'many'],
#  'original': ['same', 'actual', 'originally', 'the'],
#  'authorization': ['authorize', 'authorized', 'approval', 'permit'],
#  'procedure': ['process', 'method', 'necessary', 'following'],
#  'van': ['met', 'tot', 'door', 'en'],
#  'think': ['know', 'guess', 'thought', 'why'],
#  'bad': ['worse', 'too', 'thing', 'wrong'],
#  'hear': ['listen', 'tell', 'know', 'say'],
#  'differently': ['correctly', 'similarly', 'rather', 'different'],
#  'repeat': ['repeated', 'twice', 'again', 'once'],
#  'medium': ['small', 'large', 'sized', 'suitable'],
#  'lan': ['bu', 'vpn', 'tor', 'ping'],
#  'detailed': ['detail', 'overview', 'extensive', 'description'],
#  'mode': ['switch', 'switching', 'option', 'setting'],
#  'outbound': ['inbound', 'forwarding', 'incoming', 'routing'],
#  'extend': ['extending', 'extended', 'expand', 'allow'],
#  'scanner': ['scanning', 'scan', 'printer', 'computer'],
#  'path': ['way', 'route', 'step', 'direction'],
#  'reinstall': ['uninstalled', 'install', 'installing', 'reinstallation'],
#  'battery': ['charger', 'charging', 'replacement', 'adapter'],
#  'came': ['went', 'brought', 'took', 'had'],
#  'termination': ['terminate', 'subsequent', 'cancellation', 'interruption'],
#  'financial': ['finance', 'banking', 'investment', 'asset'],
#  'image': ['picture', 'photo', 'same', 'view'],
#  'detect': ['detection', 'identify', 'indicate', 'determine'],
#  'single': ['one', 'another', 'same', 'second'],
#  'recall': ['remember', 'mention', 'remind', 'when'],
#  'seem': ['might', 'quite', 'obviously', 'too'],
#  'content': ['contents', 'relevant', 'web', 'site'],
#  'environment': ['environmental', 'development', 'setting', 'experience'],
#  'word': ['meaning', 'meant', 'spoken', 'saying'],
#  'os': ['o', 'ie', 'mac', 'para'],
#  'consider': ['whether', 'concerned', 'suggest', 'assume'],
#  'moment': ['thing', 'when', 'thought', 'knowing'],
#  'forgot': ['guess', 'remember', 'figured', 'sorry'],
#  'least': ['than', 'one', 'even', 'only'],
#  'yours': ['you', 'sure', 'anyway', 'it'],
#  'conference': ['meeting', 'presentation', 'convention', 'workshop'],
#  'occurrence': ['occur', 'probable', 'indicate', 'indicative'],
#  'ago': ['days', 'year', 'month', 'gone'],
#  'around': ['up', 'over', 'out', 'somewhere'],
#  'reach': ['reaching', 'to', 'beyond', 'up'],
#  'format': ['file', 'files', 'document', 'text'],
#  'method': ['example', 'procedure', 'process', 'instance'],
#  'recipient': ['received', 'receive', 'award', 'chosen'],
#  'appear': ['seem', 'be', 'however', 'may'],
#  'everything': ['anything', 'nothing', 'it', 'something'],
#  'place': ['where', 'there', 'one', 'way'],
#  'senior': ['junior', 'assistant', 'associate', 'advisor'],
#  'azure': ['emerald', 'blue', 'sky', 'beneath'],
#  'requester': ['request', 'notify', 'authorization', 'notified'],
#  'em': ['o', 'da', 'do', 'no'],
#  'causing': ['cause', 'prevent', 'sudden', 'affected'],
#  'permission': ['request', 'unless', 'permit', 'notice'],
#  'removed': ['removing', 'remove', 'immediately', 'once'],
#  'owner': ['ownership', 'company', 'buyer', 'when'],
#  'important': ['importance', 'particular', 'most', 'especially'],
#  'determined': ['determine', 'determination', 'whether', 'assumed'],
#  'key': ['important', 'critical', 'change', 'importance'],
#  'goes': ['comes', 'turns', 'going', 'it'],
#  'notice': ['unless', 'if', 'any', 'reason'],
#  'quick': ['easy', 'fast', 'simple', 'make'],
#  'solely': ['strictly', 'primarily', 'necessarily', 'regardless'],
#  'reproduction': ['hence', 'limited', 'identical', 'original'],
#  'exist': ['necessarily', 'cannot', 'not', 'hence'],
#  'pick': ['picked', 'get', 'grab', 'maybe'],
#  'entry': ['enter', 'entering', 'post', 'first'],
#  'cause': ['causing', 'because', 'reason', 'serious'],
#  'trouble': ['worry', 'problem', 'trying', 'when'],
#  'controller': ['subsystem', 'control', 'switch', 'interface'],
#  'arrange': ['hesitate', 'advise', 'able', 'to'],
#  'till': ['until', 'til', 'sometime', 'before'],
#  'afternoon': ['morning', 'evening', 'night', 'yesterday'],
#  'connectivity': ['connection', 'functionality', 'capability', 'wireless'],
#  'tag': ['ie', 'instead', 'example', 'instance'],
#  'input': ['output', 'corresponding', 'signal', 'feedback'],
#  'validate': ['verify', 'validation', 'evaluate', 'analyze'],
#  'listed': ['listing', 'list', 'currently', 'below'],
#  'turned': ['came', 'once', 'turning', 'when'],
#  'k': ['q', 'j', 'f', 'l'],
#  'h': ['d', 'l', 'f', 'c'],
#  'video': ['clip', 'picture', 'preview', 'audio'],
#  'conversion': ['converting', 'convert', 'converted', 'example'],
#  'worthy': ['surely', 'mention', 'doubt', 'perhaps'],
#  'sorry': ['forgot', 'guess', 'hey', 'yes'],
#  'blocking': ['blocked', 'block', 'stopping', 'prevent'],
#  'deployment': ['deploy', 'operational', 'capability', 'implementation'],
#  'rule': ['exception', 'meant', 'however', 'reason'],
#  'arc': ['point', 'end', 'apart', 'turning'],
#  'overview': ['detailed', 'summary', 'description', 'presentation'],
#  'goods': ['selling', 'consignment', 'shipment', 'demand'],
#  'freezing': ['freeze', 'cold', 'frozen', 'snow'],
#  'said': ['told', 'saying', 'stated', 'say'],
#  'object': ['instance', 'attribute', 'element', 'context'],
#  'happening': ['happen', 'coming', 'there', 'going'],
#  'appropriate': ['necessary', 'specific', 'proper', 'particular'],
#  'incoming': ['sending', 'inbound', 'outgoing', 'outbound'],
#  'router': ['routing', 'vpn', 'configure', 'wireless'],
#  'unit': ['separate', 'operation', 'one', 'same'],
#  'synchronization': ['sync', 'synchronized', 'subsystem', 'functionality'],
#  'secondary': ['primary', 'particular', 'either', 'whereas'],
#  'most': ['many', 'especially', 'one', 'even'],
#  'solution': ['possible', 'solve', 'product', 'simple'],
#  'previous': ['recent', 'last', 'past', 'previously'],
#  'quantity': ['amount', 'depending', 'hence', 'sufficient'],
#  'successfully': ['effectively', 'initially', 'successful', 'eventually'],
#  'step': ['way', 'move', 'then', 'process'],
#  'such': ['as', 'certain', 'other', 'particularly'],
#  'light': ['bright', 'lighter', 'clear', 'lit'],
#  'doc': ['ie', 'document', 'if', 'ppt'],
#  'icon': ['button', 'image', 'click', 'displayed'],
#  'empty': ['fill', 'filled', 'instead', 'inside'],
#  'payment': ['pay', 'payable', 'cash', 'invoice'],
#  'p': ['j', 'f', 'r', 'n'],
#  'determine': ['evaluate', 'determined', 'whether', 'identify'],
#  'registration': ['register', 'registered', 'license', 'prior'],
#  'match': ['draw', 'final', 'same', 'matching'],
#  'z': ['j', 'r', 'n', 'f'],
#  'null': ['invalid', 'nil', 'specify', 'attribute'],
#  'standard': ['same', 'basic', 'specification', 'use'],
#  'paper': ['printed', 'print', 'sheet', 'put'],
#  'viewer': ['reader', 'listener', 'visual', 'view'],
#  'noise': ['loud', 'sound', 'audible', 'hear'],
#  'cycle': ['phase', 'time', 'hence', 'change'],
#  'year': ['month', 'last', 'week', 'day'],
#  'continue': ['begin', 'will', 'begun', 'able'],
#  'q': ['k', 'j', 'lo', 'mas'],
#  'authentic': ['genuine', 'unique', 'true', 'original'],
#  'automatic': ['manual', 'automatically', 'manually', 'auto'],
#  'hall': ['room', 'entrance', 'house', 'venue'],
#  'verify': ['validate', 'verification', 'confirm', 'determine'],
#  'might': ['could', 'would', 'probably', 'should'],
#  'impacted': ['affected', 'impact', 'affecting', 'affect'],
#  'bank': ['banking', 'credit', 'financial', 'cash'],
#  'whenever': ['when', 'wherever', 'if', 'whatever'],
#  'sa': ['po', 'ko', 'na', 'si'],
#  'task': ['accomplish', 'difficult', 'effort', 'necessary'],
#  'analyst': ['consultant', 'advisor', 'senior', 'expert'],
#  'informed': ['inform', 'concerned', 'advised', 'aware'],
#  'whether': ['if', 'that', 'consider', 'however'],
#  'adobe': ['acrobat', 'mac', 'windows', 'cad'],
#  'extension': ['extend', 'extended', 'extending', 'end'],
#  'legitimate': ['legit', 'regardless', 'necessarily', 'any'],
#  'infection': ['infected', 'virus', 'fever', 'diagnosis'],
#  'tablet': ['android', 'touch', 'notebook', 'generic'],
#  'taking': ['take', 'taken', 'giving', 'took'],
#  'utilization': ['usage', 'utilize', 'efficiency', 'facilitate'],
#  'text': ['document', 'page', 'word', 'description'],
#  'agreement': ['agreed', 'contract', 'deal', 'proposal'],
#  'unavailable': ['unfortunately', 'otherwise', 'unable', 'absent'],
#  'though': ['but', 'although', 'because', 'however'],
#  'v': ['b', 'p', 'c', 'l'],
#  'pull': ['push', 'grab', 'put', 'up'],
#  'period': ['time', 'during', 'beginning', 'prior'],
#  'purchase': ['buy', 'order', 'selling', 'discount'],
#  'inform': ['informed', 'advise', 'notify', 'clarify'],
#  'unmonitored': ['unchecked', 'unrestricted', 'unplanned', 'unreachable'],
#  'never': ['ever', 'always', 'did', 'even'],
#  'direct': ['directly', 'indirect', 'immediate', 'possible'],
#  'statistics': ['report', 'information', 'summary', 'data'],
#  'russia': ['japan', 'united', 'republic', 'china'],
#  'stuck': ['gone', 'still', 'wondering', 'got'],
#  'measuring': ['measurement', 'calculating', 'approximate', 'quantify'],
#  'cable': ['plug', 'connector', 'connection', 'wire'],
#  'extra': ['additional', 'enough', 'get', 'some'],
#  'include': ['included', 'such', 'addition', 'also'],
#  'moving': ['move', 'turning', 'way', 'up'],
#  'registered': ['register', 'registration', 'unregistered', 'listed'],
#  'j': ['f', 'l', 'c', 'r'],
#  'refresh': ['reset', 'revisit', 'whenever', 'refreshing'],
#  'hardware': ['computer', 'functionality', 'console', 'setup'],
#  'true': ['believe', 'sense', 'nothing', 'not'],
#  'protocol': ['implementation', 'packet', 'forwarding', 'routing'],
#  'sherlock': ['colin', 'mister', 'amy', 'rita'],
#  'inspector': ['inspection', 'auditor', 'contractor', 'supervisor'],
#  'flash': ['flashing', 'video', 'ie', 'stick'],
#  'player': ['play', 'pick', 'one', 'when'],
#  'known': ['as', 'commonly', 'also', 'considered'],
#  'pay': ['paying', 'money', 'owe', 'cash'],
#  'told': ['telling', 'spoke', 'tell', 'saying'],
#  'de': ['la', 'en', 'y', 'un'],
#  'regional': ['local', 'major', 'representative', 'international'],
#  'director': ['executive', 'directed', 'assistant', 'vice'],
#  'vacation': ['holiday', 'trip', 'travel', 'stay'],
#  'require': ['necessary', 'need', 'allow', 'requirement'],
#  'accounting': ['audit', 'financial', 'payroll', 'finance'],
#  'broken': ['broke', 'missing', 'apart', 'stuck'],
#  'pa': ['mo', 'po', 'wi', 'ma'],
#  'receipt': ['receipts', 'confirmation', 'invoice', 'payment'],
#  'credit': ['loan', 'cash', 'bank', 'payment'],
#  'none': ['neither', 'nothing', 'though', 'nor'],
#  'unfortunately': ['though', 'obviously', 'however', 'although'],
#  'feedback': ['response', 'input', 'suggestion', 'respond'],
#  'prompt': ['immediate', 'timely', 'whenever', 'respond'],
#  'perform': ['able', 'performance', 'doing', 'routine'],
#  'operator': ['operation', 'operate', 'operating', 'owner'],
#  'normal': ['normally', 'usual', 'same', 'ie'],
#  'based': ['basis', 'similar', 'same', 'different'],
#  'giving': ['give', 'gave', 'making', 'given'],
#  'scanning': ['scan', 'scanner', 'detection', 'detect'],
#  'sometimes': ['often', 'occasionally', 'usually', 'rarely'],
#  'route': ['road', 'way', 'path', 'along'],
#  'understand': ['know', 'explain', 'realize', 'believe'],
#  'frequent': ['occasional', 'frequently', 'occasionally', 'regularly'],
#  'virus': ['infected', 'infection', 'worm', 'outbreak'],
#  'visible': ['appear', 'indicate', 'invisible', 'hence'],
#  'frequently': ['often', 'occasionally', 'sometimes', 'regularly'],
#  'twice': ['once', 'again', 'last', 'before'],
#  'facility': ['operation', 'providing', 'provided', 'addition'],
#  'therefore': ['thus', 'hence', 'however', 'nevertheless'],
#  'asset': ['assets', 'investment', 'portfolio', 'financial'],
#  'corrected': ['correction', 'correct', 'incorrectly', 'rectified'],
#  'st': ['ave', 'th', 'wi', 'june'],
#  'cancel': ['cancellation', 'postpone', 'terminate', 'unless'],
#  'else': ['if', 'anything', 'nothing', 'something'],
#  'requirement': ['require', 'mandatory', 'necessary', 'prerequisite'],
#  'table': ['tables', 'set', 'hand', 'desk'],
#  'assistant': ['supervisor', 'associate', 'manager', 'intern'],
#  'inquiry': ['enquiry', 'investigation', 'informed', 'investigate'],
#  'relevant': ['specific', 'appropriate', 'particular', 'important'],
#  'transferred': ['transferring', 'previously', 'transfer', 'directly'],
#  'third': ['second', 'fourth', 'first', 'one'],
#  'bottom': ['top', 'sides', 'down', 'above'],
#  'thing': ['what', 'reason', 'really', 'nothing'],
#  'book': ['author', 'read', 'writing', 'reading'],
#  'saying': ['say', 'telling', 'why', 'talking'],
#  'zero': ['minus', 'equal', 'assuming', 'difference'],
#  'myself': ['me', 'wondering', 'yourself', 'something'],
#  'lead': ['led', 'leading', 'as', 'eventually'],
#  'hope': ['glad', 'wish', 'think', 'doubt'],
#  'against': ['over', 'both', 'despite', 'while'],
#  'ran': ['run', 'running', 'went', 'came'],
#  'media': ['press', 'news', 'attention', 'content'],
#  'across': ['along', 'around', 'over', 'through'],
#  'pop': ['music', 'like', 'up', 'roll'],
#  'much': ['too', 'so', 'even', 'but'],
#  'attempt': ['trying', 'effort', 'try', 'to'],
#  'ce': ['ne', 'si', 'un', 'ma'],
#  'quarantine': ['outbreak', 'mandatory', 'exclusion', 'proper'],
#  'picture': ['photo', 'pic', 'image', 'see'],
#  'clear': ['clearly', 'that', 'however', 'way'],
#  'fe': ['ana', 'ar', 'wi', 'fi'],
#  'state': ['federal', 'that', 'country', 'same'],
#  'prior': ['before', 'subsequent', 'after', 'previous'],
#  'stop': ['stopping', 'stopped', 'going', 'trying'],
#  'took': ['came', 'went', 'gave', 'had'],
#  'couple': ['few', 'two', 'some', 'several'],
#  'taken': ['taking', 'took', 'given', 'take'],
#  'revert': ['assume', 'change', 'ie', 'assuming'],
#  'nor': ['neither', 'not', 'unless', 'however'],
#  'channel': ['broadcast', 'stream', 'network', 'segment'],
#  'authentication': ['authenticate', 'encryption', 'authorization', 'login'],
#  'creation': ['create', 'idea', 'own', 'that'],
#  'generate': ['generating', 'create', 'produce', 'utilize'],
#  'map': ['mapping', 'location', 'description', 'area'],
#  'loud': ['hear', 'sound', 'noise', 'audible'],
#  'shift': ['change', 'move', 'push', 'same'],
#  'technology': ['tech', 'engineering', 'capability', 'utilize'],
#  'onto': ['into', 'along', 'off', 'down'],
#  'those': ['these', 'many', 'all', 'some'],
#  'forecast': ['forecasting', 'outlook', 'expect', 'storm'],
#  'gone': ['going', 'still', 'went', 'never'],
#  'follow': ['following', 'take', 'way', 'go'],
#  'final': ['first', 'second', 'fourth', 'third'],
#  'posted': ['post', 'posting', 'comment', 'last'],
#  'believe': ['think', 'say', 'why', 'know'],
#  'really': ['definitely', 'actually', 'think', 'but'],
#  'template': ['layout', 'tag', 'blank', 'create'],
#  'correlation': ['indicate', 'indicative', 'difference', 'quantify'],
#  'booking': ['booked', 'travel', 'ticket', 'availability'],
#  'red': ['blue', 'yellow', 'purple', 'orange'],
#  'question': ['answer', 'suggestion', 'problem', 'explain'],
#  'second': ['third', 'first', 'fourth', 'one'],
#  'according': ['same', 'given', 'as', 'which'],
#  'zebra': ['lion', 'purple', 'rabbit', 'blue'],
#  'sensor': ['detection', 'calibration', 'measurement', 'device'],
#  'cache': ['memory', 'instance', 'buffer', 'fetch'],
#  'accept': ['accepted', 'reject', 'cannot', 'assume'],
#  'classification': ['criteria', 'classified', 'category', 'identification'],
#  'weaver': ['baker', 'scot', 'mason', 'schneider'],
#  'score': ['tally', 'overall', 'count', 'point'],
#  'misconfiguration': ['incompatibility',
#   'malfunction',
#   'disconnection',
#   'inconsistency'],
#  'chat': ['talk', 'conversation', 'invite', 'yahoo'],
#  'appreciate': ['understand', 'glad', 'wish', 'realize'],
#  'export': ['import', 'demand', 'bulk', 'commodity'],
#  'clock': ['alarm', 'time', 'set', 'timing'],
#  'limited': ['only', 'however', 'either', 'not'],
#  'carrier': ['transport', 'carry', 'carried', 'whereby'],
#  'selected': ['chosen', 'select', 'selection', 'previously'],
#  'zip': ['snap', 'code', 'full', 'easy'],
#  'record': ['recording', 'track', 'previous', 'last'],
#  'charging': ['charge', 'charger', 'instead', 'paying'],
#  'level': ['higher', 'high', 'above', 'regardless'],
#  ...}

# %%
## Use this synonym list to replace words with it's variation
## Below code is in draft. But logic can be used to complete the task

# %%
## Can only change words for selected part of speech to preserve semantic meaning.

import nltk
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize

def get_pos_tag (word, tagged) :
    res = [(x, y) for x, y in tagged if x == word]
    return res[0][1]

# Load the pretrained neural net
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# %%
synonymX = {}
for desc in mydata["Combined Description Cleaned"]:
    #print(desc)
    # Tokenize the text
    tokenized = tokenizer.tokenize(desc)

    # Get the list of words from the entire text
    words = word_tokenize(desc)

    # Identify the parts of speech
    tagged = nltk.pos_tag(words, tagset="universal")
    
    replacements = []


    for word in words:
        synonym2 = []
        antonyms = []
        word_index = vocab_dict.get(word, None)

        pos_tag = get_pos_tag(word, tagged)
        if (word_index and pos_tag in ["ADJ", "ADV", "NOUN", "VERB"] and word not in nltk.corpus.stopwords.words('english')) :
            for syn in wordnet.synsets(word, eval("wordnet." + pos_tag)):
                for l in syn.lemmas() :
                    try:
                        if(l.name() in [index_word[synonyms[word_index][i]] for i in range(synonyms_number-1)]):
                            synonym2.append(l.name())
                    except KeyError:
                            print ('Key error')
                            print(l.name())
                    #if l.antonyms():
                    #    antonyms.append(l.antonyms()[0].name())
        
        if (synonym2) :
            #print("hello")
            synonymX.update({word : list(set(synonym2))})
            print(word, set(synonym2))
# Out:
# checked {'check'}
# advised {'advise'}
# confirmed {'confirm'}
# resolved {'resolve'}
# received {'receive'}
# hello {'hi'}
# kind {'sort'}
# received {'receive'}
# hi {'hello'}
# best {'better', 'good'}
# engineering {'technology'}
# engineering {'technology'}
# connected {'connect'}
# received {'receive'}
# hi {'hello'}
# trying {'try'}
# working {'work'}
# home {'house'}
# unlocking {'unlock'}
# locked {'lock'}
# received {'receive'}
# hello {'hi'}
# home {'house'}
# connected {'connect'}
# working {'work'}
# getting {'get'}
# need {'want'}
# dynamics {'dynamic'}
# regarding {'regard'}
# best {'better', 'good'}
# phone {'telephone'}
# working {'work'}
# received {'receive'}
# hello {'hi'}
# locked {'lock'}
# client {'customer'}
# duplication {'duplicate'}
# received {'receive'}
# gentle {'soft'}
# trying {'try'}
# display {'showing'}
# assigned {'assign'}
# set {'put'}
# need {'want'}
# corrected {'correct'}
# flash {'flashing'}
# resolve {'solve'}
# assigned {'assign'}
# engineering {'technology'}
# need {'want'}
# working {'work'}
# needs {'need'}
# resolved {'resolve'}
# received {'receive'}
# working {'work'}
# days {'day'}
# need {'want'}
# taken {'take'}
# printed {'print'}
# picked {'pick'}
# daily {'everyday'}
# received {'receive'}
# telephony {'telephone'}
# received {'receive'}
# need {'want'}
# received {'receive'}
# global {'world'}
# locked {'lock'}
# kept {'keep'}
# locking {'lock'}
# incorrect {'wrong'}
# meeting {'meet'}
# received {'receive'}
# good {'well'}
# lost {'lose'}
# option {'choice'}
# setting {'set'}
# recall {'remember'}
# enquiry {'inquiry'}
# need {'want'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# best {'better', 'good'}
# tried {'try'}
# unlocked {'unlock'}
# confirmed {'confirm'}
# resolved {'resolve'}
# display {'showing'}
# entry {'entering'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# locked {'lock'}
# received {'receive'}
# locked {'lock'}
# working {'work'}
# needs {'need'}
# home {'house'}
# connected {'connect'}
# checked {'check'}
# home {'house'}
# disconnected {'disconnect'}
# confirmed {'confirm'}
# resolved {'resolve'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# power {'force'}
# power {'force'}
# start {'begin'}
# power {'force'}
# notified {'notify'}
# dialing {'dial'}
# working {'work'}
# global {'world'}
# global {'world'}
# additional {'extra'}
# power {'force'}
# power {'force'}
# start {'begin'}
# power {'force'}
# notified {'notify'}
# dialing {'dial'}
# working {'work'}
# global {'world'}
# additional {'extra'}
# received {'receive'}
# locked {'lock'}
# logging {'log'}
# works {'work'}
# received {'receive'}
# engineering {'technology'}
# drawing {'draw'}
# shown {'indicate'}
# hello {'hi'}
# need {'want'}
# showing {'show'}
# process {'procedure'}
# problem {'trouble'}
# fixed {'fix'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# space {'place'}
# view {'see'}
# expiry {'expiration'}
# received {'receive'}
# want {'need'}
# expiring {'expire'}
# received {'receive'}
# hello {'hi'}
# sent {'send'}
# hi {'hello'}
# contents {'content'}
# received {'receive'}
# hi {'hello'}
# contents {'content'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# good {'well'}
# displayed {'display'}
# stays {'remain', 'stay'}
# support {'supporting'}
# fix {'fixing'}
# freezing {'freeze'}
# received {'receive'}
# said {'say'}
# locked {'lock'}
# received {'receive'}
# hello {'hi'}
# trying {'try'}
# roll {'rolling'}
# hello {'hi'}
# blocked {'block'}
# hi {'hello'}
# received {'receive'}
# told {'tell'}
# received {'receive'}
# tried {'try'}
# got {'get'}
# taken {'take'}
# ensure {'insure'}
# trying {'try'}
# loaded {'load'}
# list {'listing'}
# customer {'client'}
# finishing {'finish'}
# starting {'begin', 'start'}
# select {'choose'}
# roughing {'rough'}
# times {'time'}
# good {'well'}
# person {'someone'}
# working {'work'}
# cause {'reason'}
# client {'customer'}
# customer {'client'}
# take {'get', 'make'}
# taking {'take'}
# phone {'telephone'}
# customer {'client'}
# scrapped {'scrap'}
# old {'older'}
# phone {'telephone'}
# take {'get', 'make'}
# set {'put'}
# view {'see'}
# received {'receive'}
# received {'receive'}
# view {'see'}
# hi {'hello'}
# received {'receive'}
# regarding {'regard'}
# needs {'need'}
# fixed {'fix'}
# attached {'attach'}
# extracted {'extract'}
# received {'receive'}
# good {'well'}
# made {'make'}
# checked {'check'}
# advised {'advise'}
# confirmed {'confirm'}
# resolved {'resolve'}
# start {'begin'}
# good {'well'}
# trouble {'problem', 'worry'}
# getting {'get'}
# customer {'client'}
# assist {'help'}
# blocked {'block'}
# used {'use'}
# need {'want'}
# received {'receive'}
# controller {'control'}
# getting {'get'}
# disabled {'disable'}
# working {'work'}
# getting {'get'}
# trying {'try'}
# got {'get'}
# find {'discover'}
# target {'aim'}
# received {'receive'}
# received {'receive'}
# note {'notice', 'mention'}
# happening {'happen'}
# getting {'get'}
# wasted {'waste'}
# received {'receive'}
# working {'work'}
# need {'want'}
# view {'see'}
# best {'better', 'good'}
# received {'receive'}
# currently {'presently'}
# utilization {'usage'}
# observing {'observe'}
# received {'receive'}
# hello {'hi'}
# starting {'begin', 'start'}
# finally {'eventually'}
# rather {'instead'}
# support {'supporting'}
# added {'add'}
# received {'receive'}
# added {'add'}
# used {'use'}
# licensed {'license'}
# locked {'lock'}
# received {'receive'}
# needs {'need'}
# engineering {'technology'}
# connected {'connect'}
# client {'customer'}
# resolved {'resolve'}
# working {'work'}
# received {'receive'}
# hello {'hi'}
# showing {'show'}
# received {'receive'}
# hello {'hi'}
# received {'receive'}
# received {'receive'}
# take {'get', 'make'}
# received {'receive'}
# received {'receive'}
# hi {'hello'}
# attached {'attach'}
# vacation {'holiday'}
# days {'day'}
# requirement {'prerequisite', 'necessary'}
# days {'day'}
# security {'protection'}
# reply {'answer'}
# require {'need'}
# global {'world'}
# support {'supporting'}
# center {'middle'}
# ticketing {'ticket'}
# kind {'sort'}
# received {'receive'}
# license {'permit', 'permission'}
# sent {'send'}
# hello {'hi'}
# received {'receive'}
# locked {'lock'}
# phone {'telephone'}
# mail {'send'}
# data {'information'}
# travel {'traveling'}
# shipment {'consignment'}
# notification {'notice'}
# setting {'set'}
# sent {'send'}
# customer {'client'}
# shipment {'consignment'}
# notification {'notice'}
# copied {'copy'}
# want {'need'}
# received {'receive'}
# power {'force'}
# start {'begin'}
# power {'force'}
# power {'force'}
# dialing {'dial'}
# working {'work'}
# global {'world'}
# additional {'extra'}
# appear {'seem'}
# locked {'lock'}
# need {'want'}
# customer {'client'}
# advisor {'consultant'}
# license {'permit', 'permission'}
# received {'receive'}
# good {'well'}
# need {'want'}
# received {'receive'}
# telephone {'phone'}
# map {'mapping'}
# power {'force'}
# start {'begin'}
# power {'force'}
# power {'force'}
# notified {'notify'}
# dialing {'dial'}
# working {'work'}
# global {'world'}
# additional {'extra'}
# added {'add'}
# received {'receive'}
# hi {'hello'}
# works {'work'}
# best {'better', 'good'}
# shipment {'consignment'}
# grinding {'grind'}
# received {'receive'}
# support {'supporting'}
# consignment {'shipment'}
# phone {'telephone'}
# support {'supporting'}
# hello {'hi'}
# received {'receive'}
# rectified {'rectify'}
# need {'want'}
# view {'see'}
# customer {'client'}
# getting {'get'}
# received {'receive'}
# sending {'send'}
# someone {'somebody'}
# look {'see'}
# affecting {'impact', 'affect'}
# paying {'pay'}
# locked {'lock'}
# locked {'lock'}
# need {'want'}
# section {'part'}
# received {'receive'}
# section {'part'}
# controller {'control'}
# received {'receive'}
# tell {'say'}
# sent {'send'}
# certificate {'credential'}
# yet {'even'}
# data {'information'}
# data {'information'}
# worked {'work'}
# start {'beginning', 'starting'}
# customer {'client'}
# still {'even'}
# target {'aim'}
# trying {'try'}
# cause {'reason'}
# find {'discover'}
# cause {'reason'}
# expiration {'expiry'}
# got {'get'}
# need {'want'}
# sent {'send'}
# house {'home'}
# want {'need'}
# received {'receive'}
# works {'work'}
# problem {'trouble'}
# returned {'return'}
# provide {'offer'}
# resolve {'solve'}
# make {'give'}
# model {'modeling', 'example'}
# need {'want'}
# printing {'print'}
# used {'use'}
# problem {'trouble'}
# printing {'print'}
# respond {'answer'}
# power {'force'}
# ticketing {'ticket'}
# power {'force'}
# power {'force'}
# start {'begin'}
# power {'force'}
# notified {'notify'}
# dialing {'dial'}
# working {'work'}
# global {'world'}
# global {'world'}
# additional {'extra'}
# received {'receive'}
# accepted {'accept'}
# need {'want'}
# set {'put'}
# old {'older'}
# attached {'attach'}
# checked {'check'}
# advised {'advise'}
# confirmed {'confirm'}
# resolved {'resolve'}
# hi {'hello'}
# received {'receive'}
# hello {'hi'}
# hi {'hello'}
# hello {'hi'}
# need {'want'}
# hello {'hi'}
# balancing {'balance'}
# hi {'hello'}
# customer {'client'}
# problem {'trouble'}
# received {'receive'}
# client {'customer'}
# license {'permit', 'permission'}
# working {'work'}
# extend {'expand'}
# need {'want'}
# received {'receive'}
# customer {'client'}
# days {'day'}
# need {'want'}
# sent {'send'}
# client {'customer'}
# working {'work'}
# received {'receive'}
# hi {'hello'}
# want {'need'}
# set {'put'}
# data {'information'}
# source {'reference'}
# getting {'get'}
# received {'receive'}
# synchronized {'sync'}
# received {'receive'}
# works {'work'}
# received {'receive'}
# hello {'hi'}
# best {'better', 'good'}
# effective {'efficient'}
# received {'receive'}
# received {'receive'}
# longer {'long'}
# works {'work'}
# seen {'see'}
# problem {'trouble'}
# find {'discover'}
# path {'route', 'way'}
# logging {'log'}
# balancing {'balance'}
# locked {'lock'}
# meeting {'meet'}
# received {'receive'}
# hello {'hi'}
# best {'better', 'good'}
# becomes {'become'}
# received {'receive'}
# create {'make'}
# provide {'offer'}
# locked {'lock'}
# sent {'send'}
# hi {'hello'}
# getting {'get'}
# resolution {'resolve'}
# still {'even'}
# received {'receive'}
# set {'put'}
# phone {'telephone'}
# best {'better', 'good'}
# power {'force'}
# start {'begin'}
# power {'force'}
# power {'force'}
# dialing {'dial'}
# working {'work'}
# global {'world'}
# additional {'extra'}
# logging {'log'}
# installation {'installing'}
# running {'run'}
# need {'want'}
# need {'want'}
# engineering {'technology'}
# connected {'connect'}
# connected {'connect'}
# received {'receive'}
# phone {'telephone'}
# best {'better', 'good'}
# need {'want'}
# need {'want'}
# security {'protection'}
# received {'receive'}
# dynamics {'dynamic'}
# global {'world'}
# technology {'engineering'}
# price {'cost'}
# center {'middle'}
# center {'middle'}
# made {'make'}
# need {'want'}
# lost {'lose'}
# works {'work'}
# data {'information'}
# going {'go'}
# problem {'trouble'}
# especially {'particularly'}
# best {'better', 'good'}
# provided {'provide'}
# old {'older'}
# problem {'trouble'}
# support {'supporting'}
# locked {'lock'}
# received {'receive'}
# hello {'hi'}
# sending {'send'}
# technologist {'engineer'}
# needs {'need'}
# connected {'connect'}
# confirmed {'confirm'}
# resolved {'resolve'}
# need {'want'}
# opening {'open'}
# still {'even'}
# old {'older'}
# data {'information'}
# need {'want'}
# phone {'telephone'}
# showing {'show'}
# small {'little'}
# connected {'connect'}
# corrected {'correct'}
# advised {'advise'}
# confirmed {'confirm'}
# resolved {'resolve'}
# fix {'fixing'}
# old {'older'}
# fix {'fixing'}
# needs {'need'}
# telephony {'telephone'}
# received {'receive'}
# hello {'hi'}
# want {'need'}
# need {'want'}
# permission {'permit'}
# checked {'check'}
# advised {'advise'}
# confirmed {'confirm'}
# resolved {'resolve'}
# received {'receive'}
# need {'want'}
# trouble {'problem', 'worry'}
# received {'receive'}
# good {'well'}
# assist {'help', 'assistance'}
# view {'see'}
# kind {'sort'}
# engineering {'technology'}
# severe {'serious'}
# especially {'particularly'}
# talk {'talking'}
# list {'listing'}
# working {'work'}
# still {'even'}
# data {'information'}
# blocked {'block'}
# incorrect {'wrong'}
# security {'protection'}
# entry {'entering'}
# source {'reference'}
# opening {'open'}
# received {'receive'}
# model {'modeling', 'example'}
# kind {'sort'}
# locked {'lock'}
# disconnected {'disconnect'}
# received {'receive'}
# hi {'hello'}
# disconnected {'disconnect'}
# make {'give'}
# received {'receive'}
# received {'receive'}
# locking {'lock'}
# causing {'cause'}
# entering {'enter'}
# especially {'particularly'}
# provide {'offer'}
# met {'meet'}
# power {'force'}
# start {'begin'}
# met {'meet'}
# power {'force'}
# power {'force'}
# dialing {'dial'}
# working {'work'}
# global {'world'}
# additional {'extra'}
# talk {'talking'}
# received {'receive'}
# hello {'hi'}
# load {'loading'}
# currently {'presently'}
# working {'work'}
# ordered {'order'}
# data {'information'}
# received {'receive'}
# currently {'presently'}
# locked {'lock'}
# power {'force'}
# start {'begin'}
# power {'force'}
# power {'force'}
# notified {'notify'}
# dialing {'dial'}
# working {'work'}
# global {'world'}
# additional {'extra'}
# received {'receive'}
# shop {'store'}
# shop {'store'}
# selected {'select'}
# shop {'store'}
# data {'information'}
# accepted {'accept'}
# client {'customer'}
# attached {'attach'}
# hello {'hi'}
# look {'looking'}
# need {'want'}
# received {'receive'}
# locked {'lock'}
# received {'receive'}
# hi {'hello'}
# locked {'lock'}
# data {'information'}
# used {'use'}
# saved {'save'}
# received {'receive'}
# received {'receive'}
# printed {'print'}
# engineering {'technology'}
# client {'customer'}
# working {'work'}
# received {'receive'}
# kind {'sort'}
# working {'work'}
# received {'receive'}
# hello {'hi'}
# worked {'work'}
# kind {'sort'}
# need {'want'}
# create {'make'}
# setting {'set'}
# set {'put'}
# received {'receive'}
# hi {'hello'}
# support {'supporting'}
# find {'discover'}
# reply {'answer'}
# data {'information'}
# old {'older'}
# ensure {'insure'}
# removed {'remove'}
# ticketing {'ticket'}
# section {'part'}
# best {'better', 'good'}
# cost {'price'}
# center {'middle'}
# received {'receive'}
# hello {'hi'}
# find {'discover'}
# engineering {'technology'}
# sent {'send'}
# find {'discover'}
# faced {'face'}
# resolve {'solve'}
# regarding {'regard'}
# logging {'log'}
# inquiry {'enquiry'}
# assist {'help', 'assistance'}
# logging {'log'}
# attached {'attach'}
# freezing {'freeze'}
# phone {'telephone'}
# freezing {'freeze'}
# find {'discover'}
# working {'work'}
# view {'see'}
# getting {'get'}
# stack {'heap'}
# tried {'try'}
# starting {'begin', 'start'}
# repair {'fix'}
# need {'want'}
# cost {'price'}
# received {'receive'}
# need {'want'}
# received {'receive'}
# best {'better', 'good'}
# working {'work'}
# received {'receive'}
# support {'supporting'}
# resolve {'solve'}
# problem {'trouble'}
# attached {'attach'}
# hi {'hello'}
# received {'receive'}
# contents {'content'}
# days {'day'}
# need {'want'}
# president {'chairman'}
# days {'day'}
# days {'day'}
# go {'get'}
# amount {'quantity'}
# data {'information'}
# transferred {'transfer'}
# recall {'remember'}
# assigned {'assign'}
# received {'receive'}
# recall {'remember'}
# locked {'lock'}
# locked {'lock'}
# license {'permit', 'permission'}
# license {'permit', 'permission'}
# engineering {'technology'}
# engineering {'technology'}
# phone {'telephone'}
# removing {'remove'}
# repeated {'repeat'}
# hello {'hi'}
# setting {'set'}
# need {'want'}
# hello {'hi'}
# colleague {'fellow'}
# fully {'full'}
# affected {'affect'}
# engineering {'technology'}
# hello {'hi'}
# security {'protection'}
# respect {'regard'}
# support {'supporting'}
# primary {'main'}
# telephone {'phone'}
# hello {'hi'}
# running {'run'}
# problem {'trouble'}
# working {'work'}
# received {'receive'}
# hello {'hi'}
# look {'see'}
# entering {'enter'}
# space {'place'}
# received {'receive'}
# seeing {'see'}
# global {'world'}
# need {'want'}
# data {'information'}
# global {'world'}
# need {'want'}
# received {'receive'}
# involved {'involve'}
# client {'customer'}
# installation {'installing'}
# links {'link'}
# start {'begin'}
# received {'receive'}
# phone {'telephone'}
# charging {'charge'}
# working {'work'}
# hello {'hi'}
# problem {'trouble'}
# tried {'try'}
# saving {'save'}
# worked {'work'}
# running {'run'}
# data {'information'}
# blocked {'block'}
# communication {'communicating'}
# sending {'send'}
# received {'receive'}
# logged {'log'}
# received {'receive'}
# hello {'hi'}
# ticketing {'ticket'}
# received {'receive'}
# currently {'presently'}
# utilization {'usage'}
# blocked {'block'}
# said {'say'}
# received {'receive'}
# give {'make'}
# subject {'topic'}
# blocked {'block'}
# customer {'client'}
# received {'receive'}
# data {'information'}
# daily {'everyday'}
# power {'force'}
# start {'begin'}
# power {'force'}
# power {'force'}
# dialing {'dial'}
# working {'work'}
# global {'world'}
# additional {'extra'}
# customer {'client'}
# customer {'client'}
# received {'receive'}
# hello {'hi'}
# need {'want'}
# left {'leave'}
# kind {'sort'}
# received {'receive'}
# showing {'show'}
# create {'make'}
# stack {'heap'}
# protection {'security'}
# hi {'hello'}
# received {'receive'}
# checked {'check'}
# advised {'advise'}
# confirmed {'confirm'}
# resolved {'resolve'}
# security {'protection'}
# balancing {'balance'}
# received {'receive'}
# locked {'lock'}
# provided {'provide'}
# phone {'telephone'}
# create {'make'}
# received {'receive'}
# need {'want'}
# received {'receive'}
# need {'want'}
# path {'route', 'way'}
# controller {'control'}
# phone {'telephone'}
# going {'go'}
# selection {'choice'}
# filtering {'filter'}
# extended {'extend'}
# instead {'rather'}
# communication {'communicating'}
# example {'instance'}
# trouble {'problem', 'worry'}
# tried {'try'}
# logging {'log'}
# sent {'send'}
# determined {'determine'}
# want {'need'}
# sent {'send'}
# reply {'answer'}
# hi {'hello'}
# sent {'send'}
# problem {'trouble'}
# sent {'send'}
# start {'beginning', 'starting'}
# topic {'subject'}
# hello {'hi'}
# balancing {'balance'}
# freezing {'freeze'}
# used {'use'}
# hello {'hi'}
# assume {'presume'}
# need {'want'}
# locked {'lock'}
# hi {'hello'}
# locked {'lock'}
# tried {'try'}
# going {'go'}
# listed {'list'}
# home {'house'}
# appear {'seem'}
# working {'work'}
# received {'receive'}
# hello {'hi'}
# someone {'somebody'}
# assist {'help'}
# showing {'show'}
# working {'work'}
# home {'house'}
# getting {'get'}
# balancing {'balance'}
# hello {'hi'}
# kind {'sort'}
# effective {'efficient'}
# expiring {'expire'}
# process {'procedure'}
# extend {'expand'}
# vacation {'holiday'}
# give {'make'}
# customer {'client'}
# telephone {'phone'}
# meeting {'meet'}
# freezing {'freeze'}
# meeting {'meet'}
# freezing {'freeze'}
# center {'middle'}
# working {'work'}
# global {'world'}
# customer {'client'}
# telephone {'phone'}
# needs {'need'}
# assistance {'assist', 'aid', 'help'}
# logging {'log'}
# customer {'client'}
# telephone {'phone'}
# price {'cost'}
# calculating {'calculate'}
# loaded {'load'}
# need {'want'}
# customer {'client'}
# start {'begin'}
# exploring {'explore'}
# space {'place'}
# data {'information'}
# received {'receive'}
# hi {'hello'}
# disruption {'disturbance', 'interruption'}
# begin {'start'}
# affected {'affect'}
# supply {'provide'}
# data {'information'}
# best {'better', 'good'}
# received {'receive'}
# longer {'long'}
# phone {'telephone'}
# customer {'client'}
# telephone {'phone'}
# received {'receive'}
# times {'time'}
# tried {'try'}
# hour {'minute'}
# met {'meet'}
# received {'receive'}
# coming {'come'}
# told {'tell'}
# mean {'think'}
# home {'house'}
# meeting {'meet'}
# getting {'get'}
# disabled {'disable'}
# shown {'indicate'}
# working {'work'}
# client {'customer'}
# attached {'attach'}
# said {'say'}
# working {'work'}
# received {'receive'}
# hello {'hi'}
# facing {'face'}
# meeting {'meet'}
# problem {'trouble'}
# fixed {'fix'}
# regarding {'regard'}
# showing {'show'}
# told {'tell'}
# investigating {'investigate'}
# involve {'require'}
# customer {'client'}
# telephone {'phone'}
# still {'even'}
# working {'work'}
# fixing {'fix'}
# expiring {'expire'}
# sent {'send'}
# hello {'hi'}
# days {'day'}
# received {'receive'}
# hello {'hi'}
# support {'supporting'}
# give {'make'}
# permission {'permit'}
# load {'loading'}
# global {'world'}
# customer {'client'}
# telephone {'phone'}
# block {'blocking'}
# removed {'remove'}
# need {'want'}
# create {'make'}
# customer {'client'}
# telephone {'phone'}
# need {'want'}
# fill {'filling'}
# blocked {'block'}
# received {'receive'}
# hello {'hi'}
# kind {'sort'}
# saying {'say'}
# facing {'face'}
# charging {'charge'}
# received {'receive'}
# path {'route', 'way'}
# found {'find'}
# switching {'switch', 'alternate'}
# times {'time'}
# best {'better', 'good'}
# locked {'lock'}
# synchronized {'sync'}
# longer {'long'}
# getting {'get'}
# talk {'speak'}
# received {'receive'}
# locked {'lock'}
# opening {'open'}
# hello {'hi'}
# net {'profit'}
# press {'pressing'}
# hello {'hi'}
# hi {'hello'}
# received {'receive'}
# old {'older'}
# phone {'telephone'}
# got {'get'}
# car {'auto'}
# displayed {'display'}
# look {'see'}
# checked {'check'}
# advised {'advise'}
# confirmed {'confirm'}
# resolved {'resolve'}
# display {'showing'}
# phone {'telephone'}
# power {'force'}
# start {'begin'}
# power {'force'}
# power {'force'}
# notified {'notify'}
# dialing {'dial'}
# working {'work'}
# global {'world'}
# additional {'extra'}
# received {'receive'}
# transportation {'transit', 'transport'}
# approximately {'around'}
# problem {'trouble'}
# received {'receive'}
# hello {'hi'}
# start {'begin'}
# connected {'connect'}
# connected {'connect'}
# confirmed {'confirm'}
# resolved {'resolve'}
# working {'work'}
# telephony {'telephone'}
# attached {'attach'}
# works {'work'}
# normally {'usually'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# create {'make'}
# received {'receive'}
# best {'better', 'good'}
# received {'receive'}
# received {'receive'}
# target {'aim'}
# defective {'faulty'}
# received {'receive'}
# hello {'hi'}
# works {'work'}
# best {'better', 'good'}
# received {'receive'}
# received {'receive'}
# routing {'route'}
# someone {'somebody'}
# routing {'route'}
# engineering {'technology'}
# connected {'connect'}
# confirmed {'confirm'}
# resolved {'resolve'}
# power {'force'}
# start {'begin'}
# power {'force'}
# power {'force'}
# notified {'notify'}
# dialing {'dial'}
# working {'work'}
# global {'world'}
# additional {'extra'}
# received {'receive'}
# hello {'hi'}
# working {'work'}
# opening {'open'}
# displayed {'display'}
# program {'plan'}
# closed {'close', 'shut'}
# primary {'main'}
# power {'force'}
# start {'begin'}
# power {'force'}
# power {'force'}
# notified {'notify'}
# dialing {'dial'}
# working {'work'}
# global {'world'}
# additional {'extra'}
# received {'receive'}
# hi {'hello'}
# facing {'face'}
# best {'better', 'good'}
# ticketing {'ticket'}
# received {'receive'}
# example {'instance'}
# problem {'trouble'}
# received {'receive'}
# hello {'hi'}
# checked {'check'}
# working {'work'}
# made {'make'}
# press {'pressing'}
# working {'work'}
# received {'receive'}
# currently {'presently'}
# found {'find'}
# best {'better', 'good'}
# tried {'try'}
# confirmed {'confirm'}
# resolved {'resolve'}
# opening {'open'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# hi {'hello'}
# assist {'help', 'assistance'}
# look {'see'}
# price {'cost'}
# global {'world'}
# inquiry {'enquiry'}
# kind {'sort'}
# told {'tell'}
# talk {'speak'}
# still {'even'}
# guess {'think', 'suppose'}
# need {'want'}
# provide {'offer'}
# phone {'telephone'}
# blocked {'block'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# hi {'hello'}
# got {'get'}
# disconnected {'disconnect'}
# received {'receive'}
# received {'receive'}
# power {'force'}
# data {'information'}
# timed {'time'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# locked {'lock'}
# received {'receive'}
# inquiry {'enquiry'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# primary {'main'}
# received {'receive'}
# received {'receive'}
# space {'place'}
# received {'receive'}
# received {'receive'}
# interruption {'disruption'}
# involved {'involve'}
# operational {'operating'}
# problem {'trouble'}
# best {'better', 'good'}
# power {'force'}
# start {'begin'}
# power {'force'}
# power {'force'}
# notified {'notify'}
# dialing {'dial'}
# working {'work'}
# global {'world'}
# additional {'extra'}
# effective {'efficient'}
# data {'information'}
# model {'modeling', 'example'}
# received {'receive'}
# controller {'control'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# power {'force'}
# engineering {'technology'}
# power {'force'}
# start {'begin'}
# power {'force'}
# notified {'notify'}
# dialing {'dial'}
# working {'work'}
# global {'world'}
# additional {'extra'}
# received {'receive'}
# working {'work'}
# received {'receive'}
# keeping {'keep'}
# power {'force'}
# start {'begin'}
# power {'force'}
# power {'force'}
# notified {'notify'}
# dialing {'dial'}
# working {'work'}
# global {'world'}
# additional {'extra'}
# resulting {'result'}
# flashing {'flash'}
# display {'showing'}
# shop {'store'}
# perhaps {'possibly'}
# refusing {'deny'}
# happening {'happen'}
# got {'get'}
# problem {'trouble'}
# option {'choice'}
# files {'file'}
# received {'receive'}
# hello {'hi'}
# locked {'lock'}
# received {'receive'}
# still {'even'}
# working {'work'}
# center {'middle'}
# locked {'lock'}
# freezing {'freeze'}
# received {'receive'}
# buttons {'button'}
# checked {'check'}
# region {'area'}
# received {'receive'}
# received {'receive'}
# best {'better', 'good'}
# received {'receive'}
# create {'make'}
# lead {'leading'}
# global {'world'}
# searching {'search'}
# received {'receive'}
# included {'include'}
# logging {'log'}
# needs {'need'}
# working {'work'}
# currently {'presently'}
# view {'see'}
# requirement {'prerequisite', 'necessary'}
# problem {'trouble'}
# received {'receive'}
# loaded {'load'}
# thought {'think'}
# working {'work'}
# telephone {'phone'}
# phone {'telephone'}
# problem {'trouble'}
# received {'receive'}
# dialing {'dial'}
# make {'give'}
# selection {'choice'}
# received {'receive'}
# hello {'hi'}
# trouble {'problem', 'worry'}
# getting {'get'}
# phone {'telephone'}
# works {'work'}
# customer {'client'}
# telephone {'phone'}
# assigned {'assign'}
# incorrect {'wrong'}
# need {'want'}
# received {'receive'}
# used {'use'}
# load {'loading'}
# old {'older'}
# phone {'telephone'}
# phone {'telephone'}
# attached {'attach'}
# received {'receive'}
# good {'well'}
# need {'want'}
# assistance {'assist', 'aid', 'help'}
# customer {'client'}
# give {'make'}
# experienced {'experience'}
# quantity {'amount'}
# still {'even'}
# showing {'show'}
# make {'give'}
# posted {'post'}
# tried {'try'}
# getting {'get'}
# frozen {'freeze'}
# made {'make'}
# working {'work'}
# customer {'client'}
# working {'work'}
# received {'receive'}
# calling {'call'}
# option {'choice'}
# select {'choose'}
# disconnected {'disconnect'}
# received {'receive'}
# good {'well'}
# give {'make'}
# received {'receive'}
# hello {'hi'}
# getting {'get'}
# trying {'try'}
# create {'make'}
# attached {'attach'}
# need {'want'}
# resolve {'solve'}
# locked {'lock'}
# locked {'lock'}
# need {'want'}
# shift {'change'}
# set {'put'}
# path {'route', 'way'}
# process {'procedure'}
# hi {'hello'}
# need {'want'}
# looking {'look'}
# received {'receive'}
# fill {'filling'}
# defense {'defence'}
# received {'receive'}
# measuring {'measurement'}
# received {'receive'}
# hello {'hi'}
# need {'want'}
# provide {'offer'}
# customer {'client'}
# quantity {'amount'}
# yet {'even'}
# received {'receive'}
# working {'work'}
# received {'receive'}
# best {'better', 'good'}
# received {'receive'}
# best {'better', 'good'}
# notification {'notice'}
# sending {'send'}
# received {'receive'}
# hi {'hello'}
# still {'even'}
# raised {'raise'}
# received {'receive'}
# impacted {'impact', 'affect'}
# need {'want'}
# works {'work'}
# working {'work'}
# received {'receive'}
# hello {'hi'}
# best {'better', 'good'}
# running {'run'}
# reaching {'reach'}
# received {'receive'}
# received {'receive'}
# best {'better', 'good'}
# received {'receive'}
# received {'receive'}
# hello {'hi'}
# provide {'offer'}
# best {'better', 'good'}
# got {'get'}
# received {'receive'}
# boots {'boot'}
# process {'procedure'}
# customer {'client'}
# telephone {'phone'}
# various {'several'}
# engineering {'technology'}
# received {'receive'}
# primary {'main'}
# global {'world'}
# power {'force'}
# start {'begin'}
# power {'force'}
# power {'force'}
# notified {'notify'}
# dialing {'dial'}
# working {'work'}
# global {'world'}
# additional {'extra'}
# received {'receive'}
# hi {'hello'}
# fulfill {'satisfy', 'accomplish'}
# fast {'quick'}
# received {'receive'}
# hello {'hi'}
# worse {'bad'}
# locked {'lock'}
# locked {'lock'}
# found {'find'}
# received {'receive'}
# hi {'hello'}
# assist {'help', 'assistance'}
# daily {'everyday'}
# received {'receive'}
# instead {'rather'}
# effective {'efficient'}
# received {'receive'}
# effective {'efficient'}
# old {'older'}
# received {'receive'}
# older {'old'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# aborted {'abort'}
# used {'use'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# home {'house'}
# received {'receive'}
# dynamics {'dynamic'}
# received {'receive'}
# good {'well'}
# portion {'part'}
# received {'receive'}
# working {'work'}
# working {'work'}
# problem {'trouble'}
# start {'beginning', 'starting'}
# opening {'open'}
# times {'time'}
# fixed {'fix'}
# phone {'telephone'}
# home {'house'}
# believe {'think'}
# need {'want'}
# received {'receive'}
# needs {'need'}
# received {'receive'}
# trouble {'problem', 'worry'}
# getting {'get'}
# person {'someone'}
# engineering {'technology'}
# provided {'provide'}
# trying {'try'}
# corrupt {'corrupted'}
# regarding {'regard'}
# locked {'lock'}
# find {'discover'}
# power {'force'}
# start {'begin'}
# power {'force'}
# power {'force'}
# notified {'notify'}
# dialing {'dial'}
# working {'work'}
# global {'world'}
# additional {'extra'}
# received {'receive'}
# getting {'get'}
# certificate {'credential'}
# trying {'try'}
# ran {'run'}
# quick {'fast'}
# longer {'long'}
# needs {'need'}
# attached {'attach'}
# good {'well'}
# need {'want'}
# connected {'connect'}
# make {'give'}
# received {'receive'}
# working {'work'}
# still {'even'}
# engineering {'technology'}
# hi {'hello'}
# need {'want'}
# received {'receive'}
# phone {'telephone'}
# received {'receive'}
# hello {'hi'}
# create {'make'}
# really {'actually'}
# posted {'post'}
# hi {'hello'}
# received {'receive'}
# license {'permit', 'permission'}
# need {'want'}
# working {'work'}
# worked {'work'}
# received {'receive'}
# logged {'log'}
# needs {'need'}
# needs {'need'}
# set {'put'}
# laid {'put'}
# need {'want'}
# engineering {'technology'}
# installation {'installing'}
# working {'work'}
# needs {'need'}
# working {'work'}
# almost {'nearly'}
# currently {'presently'}
# met {'meet'}
# leaves {'leave'}
# process {'procedure'}
# ticketing {'ticket'}
# special {'limited'}
# thus {'therefore', 'hence'}
# person {'someone'}
# usually {'normally'}
# filled {'fill'}
# received {'receive'}
# needs {'need'}
# provided {'provide'}
# resolved {'resolve'}
# problem {'trouble'}
# received {'receive'}
# go {'get'}
# tried {'try'}
# locked {'lock'}
# showing {'show'}
# hello {'hi'}
# option {'choice'}
# problem {'trouble'}
# flash {'flashing'}
# customer {'client'}
# profit {'earnings'}
# assigned {'assign'}
# center {'middle'}
# center {'middle'}
# procedure {'process'}
# warning {'warn'}
# notification {'notice'}
# completely {'totally'}
# class {'course'}
# working {'work'}
# data {'information'}
# set {'put'}
# eventually {'finally'}
# need {'want'}
# rather {'instead'}
# longer {'long'}
# fix {'fixing'}
# need {'want'}
# added {'add'}
# closed {'close', 'shut'}
# received {'receive'}
# checked {'check'}
# meeting {'meet'}
# printing {'print'}
# want {'need'}
# phone {'telephone'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# set {'put'}
# logging {'log'}
# support {'supporting'}
# power {'force'}
# start {'begin'}
# power {'force'}
# power {'force'}
# notified {'notify'}
# dialing {'dial'}
# working {'work'}
# global {'world'}
# additional {'extra'}
# checked {'check'}
# advised {'advise'}
# confirmed {'confirm'}
# resolved {'resolve'}
# phone {'telephone'}
# someone {'somebody'}
# look {'looking'}
# needs {'need'}
# working {'work'}
# getting {'get'}
# authorized {'authorize'}
# ticketing {'ticket'}
# provide {'offer'}
# locked {'lock'}
# received {'receive'}
# got {'get'}
# attempt {'effort', 'try'}
# support {'supporting'}
# received {'receive'}
# printing {'print'}
# need {'want'}
# power {'force'}
# ticketing {'ticket'}
# satisfied {'satisfy'}
# stays {'remain', 'stay'}
# currently {'presently'}
# list {'listing'}
# needs {'need'}
# old {'older'}
# printed {'print'}
# building {'build'}
# currently {'presently'}
# utilization {'usage'}
# regarding {'regard'}
# received {'receive'}
# path {'route', 'way'}
# received {'receive'}
# old {'older'}
# phone {'telephone'}
# received {'receive'}
# measuring {'measurement'}
# defective {'faulty'}
# good {'well'}
# provide {'offer'}
# entering {'enter'}
# received {'receive'}
# received {'receive'}
# working {'work'}
# received {'receive'}
# hi {'hello'}
# resolve {'solve'}
# problem {'trouble'}
# someone {'somebody'}
# best {'better', 'good'}
# working {'work'}
# printing {'print'}
# instead {'rather'}
# made {'make'}
# showing {'show'}
# data {'information'}
# example {'instance'}
# extra {'additional'}
# printed {'print'}
# note {'notice', 'mention'}
# running {'run'}
# make {'give'}
# received {'receive'}
# amount {'quantity'}
# finally {'eventually'}
# phone {'telephone'}
# received {'receive'}
# model {'modeling', 'example'}
# used {'use'}
# center {'middle'}
# trying {'try'}
# loaded {'load'}
# used {'use'}
# working {'work'}
# starting {'begin', 'start'}
# process {'procedure'}
# received {'receive'}
# create {'make'}
# customer {'client'}
# data {'information'}
# received {'receive'}
# best {'better', 'good'}
# received {'receive'}
# hi {'hello'}
# provided {'provide'}
# directly {'immediately', 'direct'}
# problem {'trouble'}
# received {'receive'}
# good {'well'}
# received {'receive'}
# client {'customer'}
# received {'receive'}
# ticketing {'ticket'}
# received {'receive'}
# display {'showing'}
# power {'force'}
# start {'begin'}
# power {'force'}
# power {'force'}
# dialing {'dial'}
# working {'work'}
# global {'world'}
# additional {'extra'}
# received {'receive'}
# sent {'send'}
# hi {'hello'}
# still {'even'}
# solve {'resolve'}
# yet {'even'}
# higher {'high'}
# shown {'indicate'}
# attached {'attach'}
# need {'want'}
# yet {'even'}
# best {'better', 'good'}
# printed {'print'}
# quotation {'quote'}
# locked {'lock'}
# received {'receive'}
# received {'receive'}
# best {'better', 'good'}
# customer {'client'}
# used {'use'}
# problem {'trouble'}
# problem {'trouble'}
# support {'supporting'}
# taken {'take'}
# need {'want'}
# received {'receive'}
# need {'want'}
# look {'see'}
# dynamics {'dynamic'}
# working {'work'}
# attached {'attach'}
# engineering {'technology'}
# customer {'client'}
# engineering {'technology'}
# permission {'permit'}
# create {'make'}
# cost {'price'}
# center {'middle'}
# fixed {'fix'}
# provide {'offer'}
# assistance {'assist', 'aid', 'help'}
# working {'work'}
# working {'work'}
# getting {'get'}
# trying {'try'}
# process {'procedure'}
# attached {'attach'}
# adapter {'adaptor'}
# thrown {'throw'}
# tried {'try'}
# times {'time'}
# connected {'connect'}
# phone {'telephone'}
# going {'go'}
# logged {'log'}
# getting {'get'}
# running {'run'}
# example {'instance'}
# source {'reference'}
# making {'make'}
# included {'include'}
# running {'run'}
# problem {'trouble'}
# start {'begin'}
# repair {'fix'}
# loading {'load'}
# tried {'try'}
# shutting {'shut'}
# trying {'try'}
# go {'get'}
# power {'force'}
# go {'get'}
# going {'go'}
# space {'place'}
# need {'want'}
# added {'add'}
# locked {'lock'}
# received {'receive'}
# hello {'hi'}
# locked {'lock'}
# best {'better', 'good'}
# showing {'show'}
# attached {'attach'}
# making {'make'}
# process {'procedure'}
# sent {'send'}
# sent {'send'}
# notification {'notice'}
# hello {'hi'}
# days {'day'}
# found {'find'}
# center {'middle'}
# used {'use'}
# global {'world'}
# support {'supporting'}
# ensure {'insure'}
# needs {'need'}
# engineering {'technology'}
# locked {'lock'}
# still {'even'}
# received {'receive'}
# trying {'try'}
# working {'work'}
# go {'get'}
# connected {'connect'}
# confirmed {'confirm'}
# resolved {'resolve'}
# ensure {'insure'}
# data {'information'}
# cost {'price'}
# center {'middle'}
# need {'want'}
# security {'protection'}
# person {'someone'}
# license {'permit', 'permission'}
# assigned {'assign'}
# client {'customer'}
# client {'customer'}
# assigned {'assign'}
# used {'use'}
# license {'permit', 'permission'}
# needs {'need'}
# start {'beginning', 'starting'}
# client {'customer'}
# received {'receive'}
# solve {'resolve'}
# problem {'trouble'}
# logging {'log'}
# display {'showing'}
# set {'put'}
# working {'work'}
# regarding {'regard'}
# checked {'check'}
# found {'find'}
# locked {'lock'}
# logging {'log'}
# customer {'client'}
# telephone {'phone'}
# customer {'client'}
# support {'supporting'}
# phone {'telephone'}
# phone {'telephone'}
# set {'put'}
# connected {'connect'}
# confirmed {'confirm'}
# resolved {'resolve'}
# go {'get'}
# received {'receive'}
# good {'well'}
# determined {'determine'}
# working {'work'}
# buy {'purchase'}
# need {'want'}
# received {'receive'}
# need {'want'}
# needs {'need'}
# connected {'connect'}
# resolved {'resolve'}
# need {'want'}
# received {'receive'}
# someone {'somebody'}
# give {'make'}
# received {'receive'}
# hello {'hi'}
# travel {'trip'}
# getting {'get'}
# leaving {'leave'}
# left {'leave'}
# list {'listing'}
# left {'leave'}
# received {'receive'}
# hello {'hi'}
# assigned {'assign'}
# someone {'somebody'}
# go {'get'}
# need {'want'}
# received {'receive'}
# hello {'hi'}
# vacation {'holiday'}
# support {'supporting'}
# view {'see'}
# client {'customer'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# hello {'hi'}
# program {'plan'}
# needs {'need'}
# working {'work'}
# getting {'get'}
# authorized {'authorize'}
# ticketing {'ticket'}
# provide {'offer'}
# best {'better', 'good'}
# working {'work'}
# old {'older'}
# received {'receive'}
# need {'want'}
# data {'information'}
# received {'receive'}
# checked {'check'}
# advised {'advise'}
# confirmed {'confirm'}
# resolved {'resolve'}
# received {'receive'}
# effective {'efficient'}
# yet {'even'}
# disabled {'disable'}
# received {'receive'}
# hello {'hi'}
# got {'get'}
# working {'work'}
# take {'get', 'make'}
# phone {'telephone'}
# model {'modeling', 'example'}
# calling {'call'}
# phone {'telephone'}
# received {'receive'}
# currently {'presently'}
# space {'place'}
# power {'force'}
# power {'force'}
# start {'begin'}
# power {'force'}
# dialing {'dial'}
# working {'work'}
# global {'world'}
# additional {'extra'}
# defective {'faulty'}
# good {'well'}
# need {'want'}
# light {'clear'}
# gray {'grey'}
# built {'build'}
# create {'make'}
# provide {'offer'}
# extended {'extend'}
# extend {'expand'}
# set {'put'}
# problem {'trouble'}
# take {'get', 'make'}
# times {'time'}
# often {'frequently'}
# block {'blocking'}
# stocks {'stock'}
# example {'instance'}
# problem {'trouble'}
# find {'discover'}
# cause {'reason'}
# solve {'resolve'}
# need {'want'}
# space {'place'}
# utilization {'usage'}
# currently {'presently'}
# received {'receive'}
# resolve {'solve'}
# connected {'connect'}
# checked {'check'}
# go {'get'}
# connected {'connect'}
# happening {'happen'}
# working {'work'}
# blocked {'block'}
# received {'receive'}
# need {'want'}
# received {'receive'}
# works {'work'}
# process {'procedure'}
# received {'receive'}
# hi {'hello'}
# assist {'help', 'assistance'}
# blocked {'block'}
# blocked {'block'}
# found {'find'}
# blocked {'block'}
# create {'make'}
# quote {'quotation'}
# adapter {'adaptor'}
# received {'receive'}
# give {'make'}
# best {'better', 'good'}
# received {'receive'}
# established {'establish'}
# block {'blocking'}
# received {'receive'}
# hello {'hi'}
# assist {'help'}
# create {'make'}
# set {'put'}
# need {'want'}
# power {'force'}
# defective {'faulty'}
# power {'force'}
# repair {'fix'}
# switched {'switch'}
# moving {'move'}
# locked {'lock'}
# showing {'show'}
# received {'receive'}
# hello {'hi'}
# create {'make'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# got {'get'}
# corrupted {'corrupt'}
# phone {'telephone'}
# effective {'efficient'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# hi {'hello'}
# assist {'help', 'assistance'}
# effective {'efficient'}
# sent {'send'}
# received {'receive'}
# attached {'attach'}
# old {'older'}
# data {'information'}
# hello {'hi'}
# customer {'client'}
# sent {'send'}
# hello {'hi'}
# effective {'efficient'}
# view {'see'}
# phone {'telephone'}
# received {'receive'}
# old {'older'}
# want {'need'}
# problem {'trouble'}
# opening {'open'}
# closed {'shut'}
# create {'make'}
# received {'receive'}
# hello {'hi'}
# effective {'efficient'}
# suspected {'suspect'}
# make {'give'}
# someone {'somebody'}
# data {'information'}
# security {'protection'}
# getting {'get'}
# thrown {'throw'}
# display {'showing'}
# list {'listing'}
# removed {'remove'}
# added {'add'}
# worked {'work'}
# resolved {'resolve'}
# instance {'example'}
# attached {'attach'}
# concerned {'concern'}
# consignment {'shipment'}
# customer {'client'}
# shipped {'ship'}
# received {'receive'}
# best {'better', 'good'}
# hello {'hi'}
# currently {'presently'}
# added {'add'}
# received {'receive'}
# hello {'hi'}
# days {'day'}
# installation {'installing'}
# displayed {'display'}
# received {'receive'}
# got {'get'}
# corrupted {'corrupt'}
# customer {'client'}
# telephone {'phone'}
# take {'get', 'make'}
# received {'receive'}
# need {'want'}
# power {'force'}
# start {'begin'}
# power {'force'}
# power {'force'}
# notified {'notify'}
# dialing {'dial'}
# working {'work'}
# global {'world'}
# additional {'extra'}
# hello {'hi'}
# person {'someone'}
# assigned {'assign'}
# problem {'trouble'}
# used {'use'}
# times {'time'}
# load {'loading'}
# really {'actually'}
# need {'want'}
# working {'work'}
# need {'want'}
# find {'discover'}
# need {'want'}
# received {'receive'}
# global {'world'}
# received {'receive'}
# hi {'hello'}
# picture {'pic', 'image', 'photo'}
# added {'add'}
# checked {'check'}
# giving {'give'}
# worked {'work'}
# resolved {'resolve'}
# received {'receive'}
# appear {'seem'}
# moving {'move'}
# hello {'hi'}
# yet {'even'}
# authorized {'authorize'}
# got {'get'}
# disconnected {'disconnect'}
# person {'someone'}
# disconnected {'disconnect'}
# problem {'trouble'}
# keeping {'keep'}
# received {'receive'}
# go {'get'}
# forward {'ahead'}
# showing {'show'}
# vacation {'holiday'}
# engineering {'technology'}
# need {'want'}
# corrupt {'corrupted'}
# working {'work'}
# working {'work'}
# got {'get'}
# trying {'try'}
# customer {'client'}
# telephone {'phone'}
# severe {'serious'}
# working {'work'}
# lost {'lose'}
# scanning {'scan'}
# telephone {'phone'}
# scanning {'scan'}
# found {'find'}
# loaded {'load'}
# create {'make'}
# data {'information'}
# source {'reference'}
# list {'listing'}
# freezing {'freeze'}
# power {'force'}
# start {'begin'}
# power {'force'}
# power {'force'}
# notified {'notify'}
# dialing {'dial'}
# working {'work'}
# global {'world'}
# global {'world'}
# additional {'extra'}
# loading {'load'}
# needs {'need'}
# received {'receive'}
# printing {'print'}
# need {'want'}
# printed {'print'}
# look {'see'}
# controller {'control'}
# handling {'handle'}
# handling {'handle'}
# best {'better', 'good'}
# engineering {'technology'}
# received {'receive'}
# hi {'hello'}
# look {'looking'}
# extremely {'highly'}
# received {'receive'}
# assist {'help'}
# old {'older'}
# kind {'sort'}
# extremely {'highly'}
# take {'get', 'make'}
# video {'picture'}
# measuring {'measurement'}
# defective {'faulty'}
# engineering {'technology'}
# working {'work'}
# authorized {'authorize'}
# view {'see'}
# permission {'permit'}
# start {'begin'}
# icon {'image'}
# start {'begin'}
# brought {'bring'}
# engineering {'technology'}
# received {'receive'}
# hi {'hello'}
# waiting {'wait'}
# believe {'think'}
# need {'want'}
# solve {'resolve'}
# problem {'trouble'}
# process {'procedure'}
# problem {'trouble'}
# give {'make'}
# power {'force'}
# start {'begin'}
# power {'force'}
# power {'force'}
# dialing {'dial'}
# working {'work'}
# global {'world'}
# additional {'extra'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# hello {'hi'}
# engineering {'technology'}
# create {'make'}
# approximately {'around'}
# old {'older'}
# rather {'instead'}
# instead {'rather'}
# trying {'try'}
# fix {'fixing'}
# best {'better', 'good'}
# set {'put'}
# permission {'permit'}
# greeting {'greet'}
# registered {'register'}
# listed {'list'}
# center {'middle'}
# men {'man'}
# need {'want'}
# power {'force'}
# start {'begin'}
# power {'force'}
# power {'force'}
# notified {'notify'}
# dialing {'dial'}
# working {'work'}
# global {'world'}
# additional {'extra'}
# resolved {'resolve'}
# received {'receive'}
# hello {'hi'}
# communication {'communicating'}
# protection {'security'}
# needs {'need'}
# connected {'connect'}
# informed {'inform'}
# resolved {'resolve'}
# phone {'telephone'}
# received {'receive'}
# tried {'try'}
# sent {'send'}
# center {'middle'}
# power {'force'}
# affected {'affect'}
# additional {'extra'}
# route {'path', 'road'}
# timed {'time'}
# regarding {'regard'}
# notification {'notice'}
# support {'supporting'}
# listed {'list'}
# phone {'telephone'}
# communication {'communicating'}
# client {'customer'}
# received {'receive'}
# hello {'hi'}
# client {'customer'}
# las {'la'}
# attached {'attach'}
# customer {'client'}
# telephone {'phone'}
# remember {'think'}
# locked {'lock'}
# customer {'client'}
# telephone {'phone'}
# customer {'client'}
# shown {'indicate'}
# attached {'attach'}
# getting {'get'}
# trying {'try'}
# data {'information'}
# found {'find'}
# option {'choice'}
# currently {'presently'}
# audio {'sound'}
# setting {'set'}
# need {'want'}
# client {'customer'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# gray {'grey'}
# heap {'stack'}
# light {'clear'}
# light {'clear'}
# telephony {'telephone'}
# received {'receive'}
# need {'want'}
# installation {'installing'}
# license {'permit', 'permission'}
# need {'want'}
# received {'receive'}
# hello {'hi'}
# problem {'trouble'}
# tried {'try'}
# luck {'chance'}
# received {'receive'}
# hello {'hi'}
# go {'get'}
# engineering {'technology'}
# example {'instance'}
# entering {'enter'}
# engineering {'technology'}
# looking {'look'}
# data {'information'}
# found {'find'}
# received {'receive'}
# hi {'hello'}
# need {'want'}
# make {'give'}
# solve {'resolve'}
# problem {'trouble'}
# working {'work'}
# quote {'quotation'}
# showing {'show'}
# registered {'register'}
# received {'receive'}
# expiry {'expiration'}
# problem {'trouble'}
# best {'better', 'good'}
# flash {'flashing'}
# need {'want'}
# path {'route', 'way'}
# needs {'need'}
# forward {'ahead'}
# need {'want'}
# effective {'efficient'}
# edit {'delete'}
# telephone {'phone'}
# alarm {'alert'}
# received {'receive'}
# need {'want'}
# locked {'lock'}
# customer {'client'}
# telephone {'phone'}
# locked {'lock'}
# got {'get'}
# phone {'telephone'}
# received {'receive'}
# received {'receive'}
# currently {'presently'}
# customer {'client'}
# telephone {'phone'}
# difficulty {'trouble'}
# assist {'help', 'assistance'}
# received {'receive'}
# hello {'hi'}
# trying {'try'}
# received {'receive'}
# hello {'hi'}
# make {'give'}
# best {'better', 'good'}
# getting {'get'}
# trying {'try'}
# attached {'attach'}
# section {'part'}
# engineering {'technology'}
# fixed {'fix'}
# costing {'cost'}
# received {'receive'}
# hi {'hello'}
# made {'make'}
# extended {'extend'}
# cost {'price'}
# think {'guess'}
# coming {'come'}
# component {'element'}
# need {'want'}
# best {'better', 'good'}
# locked {'lock'}
# opening {'open'}
# received {'receive'}
# got {'get'}
# someone {'somebody'}
# worked {'work'}
# impacted {'impact', 'affect'}
# client {'customer'}
# loading {'load'}
# received {'receive'}
# engineering {'technology'}
# received {'receive'}
# hello {'hi'}
# facing {'face'}
# need {'want'}
# hello {'hi'}
# problem {'trouble'}
# received {'receive'}
# attached {'attach'}
# locked {'lock'}
# received {'receive'}
# running {'run'}
# still {'even'}
# working {'work'}
# received {'receive'}
# days {'day'}
# yet {'even'}
# find {'discover'}
# checked {'check'}
# attached {'attach'}
# received {'receive'}
# added {'add'}
# received {'receive'}
# power {'force'}
# working {'work'}
# received {'receive'}
# simply {'just'}
# problem {'trouble'}
# space {'place'}
# received {'receive'}
# received {'receive'}
# hi {'hello'}
# need {'want'}
# consultant {'advisor'}
# finish {'end'}
# cost {'price'}
# center {'middle'}
# set {'put'}
# phone {'telephone'}
# received {'receive'}
# hi {'hello'}
# assistance {'assist', 'aid', 'help'}
# best {'better', 'good'}
# look {'see'}
# defective {'faulty'}
# graphics {'graphic'}
# engineering {'technology'}
# taking {'take'}
# showing {'show'}
# customer {'client'}
# telephone {'phone'}
# unlocked {'unlock'}
# best {'better', 'good'}
# create {'make'}
# provide {'offer'}
# used {'use'}
# received {'receive'}
# received {'receive'}
# good {'well'}
# assist {'help', 'assistance'}
# possibly {'perhaps'}
# power {'force'}
# data {'information'}
# image {'picture'}
# support {'supporting'}
# scanning {'scan'}
# problem {'trouble'}
# directly {'immediately', 'direct'}
# somebody {'someone'}
# charging {'charge'}
# power {'force'}
# adapter {'adaptor'}
# connected {'connect'}
# adapter {'adaptor'}
# adaptor {'adapter'}
# checked {'check'}
# still {'even'}
# tried {'try'}
# confirmed {'confirm'}
# resolved {'resolve'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# getting {'get'}
# balancing {'balance'}
# advised {'advise'}
# confirmed {'confirm'}
# resolved {'resolve'}
# received {'receive'}
# received {'receive'}
# customer {'client'}
# best {'better', 'good'}
# received {'receive'}
# customer {'client'}
# best {'better', 'good'}
# received {'receive'}
# provide {'offer'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# forward {'ahead'}
# received {'receive'}
# got {'get'}
# need {'want'}
# returned {'return'}
# received {'receive'}
# customer {'client'}
# telephone {'phone'}
# connected {'connect'}
# confirmed {'confirm'}
# repair {'fix'}
# taking {'take'}
# locked {'lock'}
# tell {'say'}
# received {'receive'}
# received {'receive'}
# image {'picture'}
# trying {'try'}
# hello {'hi'}
# hi {'hello'}
# need {'want'}
# switch {'switching'}
# received {'receive'}
# state {'country'}
# process {'procedure'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# power {'force'}
# start {'begin'}
# power {'force'}
# power {'force'}
# notified {'notify'}
# dialing {'dial'}
# working {'work'}
# global {'world'}
# additional {'extra'}
# power {'force'}
# power {'force'}
# start {'begin'}
# power {'force'}
# notified {'notify'}
# dialing {'dial'}
# working {'work'}
# ...
# disabled {'disable'}
# telephony {'telephone'}
# hi {'hello'}
# engineering {'technology'}
# received {'receive'}
# assigned {'assign'}
# tried {'try'}
# usually {'normally'}
# tell {'say'}
# engineering {'technology'}
# told {'tell'}
# display {'showing'}
# setting {'set'}
# drawing {'draw'}
# printed {'print'}
# still {'even'}
# connected {'connect'}
# getting {'get'}
# saved {'save'}
# sent {'send'}
# seen {'see'}
# client {'customer'}
# hi {'hello'}
# drawing {'draw'}
# client {'customer'}
# total {'amount'}
# defective {'faulty'}
# got {'get'}
# data {'information'}
# process {'procedure'}
# found {'find'}
# working {'work'}
# locked {'lock'}
# hear {'listen'}
# received {'receive'}
# find {'discover'}
# need {'want'}
# higher {'high'}
# hello {'hi'}
# working {'work'}
# support {'supporting'}
# higher {'high'}
# provide {'offer'}
# protection {'security'}
# data {'information'}
# installation {'installing'}
# locked {'lock'}
# defective {'faulty'}
# image {'picture'}
# hello {'hi'}
# effective {'efficient'}
# view {'see'}
# effective {'efficient'}
# view {'see'}
# received {'receive'}
# hello {'hi'}
# find {'discover'}
# displayed {'display'}
# received {'receive'}
# kind {'sort'}
# showing {'show'}
# power {'force'}
# start {'begin'}
# power {'force'}
# power {'force'}
# dialing {'dial'}
# working {'work'}
# global {'world'}
# additional {'extra'}
# notification {'notice'}
# hi {'hello'}
# received {'receive'}
# notification {'notice'}
# sent {'send'}
# view {'see'}
# prompt {'immediate'}
# look {'looking'}
# closed {'shut'}
# installation {'installing'}
# prompt {'immediate'}
# running {'run'}
# saved {'save'}
# received {'receive'}
# hello {'hi'}
# best {'better', 'good'}
# customer {'client'}
# telephone {'phone'}
# setting {'set'}
# customer {'client'}
# received {'receive'}
# find {'discover'}
# connected {'connect'}
# set {'put'}
# sort {'kind'}
# routing {'route'}
# support {'supporting'}
# fixed {'fix'}
# locked {'lock'}
# received {'receive'}
# received {'receive'}
# need {'want'}
# locked {'lock'}
# needs {'need'}
# working {'work'}
# getting {'get'}
# authorized {'authorize'}
# ticketing {'ticket'}
# provide {'offer'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# need {'want'}
# customer {'client'}
# telephone {'phone'}
# locked {'lock'}
# running {'run'}
# longer {'long'}
# received {'receive'}
# need {'want'}
# good {'well'}
# take {'get', 'make'}
# assist {'help'}
# kind {'sort'}
# inquiry {'enquiry'}
# shop {'store'}
# locked {'lock'}
# received {'receive'}
# received {'receive'}
# showing {'show'}
# process {'procedure'}
# running {'run'}
# appear {'seem'}
# showing {'show'}
# causing {'cause'}
# quote {'quotation'}
# received {'receive'}
# assistance {'assist', 'aid', 'help'}
# received {'receive'}
# causing {'cause'}
# process {'procedure'}
# needs {'need'}
# customer {'client'}
# telephone {'phone'}
# assigned {'assign'}
# running {'run'}
# longer {'long'}
# received {'receive'}
# publication {'issue'}
# assist {'help', 'assistance'}
# keeping {'keep'}
# logged {'log'}
# lab {'laboratory'}
# hello {'hi'}
# effective {'efficient'}
# view {'see'}
# working {'work'}
# working {'work'}
# trouble {'problem', 'worry'}
# customer {'client'}
# telephone {'phone'}
# trying {'try'}
# still {'even'}
# sitting {'sit'}
# coming {'come'}
# received {'receive'}
# someone {'somebody'}
# fix {'fixing'}
# client {'customer'}
# customer {'client'}
# telephone {'phone'}
# still {'even'}
# loading {'load'}
# net {'profit'}
# applied {'apply'}
# locked {'lock'}
# engineering {'technology'}
# customer {'client'}
# engineering {'technology'}
# hear {'listen'}
# audio {'sound'}
# locking {'lock'}
# giving {'give'}
# problem {'trouble'}
# times {'time'}
# working {'work'}
# received {'receive'}
# sent {'send'}
# blocked {'block'}
# need {'want'}
# take {'get', 'make'}
# used {'use'}
# special {'limited'}
# currently {'presently'}
# beginning {'begin'}
# moving {'move'}
# forward {'ahead'}
# providing {'provide'}
# found {'find'}
# ticketing {'ticket'}
# global {'world'}
# support {'supporting'}
# center {'middle'}
# procedure {'process'}
# provided {'provide'}
# process {'procedure'}
# procedure {'process'}
# model {'modeling', 'example'}
# os {'o'}
# state {'country'}
# state {'country'}
# sent {'send'}
# needs {'need'}
# working {'work'}
# getting {'get'}
# authorized {'authorize'}
# ticketing {'ticket'}
# provide {'offer'}
# phone {'telephone'}
# hello {'hi'}
# logging {'log'}
# certificate {'credential'}
# received {'receive'}
# hello {'hi'}
# facing {'face'}
# look {'looking'}
# locked {'lock'}
# set {'put'}
# getting {'get'}
# find {'discover'}
# logging {'log'}
# hello {'hi'}
# price {'cost'}
# amount {'quantity'}
# received {'receive'}
# needs {'need'}
# forward {'ahead'}
# locked {'lock'}
# charging {'charge'}
# checked {'check'}
# still {'even'}
# locked {'lock'}
# instead {'rather'}
# directly {'immediately', 'direct'}
# getting {'get'}
# make {'give'}
# running {'run'}
# shipping {'ship'}
# used {'use'}
# loading {'load'}
# power {'force'}
# start {'begin'}
# power {'force'}
# power {'force'}
# notified {'notify'}
# dialing {'dial'}
# working {'work'}
# global {'world'}
# additional {'extra'}
# installation {'installing'}
# client {'customer'}
# need {'want'}
# enquiry {'inquiry'}
# recording {'record'}
# working {'work'}
# running {'run'}
# home {'house'}
# quick {'fast'}
# impacted {'impact', 'affect'}
# times {'time'}
# working {'work'}
# taken {'take'}
# instead {'rather'}
# logged {'log'}
# directly {'immediately', 'direct'}
# tried {'try'}
# logging {'log'}
# center {'middle'}
# option {'choice'}
# choose {'select'}
# hi {'hello'}
# defective {'faulty'}
# trying {'try'}
# received {'receive'}
# hi {'hello'}
# customer {'client'}
# telephone {'phone'}
# incorrect {'wrong'}
# received {'receive'}
# attached {'attach'}
# taking {'take'}
# working {'work'}
# think {'guess'}
# need {'want'}
# received {'receive'}
# controller {'control'}
# received {'receive'}
# hi {'hello'}
# look {'see'}
# snap {'grab'}
# best {'better', 'good'}
# working {'work'}
# received {'receive'}
# received {'receive'}
# problem {'trouble'}
# hello {'hi'}
# measurement {'measuring'}
# best {'better', 'good'}
# problem {'trouble'}
# received {'receive'}
# measurement {'measuring'}
# best {'better', 'good'}
# received {'receive'}
# hi {'hello'}
# visiting {'visit'}
# received {'receive'}
# hello {'hi'}
# working {'work'}
# working {'work'}
# hello {'hi'}
# center {'middle'}
# used {'use'}
# global {'world'}
# ensure {'insure'}
# ticketing {'ticket'}
# closed {'close', 'shut'}
# instead {'rather'}
# option {'choice'}
# needs {'need'}
# received {'receive'}
# met {'meet'}
# sending {'send'}
# hi {'hello'}
# daily {'everyday'}
# example {'instance'}
# attached {'attach'}
# daily {'everyday'}
# note {'notice', 'mention'}
# sent {'send'}
# instead {'rather'}
# times {'time'}
# higher {'high'}
# look {'see'}
# need {'want'}
# received {'receive'}
# hi {'hello'}
# used {'use'}
# audio {'sound'}
# working {'work'}
# drawing {'draw'}
# working {'work'}
# model {'modeling', 'example'}
# customer {'client'}
# affected {'affect'}
# received {'receive'}
# attached {'attach'}
# best {'better', 'good'}
# received {'receive'}
# needs {'need'}
# links {'link'}
# hello {'hi'}
# topic {'subject'}
# received {'receive'}
# yet {'even'}
# kind {'sort'}
# communication {'communicating'}
# protection {'security'}
# posted {'post'}
# subject {'topic'}
# select {'choose'}
# go {'get'}
# data {'information'}
# attached {'attach'}
# tried {'try'}
# times {'time'}
# locked {'lock'}
# hi {'hello'}
# assist {'help', 'assistance'}
# create {'make'}
# authorized {'authorize'}
# received {'receive'}
# taking {'take'}
# received {'receive'}
# telephone {'phone'}
# defective {'faulty'}
# opening {'open'}
# hi {'hello'}
# opening {'open'}
# sent {'send'}
# good {'well'}
# received {'receive'}
# tried {'try'}
# need {'want'}
# lost {'lose'}
# locked {'lock'}
# resolution {'resolve'}
# problem {'trouble'}
# set {'put'}
# need {'want'}
# repair {'fix'}
# net {'profit'}
# received {'receive'}
# showing {'show'}
# customer {'client'}
# telephone {'phone'}
# locked {'lock'}
# received {'receive'}
# locked {'lock'}
# find {'discover'}
# received {'receive'}
# solve {'resolve'}
# locked {'lock'}
# locked {'lock'}
# heating {'heat'}
# audio {'sound'}
# working {'work'}
# effective {'efficient'}
# view {'see'}
# indicate {'suggest'}
# certificate {'credential'}
# used {'use'}
# engineering {'technology'}
# make {'give'}
# transferred {'transfer'}
# data {'information'}
# found {'find'}
# locked {'lock'}
# locked {'lock'}
# hi {'hello'}
# best {'better', 'good'}
# checked {'check'}
# advised {'advise'}
# confirmed {'confirm'}
# resolved {'resolve'}
# power {'force'}
# start {'begin'}
# power {'force'}
# power {'force'}
# notified {'notify'}
# dialing {'dial'}
# working {'work'}
# global {'world'}
# additional {'extra'}
# received {'receive'}
# power {'force'}
# start {'begin'}
# power {'force'}
# power {'force'}
# notified {'notify'}
# dialing {'dial'}
# working {'work'}
# global {'world'}
# additional {'extra'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# process {'procedure'}
# found {'find'}
# process {'procedure'}
# found {'find'}
# received {'receive'}
# process {'procedure'}
# found {'find'}
# received {'receive'}
# vacation {'holiday'}
# still {'even'}
# old {'older'}
# usually {'normally'}
# needs {'need'}
# failing {'fail'}
# sent {'send'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# start {'beginning', 'starting'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# connected {'connect'}
# look {'see'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# locked {'lock'}
# need {'want'}
# analyses {'analysis'}
# attached {'attach'}
# received {'receive'}
# power {'force'}
# start {'begin'}
# power {'force'}
# power {'force'}
# dialing {'dial'}
# working {'work'}
# global {'world'}
# global {'world'}
# additional {'extra'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# received {'receive'}
# connected {'connect'}
# best {'better', 'good'}
# received {'receive'}
# make {'give'}
# alarm {'alert'}
# warning {'warn'}
# need {'want'}
# received {'receive'}
# inquiry {'enquiry'}
# phone {'telephone'}
# need {'want'}
# inquiry {'enquiry'}
# received {'receive'}
# need {'want'}
# sent {'send'}
# look {'see'}
# received {'receive'}
# sent {'send'}
# tried {'try'}
# phone {'telephone'}
# hello {'hi'}
# data {'information'}
# old {'older'}
# ensure {'insure'}
# removed {'remove'}
# ticketing {'ticket'}
# section {'part'}
# left {'leave'}
# hi {'hello'}
# writing {'write'}
# forward {'ahead'}
# ensure {'insure'}
# closed {'close', 'shut'}
# holiday {'vacation'}
# best {'better', 'good'}
# provide {'offer'}
# start {'begin'}
# model {'modeling', 'example'}
# working {'work'}
# attached {'attach'}
# need {'want'}
# produce {'create', 'make'}
# received {'receive'}
# getting {'get'}
# trying {'try'}
# need {'want'}
# cost {'price'}
# center {'middle'}
# still {'even'}
# cost {'price'}
# blocked {'block'}
# engineering {'technology'}
# customer {'client'}
# telephone {'phone'}
# received {'receive'}
# center {'middle'}
# received {'receive'}
# keeping {'keep'}
# led {'lead'}
# flashing {'flash'}
# icon {'image'}
# need {'want'}
# received {'receive'}
# someone {'somebody'}
# works {'work'}
# phone {'telephone'}
# hello {'hi'}
# locked {'lock'}
# need {'want'}
# need {'want'}
# believe {'think'}
# need {'want'}
# sent {'send'}
# determined {'determine'}
# want {'need'}
# sent {'send'}
# reply {'answer'}
# phone {'telephone'}
# problem {'trouble'}
# attached {'attach'}
# resolve {'solve'}
# locked {'lock'}
# option {'choice'}
# working {'work'}
# locked {'lock'}
# certificate {'credential'}
# found {'find'}
# got {'get'}
# talking {'talk'}
# detailed {'detail'}
# class {'course'}
# branded {'brand'}
# state {'country'}
# telephone {'phone'}
# going {'go'}
# need {'want'}
# hence {'thus', 'therefore'}
# fix {'fixing'}
# received {'receive'}
# working {'work'}
# data {'information'}
# trying {'try'}
# find {'discover'}
# attached {'attach'}
# certificate {'credential'}
# giving {'give'}
# showing {'show'}
# controller {'control'}
# received {'receive'}
# alarm {'alert'}
# find {'discover'}
# pass {'passing'}
# received {'receive'}
# locked {'lock'}
# sent {'send'}
# corrected {'correct'}
# security {'protection'}
# travel {'traveling'}
# received {'receive'}
# give {'make'}
# kind {'sort'}
# received {'receive'}
# hello {'hi'}
# recognize {'realize'}
# usage {'utilization', 'use'}
# find {'discover'}
# start {'beginning', 'starting'}
# problem {'trouble'}
# look {'looking'}
# lobby {'hall'}
# working {'work'}
# received {'receive'}
# looking {'look'}
# picture {'pic', 'image', 'photo'}
# perhaps {'possibly'}
# sent {'send'}
# someone {'somebody'}
# look {'looking'}
# dynamics {'dynamic'}
# center {'middle'}
# used {'use'}
# global {'world'}
# support {'supporting'}
# ensure {'insure'}
# disconnected {'disconnect'}
# received {'receive'}
# good {'well'}
# loading {'load'}
# flash {'flashing'}
# received {'receive'}
# good {'well'}
# incorrect {'wrong'}
# phone {'telephone'}
# defective {'faulty'}
# defective {'faulty'}
# longer {'long'}
# defective {'faulty'}
# received {'receive'}
# received {'receive'}
# registered {'register'}
# need {'want'}
# showing {'show'}
# loaded {'load'}
# running {'run'}
# failing {'fail'}
# logging {'log'}
# getting {'get'}
# security {'protection'}
# process {'procedure'}
# found {'find'}
# problem {'trouble'}
# customer {'client'}
# find {'discover'}
# included {'include'}
# list {'listing'}
# attached {'attach'}
# working {'work'}
# received {'receive'}
# working {'work'}
# need {'want'}
# best {'better', 'good'}
# received {'receive'}
# telephony {'telephone'}
# pressing {'press', 'push'}
# calling {'call'}
# phone {'telephone'}
# losing {'lose'}
# facing {'face'}
# old {'older'}
# loading {'load'}
# received {'receive'}
# null {'nil'}
# revision {'revise'}
# pressing {'press', 'push'}
# directly {'immediately', 'direct'}
# running {'run'}
# saved {'save'}
# extended {'extend'}
# generating {'generate'}
# working {'work'}
# instead {'rather'}
# printed {'print'}
# set {'put'}
# working {'work'}
# received {'receive'}
# moving {'move'}
# got {'get'}
# telephony {'telephone'}
# trying {'try'}
# loaded {'load'}
# model {'modeling', 'example'}
# mill {'factory'}
# model {'modeling', 'example'}
# model {'modeling', 'example'}
# coming {'come'}
# working {'work'}
# directly {'immediately', 'direct'}
# received {'receive'}
# finished {'finish'}
# start {'beginning', 'starting'}
# process {'procedure'}
# received {'receive'}
# hello {'hi'}
# best {'better', 'good'}
# received {'receive'}
# client {'customer'}
# blocked {'block'}
# sent {'send'}
# hello {'hi'}
# facing {'face'}
# opening {'open'}
# blocked {'block'}
# amount {'quantity'}
# make {'give'}
# hi {'hello'}
# best {'better', 'good'}
# loaded {'load'}
# higher {'high'}
# locked {'lock'}
# assigned {'assign'}
# generating {'generate'}
# sending {'send'}
# received {'receive'}
# received {'receive'}
# hello {'hi'}
# received {'receive'}
# connected {'connect'}
# forward {'ahead'}
# received {'receive'}
# hi {'hello'}
# unblock {'unfreeze'}
# blocked {'block'}
# unblock {'unfreeze'}
# added {'add'}
# route {'path', 'road'}
# additional {'extra'}
# attached {'attach'}
# customer {'client'}
# list {'listing'}
# ticketing {'ticket'}
# global {'world'}
# sent {'send'}
# good {'well'}
# assist {'help', 'assistance'}
# kind {'sort'}
# freezing {'freeze'}
# inquiry {'enquiry'}
# received {'receive'}
# best {'better', 'good'}
# received {'receive'}
# additional {'extra'}
# still {'even'}
# showing {'show'}
# working {'work'}
# hour {'minute'}
# coming {'come'}
# customer {'client'}
# enhanced {'enhance'}
# received {'receive'}
# made {'make'}
# view {'see'}
# customer {'client'}
# going {'go'}
# forward {'ahead'}
# currently {'presently'}
# modify {'change'}
# enhanced {'enhance'}
# used {'use'}
# best {'better', 'good'}
# received {'receive'}
# going {'go'}
# logged {'log'}
# assist {'help', 'assistance'}
# getting {'get'}
# suspicious {'suspect'}
# sort {'kind'}
# idea {'thought'}
# sending {'send'}
# best {'better', 'good'}
# telephony {'telephone'}
# received {'receive'}
# security {'protection'}
# ran {'run'}
# used {'use'}
# still {'even'}
# repair {'fix'}
# net {'profit'}
# need {'want'}
# checked {'check'}
# client {'customer'}
# cost {'price'}
# center {'middle'}
# customer {'client'}
# telephone {'phone'}
# locked {'lock'}
# view {'see'}
# told {'tell'}
# received {'receive'}
# need {'want'}
# engineering {'technology'}
# option {'choice'}
# added {'add'}
# need {'want'}
# added {'add'}
# problem {'trouble'}
# someone {'somebody'}
# needs {'need'}
# coming {'come'}
# received {'receive'}
# good {'well'}
# sent {'send'}
# telephony {'telephone'}
# working {'work'}
# finish {'finishing'}
# Key error
# adjustment
# Key error
# accommodation
# Key error
# fitting
# Key error
# alteration
# Key error
# modification
# Key error
# adjustment
# Key error
# adjustment
# Key error
# registration
# Key error
# readjustment
# Key error
# adaptation
# Key error
# adaption
# Key error
# adjustment
# Key error
# allowance
# Key error
# adjustment

# %%
synonymX
# Out:
# {'checked': ['check'],
#  'advised': ['advise'],
#  'confirmed': ['confirm'],
#  'resolved': ['resolve'],
#  'received': ['receive'],
#  'hello': ['hi'],
#  'kind': ['sort'],
#  'hi': ['hello'],
#  'best': ['better', 'good'],
#  'engineering': ['technology'],
#  'connected': ['connect'],
#  'trying': ['try'],
#  'working': ['work'],
#  'home': ['house'],
#  'unlocking': ['unlock'],
#  'locked': ['lock'],
#  'getting': ['get'],
#  'need': ['want'],
#  'dynamics': ['dynamic'],
#  'regarding': ['regard'],
#  'phone': ['telephone'],
#  'client': ['customer'],
#  'duplication': ['duplicate'],
#  'gentle': ['soft'],
#  'display': ['showing'],
#  'assigned': ['assign'],
#  'set': ['put'],
#  'corrected': ['correct'],
#  'flash': ['flashing'],
#  'resolve': ['solve'],
#  'needs': ['need'],
#  'days': ['day'],
#  'taken': ['take'],
#  'printed': ['print'],
#  'picked': ['pick'],
#  'daily': ['everyday'],
#  'telephony': ['telephone'],
#  'global': ['world'],
#  'kept': ['keep'],
#  'locking': ['lock'],
#  'incorrect': ['wrong'],
#  'meeting': ['meet'],
#  'good': ['well'],
#  'lost': ['lose'],
#  'option': ['choice'],
#  'setting': ['set'],
#  'recall': ['remember'],
#  'enquiry': ['inquiry'],
#  'tried': ['try'],
#  'unlocked': ['unlock'],
#  'entry': ['entering'],
#  'disconnected': ['disconnect'],
#  'power': ['force'],
#  'start': ['beginning', 'starting'],
#  'notified': ['notify'],
#  'dialing': ['dial'],
#  'additional': ['extra'],
#  'logging': ['log'],
#  'works': ['work'],
#  'drawing': ['draw'],
#  'shown': ['indicate'],
#  'showing': ['show'],
#  'process': ['procedure'],
#  'problem': ['trouble'],
#  'fixed': ['fix'],
#  'space': ['place'],
#  'view': ['see'],
#  'expiry': ['expiration'],
#  'want': ['need'],
#  'expiring': ['expire'],
#  'sent': ['send'],
#  'contents': ['content'],
#  'displayed': ['display'],
#  'stays': ['stay'],
#  'support': ['supporting'],
#  'fix': ['fixing'],
#  'freezing': ['freeze'],
#  'said': ['say'],
#  'roll': ['rolling'],
#  'blocked': ['block'],
#  'told': ['tell'],
#  'got': ['get'],
#  'ensure': ['insure'],
#  'loaded': ['load'],
#  'list': ['listing'],
#  'customer': ['client'],
#  'finishing': ['finish'],
#  'starting': ['begin', 'start'],
#  'select': ['choose'],
#  'roughing': ['rough'],
#  'times': ['time'],
#  'person': ['someone'],
#  'cause': ['reason'],
#  'take': ['get', 'make'],
#  'taking': ['take'],
#  'scrapped': ['scrap'],
#  'old': ['older'],
#  'attached': ['attach'],
#  'extracted': ['extract'],
#  'made': ['make'],
#  'trouble': ['problem', 'worry'],
#  'assist': ['help', 'assistance'],
#  'used': ['use'],
#  'controller': ['control'],
#  'disabled': ['disable'],
#  'find': ['discover'],
#  'target': ['aim'],
#  'note': ['notice', 'mention'],
#  'happening': ['happen'],
#  'wasted': ['waste'],
#  'currently': ['presently'],
#  'utilization': ['usage'],
#  'observing': ['observe'],
#  'finally': ['eventually'],
#  'rather': ['instead'],
#  'added': ['add'],
#  'licensed': ['license'],
#  'vacation': ['holiday'],
#  'requirement': ['prerequisite', 'necessary'],
#  'security': ['protection'],
#  'reply': ['answer'],
#  'require': ['need'],
#  'center': ['middle'],
#  'ticketing': ['ticket'],
#  'license': ['permit', 'permission'],
#  'mail': ['send'],
#  'data': ['information'],
#  'travel': ['traveling'],
#  'shipment': ['consignment'],
#  'notification': ['notice'],
#  'copied': ['copy'],
#  'appear': ['seem'],
#  'advisor': ['consultant'],
#  'telephone': ['phone'],
#  'map': ['mapping'],
#  'grinding': ['grind'],
#  'consignment': ['shipment'],
#  'rectified': ['rectify'],
#  'sending': ['send'],
#  'someone': ['somebody'],
#  'look': ['looking'],
#  'affecting': ['impact', 'affect'],
#  'paying': ['pay'],
#  'section': ['part'],
#  'tell': ['say'],
#  'certificate': ['credential'],
#  'yet': ['even'],
#  'worked': ['work'],
#  'still': ['even'],
#  'expiration': ['expiry'],
#  'house': ['home'],
#  'returned': ['return'],
#  'provide': ['offer'],
#  'make': ['give'],
#  'model': ['modeling', 'example'],
#  'printing': ['print'],
#  'respond': ['answer'],
#  'accepted': ['accept'],
#  'balancing': ['balance'],
#  'extend': ['expand'],
#  'source': ['reference'],
#  'synchronized': ['sync'],
#  'effective': ['efficient'],
#  'longer': ['long'],
#  'seen': ['see'],
#  'path': ['route', 'way'],
#  'becomes': ['become'],
#  'create': ['make'],
#  'resolution': ['resolve'],
#  'installation': ['installing'],
#  'running': ['run'],
#  'technology': ['engineering'],
#  'price': ['cost'],
#  'going': ['go'],
#  'especially': ['particularly'],
#  'provided': ['provide'],
#  'technologist': ['engineer'],
#  'opening': ['open'],
#  'small': ['little'],
#  'permission': ['permit'],
#  'severe': ['serious'],
#  'talk': ['talking'],
#  'causing': ['cause'],
#  'entering': ['enter'],
#  'met': ['meet'],
#  'load': ['loading'],
#  'ordered': ['order'],
#  'shop': ['store'],
#  'selected': ['select'],
#  'saved': ['save'],
#  'removed': ['remove'],
#  'cost': ['price'],
#  'faced': ['face'],
#  'inquiry': ['enquiry'],
#  'stack': ['heap'],
#  'repair': ['fix'],
#  'president': ['chairman'],
#  'go': ['get'],
#  'amount': ['quantity'],
#  'transferred': ['transfer'],
#  'removing': ['remove'],
#  'repeated': ['repeat'],
#  'colleague': ['fellow'],
#  'fully': ['full'],
#  'affected': ['affect'],
#  'respect': ['regard'],
#  'primary': ['main'],
#  'seeing': ['see'],
#  'involved': ['involve'],
#  'links': ['link'],
#  'charging': ['charge'],
#  'saving': ['save'],
#  'communication': ['communicating'],
#  'logged': ['log'],
#  'give': ['make'],
#  'subject': ['topic'],
#  'left': ['leave'],
#  'protection': ['security'],
#  'selection': ['choice'],
#  'filtering': ['filter'],
#  'extended': ['extend'],
#  'instead': ['rather'],
#  'example': ['instance'],
#  'determined': ['determine'],
#  'topic': ['subject'],
#  'assume': ['presume'],
#  'listed': ['list'],
#  'assistance': ['assist', 'aid', 'help'],
#  'calculating': ['calculate'],
#  'exploring': ['explore'],
#  'disruption': ['disturbance', 'interruption'],
#  'begin': ['start'],
#  'supply': ['provide'],
#  'hour': ['minute'],
#  'coming': ['come'],
#  'mean': ['think'],
#  'facing': ['face'],
#  'investigating': ['investigate'],
#  'involve': ['require'],
#  'fixing': ['fix'],
#  'block': ['blocking'],
#  'fill': ['filling'],
#  'saying': ['say'],
#  'found': ['find'],
#  'switching': ['switch', 'alternate'],
#  'net': ['profit'],
#  'press': ['pressing'],
#  'car': ['auto'],
#  'transportation': ['transit', 'transport'],
#  'approximately': ['around'],
#  'normally': ['usually'],
#  'defective': ['faulty'],
#  'routing': ['route'],
#  'program': ['plan'],
#  'closed': ['close', 'shut'],
#  'guess': ['think', 'suppose'],
#  'timed': ['time'],
#  'interruption': ['disruption'],
#  'operational': ['operating'],
#  'keeping': ['keep'],
#  'resulting': ['result'],
#  'flashing': ['flash'],
#  'perhaps': ['possibly'],
#  'refusing': ['deny'],
#  'files': ['file'],
#  'buttons': ['button'],
#  'region': ['area'],
#  'lead': ['leading'],
#  'searching': ['search'],
#  'included': ['include'],
#  'thought': ['think'],
#  'experienced': ['experience'],
#  'quantity': ['amount'],
#  'posted': ['post'],
#  'frozen': ['freeze'],
#  'calling': ['call'],
#  'shift': ['change'],
#  'looking': ['look'],
#  'defense': ['defence'],
#  'measuring': ['quantify'],
#  'raised': ['raise'],
#  'impacted': ['impact', 'affect'],
#  'reaching': ['reach'],
#  'boots': ['boot'],
#  'various': ['several'],
#  'fulfill': ['satisfy', 'accomplish'],
#  'fast': ['quick'],
#  'worse': ['bad'],
#  'older': ['old'],
#  'aborted': ['abort'],
#  'portion': ['part'],
#  'believe': ['think'],
#  'corrupt': ['corrupted'],
#  'ran': ['run'],
#  'quick': ['fast'],
#  'really': ['actually'],
#  'laid': ['put'],
#  'almost': ['nearly'],
#  'leaves': ['leave'],
#  'special': ['limited'],
#  'thus': ['therefore', 'hence'],
#  'usually': ['normally'],
#  'filled': ['fill'],
#  'profit': ['earnings'],
#  'procedure': ['process'],
#  'warning': ['warn'],
#  'completely': ['totally'],
#  'class': ['course'],
#  'eventually': ['finally'],
#  'authorized': ['authorize'],
#  'attempt': ['effort', 'try'],
#  'satisfied': ['satisfy'],
#  'building': ['construction'],
#  'extra': ['additional'],
#  'directly': ['immediately', 'direct'],
#  'solve': ['resolve'],
#  'higher': ['high'],
#  'quotation': ['quote'],
#  'adapter': ['adaptor'],
#  'thrown': ['throw'],
#  'making': ['make'],
#  'loading': ['load'],
#  'shutting': ['shut'],
#  'buy': ['purchase'],
#  'leaving': ['leave'],
#  'light': ['lighter'],
#  'gray': ['grey'],
#  'built': ['build'],
#  'often': ['frequently'],
#  'stocks': ['stock'],
#  'quote': ['quotation'],
#  'established': ['establish'],
#  'switched': ['switch'],
#  'moving': ['move'],
#  'corrupted': ['corrupt'],
#  'suspected': ['suspect'],
#  'instance': ['example'],
#  'concerned': ['concern'],
#  'shipped': ['ship'],
#  'picture': ['pic', 'image', 'photo'],
#  'giving': ['give'],
#  'forward': ['ahead'],
#  'scanning': ['scan'],
#  'handling': ['handle'],
#  'extremely': ['highly'],
#  'video': ['picture'],
#  'icon': ['image'],
#  'brought': ['bring'],
#  'waiting': ['wait'],
#  'greeting': ['greet'],
#  'registered': ['register'],
#  'men': ['man'],
#  'informed': ['inform'],
#  'route': ['path', 'road'],
#  'las': ['la'],
#  'remember': ['think'],
#  'audio': ['sound'],
#  'heap': ['stack'],
#  'luck': ['chance'],
#  'edit': ['delete'],
#  'alarm': ['alert'],
#  'difficulty': ['trouble'],
#  'costing': ['cost'],
#  'think': ['guess'],
#  'component': ['element'],
#  'simply': ['just'],
#  'consultant': ['advisor'],
#  'finish': ['finishing'],
#  'graphics': ['graphic'],
#  'possibly': ['perhaps'],
#  'image': ['picture'],
#  'somebody': ['someone'],
#  'adaptor': ['adapter'],
#  'switch': ['switching'],
#  'state': ['country'],
#  'seeking': ['seek'],
#  'pass': ['passing'],
#  'sitting': ['sit'],
#  'os': ['o'],
#  'salary': ['pay'],
#  'hint': ['suggestion', 'clue'],
#  'specify': ['assign'],
#  'understand': ['realize'],
#  'collect': ['gather'],
#  'await': ['expect'],
#  'written': ['write'],
#  'freight': ['shipment'],
#  'applied': ['apply'],
#  'hear': ['listen'],
#  'assuming': ['assume', 'presume'],
#  'improve': ['better'],
#  'late': ['later'],
#  'quarter': ['fourth'],
#  'browse': ['browsing'],
#  'faulty': ['defective', 'incorrect'],
#  'frequently': ['often'],
#  'writer': ['author'],
#  'carried': ['carry'],
#  'run': ['running'],
#  'blocking': ['block'],
#  'finished': ['finish'],
#  'large': ['big'],
#  'turns': ['turn'],
#  'regardless': ['irrespective'],
#  'begun': ['begin'],
#  'recognize': ['realize'],
#  'failing': ['fail'],
#  'limit': ['limitation'],
#  'revision': ['revise'],
#  'ranging': ['range'],
#  'later': ['after'],
#  'latest': ['recent'],
#  'tier': ['level'],
#  'incorrectly': ['wrongly'],
#  'totally': ['completely'],
#  'construction': ['building'],
#  'losing': ['lose'],
#  'shipping': ['ship'],
#  'spoke': ['speak'],
#  'turn': ['turning'],
#  'safety': ['safe'],
#  'reduced': ['reduce'],
#  'linking': ['link'],
#  'rack': ['stand'],
#  'chassis': ['frame'],
#  'wait': ['waiting'],
#  'reach': ['reaching'],
#  'linked': ['link'],
#  'pro': ['professional'],
#  'speak': ['talk'],
#  'prerequisite': ['requirement'],
#  'choose': ['select'],
#  'away': ['out', 'off'],
#  'build': ['construct'],
#  'genuine': ['true'],
#  'pointing': ['point'],
#  'wrongly': ['incorrectly'],
#  'terminal': ['end'],
#  'bend': ['turn'],
#  'trade': ['deal'],
#  'min': ['minute'],
#  'gram': ['g'],
#  'priced': ['price'],
#  'tables': ['table'],
#  'better': ['good'],
#  'assign': ['specify'],
#  'scrolled': ['scroll'],
#  'nearly': ['almost'],
#  'laboratory': ['lab'],
#  'transport': ['transportation'],
#  'stream': ['flow'],
#  'watching': ['watch'],
#  'replicated': ['duplicate', 'replicate'],
#  'comparison': ['compare'],
#  'impact': ['affect'],
#  'lots': ['lot'],
#  'alloy': ['metal'],
#  'disturbance': ['disruption'],
#  'face': ['look'],
#  'potential': ['possible'],
#  'offer': ['provide'],
#  'telling': ['tell'],
#  'pool': ['pond'],
#  'newly': ['new'],
#  'auto': ['car'],
#  'designed': ['design'],
#  'receipts': ['receipt'],
#  'anyway': ['anyways'],
#  'highly': ['extremely'],
#  'fellow': ['colleague'],
#  'actually': ['really'],
#  'reps': ['rep'],
#  'minute': ['hour'],
#  'reflected': ['reflect'],
#  'disconnect': ['disconnection'],
#  'accept': ['assume'],
#  'kingdom': ['realm'],
#  'privileged': ['privilege'],
#  'finding': ['find'],
#  'separating': ['separate'],
#  'force': ['push'],
#  'supporting': ['support'],
#  'bigger': ['big'],
#  'therefore': ['thus', 'hence'],
#  'secure': ['safe'],
#  'filling': ['fill'],
#  'operating': ['operate'],
#  'modify': ['change'],
#  'sticks': ['stick'],
#  'posting': ['post'],
#  'road': ['route'],
#  'store': ['shop'],
#  'disconnection': ['disconnect'],
#  'shot': ['hit'],
#  'graded': ['grade'],
#  'lower': ['low'],
#  'needing': ['need'],
#  'aid': ['assist', 'help', 'assistance'],
#  'corp': ['corporation'],
#  'beginning': ['begin'],
#  'providing': ['provide'],
#  'prompt': ['immediate'],
#  'clock': ['time'],
#  'browsing': ['browse'],
#  'mill': ['factory'],
#  'converted': ['convert'],
#  'pressing': ['press', 'push'],
#  'element': ['component'],
#  'executed': ['execute'],
#  'indexed': ['index'],
#  'cutting': ['cut'],
#  'ways': ['way'],
#  'proceeding': ['proceed'],
#  'traveling': ['travel', 'trip'],
#  'disconnecting': ['disconnect'],
#  'credential': ['certificate'],
#  'suspicious': ['suspect'],
#  'divide': ['split'],
#  'dividing': ['divide'],
#  'defence': ['defense'],
#  'unblock': ['unfreeze'],
#  'faster': ['fast'],
#  'transferring': ['transfer'],
#  'confirming': ['confirm'],
#  'partially': ['partly'],
#  'converting': ['convert'],
#  'pair': ['couple'],
#  'throwing': ['throw'],
#  'accurate': ['exact'],
#  'dab': ['splash'],
#  'grey': ['gray'],
#  'shopping': ['shop'],
#  'reverse': ['turn'],
#  'affect': ['impact'],
#  'effort': ['attempt'],
#  'preserve': ['maintain'],
#  'earth': ['world'],
#  'chosen': ['choose'],
#  'fault': ['mistake'],
#  'cleanup': ['cleaning'],
#  'movement': ['move'],
#  'probable': ['likely'],
#  'rolling': ['roll'],
#  'campaign': ['effort'],
#  'execute': ['accomplish'],
#  'becoming': ['become'],
#  'stopping': ['stop'],
#  'pond': ['pool'],
#  'wanting': ['want'],
#  'handled': ['handle'],
#  'leading': ['lead'],
#  'optical': ['optic'],
#  'nevertheless': ['however'],
#  'lagging': ['lag'],
#  'particularly': ['especially'],
#  'mornings': ['morning'],
#  'replicate': ['duplicate'],
#  'bases': ['base'],
#  'permit': ['allow'],
#  'helping': ['assist', 'help'],
#  'total': ['amount'],
#  'dropping': ['drop'],
#  'realize': ['understand'],
#  'smart': ['wise'],
#  'speaking': ['speak'],
#  'thick': ['deep'],
#  'generating': ['generate'],
#  'powered': ['power'],
#  'pic': ['picture', 'photo'],
#  'shortly': ['soon'],
#  'talking': ['talk'],
#  'effects': ['effect'],
#  'transit': ['transportation'],
#  'apply': ['use'],
#  'indicate': ['suggest'],
#  'purchase': ['buy'],
#  'compare': ['comparison'],
#  'carry': ['hold'],
#  'respective': ['various'],
#  'idea': ['thought'],
#  'theme': ['idea'],
#  'recording': ['record'],
#  'lab': ['laboratory'],
#  'matching': ['match'],
#  'occur': ['happen'],
#  'passing': ['pass'],
#  'calculated': ['calculate'],
#  'queries': ['query'],
#  'dual': ['double'],
#  'transporting': ['carry', 'transport'],
#  'plugged': ['plug'],
#  'instantly': ['immediately'],
#  'restoring': ['restore'],
#  'cut': ['cutting'],
#  'naming': ['refer', 'name', 'mention'],
#  'hired': ['hire'],
#  'depending': ['depend'],
#  'watch': ['see'],
#  'resigned': ['resign'],
#  'reversed': ['reverse'],
#  'easiest': ['easy'],
#  'execution': ['implementation'],
#  'thanks': ['thank'],
#  'easily': ['easy'],
#  'assets': ['asset'],
#  'mainly': ['primarily'],
#  'settled': ['settle'],
#  'heat': ['heating'],
#  'restriction': ['limitation'],
#  'investigation': ['investigating'],
#  'wrench': ['pull'],
#  'assumed': ['assume'],
#  'extending': ['extend'],
#  'humanity': ['mankind'],
#  'mankind': ['humanity'],
#  'supposed': ['suppose'],
#  'windows': ['window'],
#  'apologize': ['excuse'],
#  'feeling': ['feel', 'sense'],
#  'aim': ['purpose'],
#  'optic': ['optical'],
#  'milling': ['mill'],
#  'feel': ['feeling'],
#  'mapping': ['map'],
#  'printers': ['printer'],
#  'joining': ['join'],
#  'adoption': ['acceptance'],
#  'triggered': ['trigger'],
#  'hence': ['thus', 'therefore'],
#  'prepare': ['ready', 'make'],
#  'entrance': ['entering'],
#  'examine': ['analyze'],
#  'targeted': ['target'],
#  'outstanding': ['great'],
#  'primarily': ['mainly'],
#  'writing': ['write'],
#  'seated': ['sit'],
#  'specific': ['particular'],
#  'reversal': ['reverse'],
#  'sides': ['side'],
#  'sort': ['kind'],
#  'fell': ['fall'],
#  'usage': ['utilization', 'use'],
#  'communicating': ['communicate'],
#  'worn': ['wear'],
#  'blasting': ['blast'],
#  'holiday': ['vacation'],
#  'gaining': ['gain'],
#  'positioned': ['position'],
#  'drag': ['pull'],
#  'partly': ['partially'],
#  'remedy': ['rectify'],
#  'forcing': ['push', 'force'],
#  'likely': ['probably'],
#  'remains': ['remain'],
#  'sized': ['size'],
#  'lighter': ['light'],
#  'efficient': ['effective'],
#  'listing': ['list'],
#  'chairman': ['president'],
#  'barely': ['hardly', 'just'],
#  'earnings': ['profit'],
#  'relocation': ['move'],
#  'installing': ['install'],
#  'structured': ['structure'],
#  'kicking': ['kick'],
#  'modeling': ['simulate', 'model'],
#  'hearing': ['hear'],
#  'kiosk': ['booth'],
#  'limitation': ['restriction', 'limit'],
#  'excluding': ['exclude', 'except'],
#  'flickering': ['flicker'],
#  'inner': ['internal', 'inside'],
#  'expanding': ['expand'],
#  'te': ['ti'],
#  'deadlock': ['standstill'],
#  'stage': ['present'],
#  'capacity': ['capability'],
#  'knowing': ['know'],
#  'author': ['writer'],
#  'discover': ['find'],
#  'null': ['nil'],
#  'erase': ['delete'],
#  'non': ['not'],
#  'honest': ['good'],
#  'photo': ['picture', 'pic'],
#  'raging': ['storm', 'rage'],
#  'raising': ['raise'],
#  'reading': ['read'],
#  'presently': ['currently'],
#  'lit': ['light'],
#  'visiting': ['visit'],
#  'easier': ['easy'],
#  'snap': ['grab'],
#  'sessions': ['session'],
#  'ending': ['end'],
#  'ti': ['te'],
#  'turning': ['turn'],
#  'cracking': ['break'],
#  'suffering': ['suffer'],
#  'propose': ['suggest'],
#  'incompatibility': ['inconsistency'],
#  'stamping': ['stamp'],
#  'spoken': ['speak'],
#  'rebuilt': ['rebuild'],
#  'tops': ['top'],
#  'specs': ['specification'],
#  'corporation': ['corp'],
#  'publication': ['issue'],
#  'measurement': ['measuring'],
#  'heating': ['heat'],
#  'analyses': ['analysis'],
#  'produce': ['create', 'make'],
#  'led': ['lead'],
#  'detailed': ['detail'],
#  'branded': ['brand'],
#  'lobby': ['hall'],
#  'enhanced': ['enhance']}

# %%
#newdf.to_csv('datasets/spaCy_Augmented_Data.csv')

# %%
with open('datasets/word_embedding_synonyms_knn.json', 'w') as fp:
    json.dump(synonym, fp, sort_keys=True, indent=4)

# %%
with open('datasets/word_embedding_synonyms_pos.json', 'w') as fp:
    json.dump(synonym, fp, sort_keys=True, indent=4)

# %%
df = mydata[['Combined Description Cleaned', 'Assignment group'] ]
df = df[df['Assignment group'] != 'GRP_0']

# %%
df_assignment_group_dist = df['Assignment group'].value_counts().reset_index()
df_assignment_group_dist['percentage'] = (df_assignment_group_dist['Assignment group']/df_assignment_group_dist['Assignment group'].sum())*100
df_assignment_group_dist.head(20)
# Out:
#      index  Assignment group  percentage
# 0    GRP_8               661   14.610964
# 1   GRP_24               289    6.388152
# 2   GRP_12               257    5.680813
# 3    GRP_9               252    5.570292
# 4    GRP_2               241    5.327144
# 5   GRP_19               215    4.752431
# 6    GRP_3               200    4.420866
# 7    GRP_6               184    4.067197
# 8   GRP_13               145    3.205128
# 9   GRP_10               140    3.094607
# 10   GRP_5               129    2.851459
# 11  GRP_14               118    2.608311
# 12  GRP_25               116    2.564103
# 13  GRP_33               107    2.365164
# 14   GRP_4               100    2.210433
# 15  GRP_29                97    2.144120
# 16  GRP_18                88    1.945181
# 17  GRP_16                85    1.878868
# 18  GRP_17                81    1.790451
# 19  GRP_31                69    1.525199

# %%
newdf = pd.DataFrame(columns = ['Combined Description Cleaned', 'Assignment group']) 
newdf
# Out:
# Empty DataFrame
# Columns: [Combined Description Cleaned, Assignment group]
# Index: []

# %%
i = 0

for index, row in df.iterrows(): 
    max_substitutions = 3
    i += 1
    if i > 30000: break
    desc = row['Combined Description Cleaned']
    assignment_grp = row['Assignment group']
    if max_substitutions > len(desc.split()):   # we are dealing with a small string
        if len(desc.split()) > 0:
            max_substitutions = 1
        else:
            max_substitutions = 0
    #print(max_substitutions)
    split_desc = desc.split()
    j=1
    while j <= max_substitutions:
        j+=1
        random_word = random.choice(split_desc)
        #print("Original sentence is %s ",  split_desc)
        #print("Picked word is %s", random_word)
        #print("Available substitutes %s",synonym.get(random_word,[random_word]) )
        substituted_word = random.choice(synonym.get(random_word,[random_word]))

        if random_word != substituted_word:
            new_desc = desc.replace(random_word, substituted_word , 1)
            #print("New sentence is %s ",  new_desc)
            newdf = newdf.append({'Combined Description Cleaned': new_desc, 'Assignment group': assignment_grp},ignore_index=True)


    #print(len(desc))
   
    #print (desc,assignment_grp )

# %% [markdown]
# #### Numbers after augmentation of the minority groups

# %%
df_assignment_group_dist = newdf['Assignment group'].value_counts().reset_index()
df_assignment_group_dist['percentage'] = (df_assignment_group_dist['Assignment group']/df_assignment_group_dist['Assignment group'].sum())*100
df_assignment_group_dist.head(20)
# Out:
#      index  Assignment group  percentage
# 0    GRP_8              1979   14.935849
# 1   GRP_12               767    5.788679
# 2    GRP_9               756    5.705660
# 3    GRP_2               715    5.396226
# 4   GRP_24               655    4.943396
# 5   GRP_19               627    4.732075
# 6    GRP_3               592    4.467925
# 7    GRP_6               552    4.166038
# 8   GRP_13               433    3.267925
# 9   GRP_10               420    3.169811
# 10   GRP_5               387    2.920755
# 11  GRP_14               350    2.641509
# 12  GRP_25               348    2.626415
# 13  GRP_33               309    2.332075
# 14   GRP_4               298    2.249057
# 15  GRP_29               291    2.196226
# 16  GRP_18               262    1.977358
# 17  GRP_16               255    1.924528
# 18  GRP_17               243    1.833962
# 19   GRP_7               204    1.539623

# %%
# We have now increased the numbers for the minority groups

# %%
df = mydata[['Combined Description Cleaned', 'Assignment group'] ]
augmented_df = df.append(newdf).drop_duplicates()

# %%
df_assignment_group_dist = augmented_df['Assignment group'].value_counts().reset_index()
df_assignment_group_dist['percentage'] = (df_assignment_group_dist['Assignment group']/df_assignment_group_dist['Assignment group'].sum())*100
df_assignment_group_dist.head(20)
# Out:
#      index  Assignment group  percentage
# 0    GRP_0              3004   17.086628
# 1    GRP_8              1442    8.202036
# 2   GRP_12               980    5.574199
# 3    GRP_2               932    5.301177
# 4   GRP_19               823    4.681190
# 5   GRP_24               779    4.430920
# 6    GRP_3               772    4.391104
# 7   GRP_13               563    3.202321
# 8   GRP_14               461    2.622149
# 9    GRP_6               458    2.605085
# 10  GRP_25               457    2.599397
# 11  GRP_33               410    2.332063
# 12  GRP_10               385    2.189864
# 13  GRP_29               385    2.189864
# 14   GRP_9               382    2.172800
# 15   GRP_4               379    2.155736
# 16  GRP_18               344    1.956658
# 17  GRP_16               336    1.911154
# 18   GRP_5               265    1.507309
# 19   GRP_7               263    1.495933

# %%
# Plot to visualize the percentage data distribution across different groups
sns.set(style="whitegrid")
plt.figure(figsize=(20,5))
order = augmented_df["Assignment group"].value_counts().index

ax = sns.countplot(x="Assignment group", data=augmented_df, order=order, linewidth=2,
                  edgecolor = "k"*len(order), palette='Set1')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
for p in ax.patches:
  ax.annotate(str(format(p.get_height()/len(augmented_df.index)*100, '.2f')+"%"), 
              (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 'bottom',
              rotation=90, xytext = (0, 10), textcoords = 'offset points')
# Out:
# c:\programdata\anaconda3\envs\tfnightly_py38\lib\site-packages\seaborn\categorical.py:1604: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated since 3.2 and will be removed two minor releases later. Use an explicit list instead.
#   barfunc(barpos, self.statistic, self.width,

# %% [markdown]
# ### Observation
# - After round 1 we see increased numbers for the minority groups.

# %%
df2 = augmented_df
le = preprocessing.LabelEncoder()
df2["LabelEncodings"] = le.fit_transform(augmented_df["Assignment group"])
y_classes_len = len(le.classes_)
le.classes_
print(y_classes_len)
# Out:
# 74

# %%
y = np.asarray(df2['LabelEncodings'])

# %%
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(augmented_df['Combined Description Cleaned'])
print(X_train_counts.shape)
# Out:
# (17581, 4025)

# %%
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
print(X_train_tfidf.shape)
# Out:
# (17581, 4025)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_train_tfidf, y, test_size=test_size)

# %%
print(len(count_vect.vocabulary_))
# Out:
# 4025

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (12306, 4025)
# (12306,)

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (5275, 4025)
# (5275,)

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(solver='lbfgs', max_iter=1000, multi_class='multinomial').fit(X_train, y_train)
y_pred = clf.predict(X_test)

# %%
acc_score = accuracy_score(y_test, y_pred)
print("Logistic Regression Score: ", acc_score)
f1_score = metrics.f1_score(y_test, y_pred, average='weighted', labels=np.unique(y_pred))
print("Logistic Regression F1 Score: ", f1_score)
precision_score = metrics.precision_score(y_test, y_pred, average='weighted', labels=np.unique(y_pred))
recall_score = metrics.recall_score(y_test, y_pred, average='weighted', labels=np.unique(y_pred))
print('f1 score: {:.2%}'.format(f1_score))
print('Precison Score : {:.2%}'.format(precision_score))
print('Recall score: {:.2%}'.format(recall_score))
#dfObj = pd.DataFrame(columns=['Algorithm', 'Accuracy', 'f1', 'Precision Score', 'Recall Score'])
accuracy = accuracy_score(y_test, y_pred)
dfObj = dfObj.append({'Algorithm' : 'LR   {:.0%}'.format(test_size) + ' Test Data after Data Augmentation Word Embedding Round 1' ,
                      'Accuracy': '{:.2%}'.format(accuracy),
                      'f1':'{:.2%}'.format(f1_score),
                      'Precision Score': '{:.2%}'.format(precision_score),
                      'Recall Score': '{:.2%}'.format(recall_score) 
                     } , ignore_index=True)

sort_by=['Accuracy', 'f1']
dfObj = sort_df(dfObj,sort_by)
dfObj
# Out:
# Logistic Regression Score:  0.6401895734597156
# Logistic Regression F1 Score:  0.632606922543797
# f1 score: 63.26%
# Precison Score : 70.10%
# Recall score: 65.48%
#                                                            Algorithm Accuracy  \
# 1  LR   30% Test Data after Data Augmentation Word Embedding Round 1   64.02%
# 2                             LR   30% Raw Test Data after Cleansing   62.12%
#
#        f1 Precision Score Recall Score
# 1  63.26%          70.10%       65.48%
# 2  56.91%          61.34%       67.72%

# %% [markdown]
# ### We are running some ML models on this dataset just to be sure the data augmentation is helping

# %% [markdown]
# # Train a Support vector machine using the train set and get the accuracy on the test set
#
# ###### (Rubric) Use Gridsearch to find appropriate hyperparameters
# ###### (Rubric) Train model using the train data with hyper parameters obtained
# ###### (Rubric) Get accuracy and also view confusion matrix
# ###### (Rubric) Inferences based on accuracy/confusion matrix and other evaluation metrics of classification problem
# ###### (Rubric) Inferences based on the results
# ### Some Parameters we are trying the find the ideal values for:
# - C is used during the training phase and says how much outliers are taken into account in calculating Support Vectors
# - gamma  determines the radius of the area of influence of the support vectors if it is too large, the radius of the area of influence of the support vectors only includes the support vector itself and no amount of regularization with C will be able to prevent overfitting. When gamma is very small, the model is too constrained and cannot capture the complexity or “shape” of the data.
# - kernel parameter selects the type of hyperplane used to separate the data.
# -- We will let the Hypersearch determine the best kernel to use amoung
# -- rbf : The RBF kernel is a stationary kernel. It is also known as the “squared exponential” kernel.
# -- poly : A polynomial kernel is a more generalized form of the linear kernel. The polynomial kernel can distinguish curved or nonlinear input space. The polynomial and RBF are especially useful when the data-points are not linearly separable.
# -- sigmoid: The Sigmoid Kernel comes from the Neural Networks field, where the bipolar sigmoid function is often used as an activation function for artificial neurons
# - probabiity: We will choose between True & False

# %%
#param_grid = {'C': [0.1,1, 10, 100], 'gamma': [1,0.1,0.01,0.001],'kernel': ['rbf', 'poly', 'sigmoid'],
#              'random_state': [1], 'probability': [True,False]}
#grid = GridSearchCV(SVC(),param_grid,refit=True,n_jobs=16,verbose=1)
#grid.fit(X_train,y_train)
#print(f'The best estimator is: \n {grid.best_estimator_}\n\n')
#grid_predictions = grid.predict(X_test)
#Fitting 5 folds for each of 96 candidates, totalling 480 fits
#C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:670: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#  warnings.warn(("The least populated class in y has only %d"
#[Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
#[Parallel(n_jobs=16)]: Done  18 tasks      | elapsed:   47.1s
#[Parallel(n_jobs=16)]: Done 168 tasks      | elapsed:  3.2min
#[Parallel(n_jobs=16)]: Done 418 tasks      | elapsed:  9.4min
#[Parallel(n_jobs=16)]: Done 480 out of 480 | elapsed: 10.3min finished
#The best estimator is: 
# SVC(C=100, gamma=0.01, probability=True, random_state=1)

# %%
svc = SVC(C=100, gamma=0.1, probability=False, random_state=1)
clf = svc.fit(X_train,y_train)
y_pred = clf.predict(X_test)

# %%
f1_score_svc = metrics.f1_score(y_test, y_pred, average='weighted', labels=np.unique(y_pred))
precision_score_svc = metrics.precision_score(y_test, y_pred, average="macro")
recall_score_svc = metrics.recall_score(y_test, y_pred, average="macro")
print('f1 score: {:.2%}'.format(f1_score_svc))
print('Precison Score : {:.2%}'.format(precision_score_svc))
print('Recall score: {:.2%}'.format(recall_score_svc))
#dfObj = pd.DataFrame(columns=['Algorithm', 'Accuracy', 'f1', 'Precision Score', 'Recall Score'])
accuracy = metrics.accuracy_score(y_test, y_pred)
dfObj = dfObj.append({'Algorithm' : 'SVC   {:.0%}'.format(test_size) + ' Test Data after Data Augmentation Word Embedding Round 1' ,
                      'Accuracy': '{:.2%}'.format(accuracy),
                      'f1':'{:.2%}'.format(f1_score_svc),
                      'Precision Score': '{:.2%}'.format(precision_score_svc),
                      'Recall Score': '{:.2%}'.format(recall_score_svc) 
                     } , ignore_index=True)

sort_by=['Accuracy', 'f1']
dfObj = sort_df(dfObj,sort_by)
dfObj
# Out:
# f1 score: 86.38%
# Precison Score : 88.67%
# Recall score: 85.84%
# c:\programdata\anaconda3\envs\tfnightly_py38\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                                                             Algorithm  \
# 1  SVC   30% Test Data after Data Augmentation Word Embedding Round 1
# 2   LR   30% Test Data after Data Augmentation Word Embedding Round 1
# 3                              LR   30% Raw Test Data after Cleansing
#
#   Accuracy      f1 Precision Score Recall Score
# 1   86.26%  86.38%          88.67%       85.84%
# 2   64.02%  63.26%          70.10%       65.48%
# 3   62.12%  56.91%          61.34%       67.72%

# %% [markdown]
# ### We will now persist the dataset for ML models to use
# - We will still proceed with one more round of augmentation

# %%
augmented_df.to_csv('datasets/input_data_after_data_for_ml__with_augmentation_knn_round1.csv')

# %%
df = augmented_df[['Combined Description Cleaned', 'Assignment group']]
df = df[df['Assignment group'] != 'GRP_0']

# %%
df_assignment_group_dist = df['Assignment group'].value_counts().reset_index()
df_assignment_group_dist['percentage'] = (df_assignment_group_dist['Assignment group']/df_assignment_group_dist['Assignment group'].sum())*100
df_assignment_group_dist.head(20)
# Out:
#      index  Assignment group  percentage
# 0    GRP_8              1442    9.892296
# 1   GRP_12               980    6.722920
# 2    GRP_2               932    6.393634
# 3   GRP_19               823    5.645880
# 4   GRP_24               779    5.344035
# 5    GRP_3               772    5.296014
# 6   GRP_13               563    3.862249
# 7   GRP_14               461    3.162516
# 8    GRP_6               458    3.141936
# 9   GRP_25               457    3.135076
# 10  GRP_33               410    2.812650
# 11  GRP_29               385    2.641147
# 12  GRP_10               385    2.641147
# 13   GRP_9               382    2.620567
# 14   GRP_4               379    2.599986
# 15  GRP_18               344    2.359882
# 16  GRP_16               336    2.305001
# 17   GRP_5               265    1.817932
# 18   GRP_7               263    1.804212
# 19  GRP_31               260    1.783632

# %%
newdf = pd.DataFrame(columns = ['Combined Description Cleaned', 'Assignment group']) 
newdf
# Out:
# Empty DataFrame
# Columns: [Combined Description Cleaned, Assignment group]
# Index: []

# %%
i = 0

for index, row in df.iterrows(): 
    max_substitutions = 3
    i += 1
    if i > 5000: break
    desc = row['Combined Description Cleaned']
    assignment_grp = row['Assignment group']
    if max_substitutions > len(desc.split()):   # we are dealing with a small string
        if len(desc.split()) > 0:
            max_substitutions = 1
        else:
            max_substitutions = 0
    #print(max_substitutions)
    split_desc = desc.split()
    j=1
    while j <= max_substitutions:
        j+=1
        random_word = random.choice(split_desc)
        #print("Original sentence is %s ",  split_desc)
        #print("Picked word is %s", random_word)
        #print("Available substitutes %s",synonym.get(random_word,[random_word]) )
        substituted_word = random.choice(synonym.get(random_word,[random_word]))

        if random_word != substituted_word:
            new_desc = desc.replace(random_word, substituted_word , 1)
            #print("New sentence is %s ",  new_desc)
            newdf = newdf.append({'Combined Description Cleaned': new_desc, 'Assignment group': assignment_grp},ignore_index=True)


    #print(len(desc))
   
    #print (desc,assignment_grp )

# %%
df_assignment_group_dist = newdf['Assignment group'].value_counts().reset_index()
df_assignment_group_dist['percentage'] = (df_assignment_group_dist['Assignment group']/df_assignment_group_dist['Assignment group'].sum())*100
df_assignment_group_dist.head(20)
# Out:
#      index  Assignment group  percentage
# 0    GRP_8              1490   10.084602
# 1    GRP_2              1063    7.194585
# 2   GRP_12              1003    6.788494
# 3    GRP_3               842    5.698816
# 4   GRP_19               799    5.407783
# 5   GRP_24               785    5.313029
# 6   GRP_13               589    3.986464
# 7   GRP_25               536    3.627750
# 8   GRP_33               494    3.343486
# 9   GRP_14               447    3.025381
# 10   GRP_9               414    2.802030
# 11   GRP_6               400    2.707276
# 12  GRP_16               387    2.619289
# 13   GRP_4               376    2.544839
# 14  GRP_29               372    2.517766
# 15  GRP_18               342    2.314721
# 16   GRP_5               339    2.294416
# 17  GRP_10               318    2.152284
# 18  GRP_34               265    1.793570
# 19   GRP_7               255    1.725888

# %%
df = augmented_df[['Combined Description Cleaned', 'Assignment group'] ]
augmented_df = df.append(newdf).drop_duplicates()

# %%
augmented_df
# Out:
#                                                           Combined Description Cleaned  \
# 0      login issue user manager name checked the name in ad and reset password advi...
# 1      outlook received from hello team my are not in calendar can somebody please ...
# 2                                   cannot log in to received from hi i cannot on best
# 3                                                           unable to access tool page
# 4                                                                                error
# ...                                                                                ...
# 14770  create corporate partner id received this hello team can you please a for in...
# 14771  create corporate partner id received from hello team need you please a for i...
# 14772                              job eu tool top place job schedule at received from
# 14773                                  job eu use top in job schedule at received from
# 14774                                work eu tool top in job schedule at received from
#
#       Assignment group
# 0                GRP_0
# 1                GRP_0
# 2                GRP_0
# 3                GRP_0
# 4                GRP_0
# ...                ...
# 14770            GRP_2
# 14771            GRP_2
# 14772            GRP_8
# 14773            GRP_8
# 14774            GRP_8
#
# [31133 rows x 2 columns]

# %%
df_assignment_group_dist = augmented_df['Assignment group'].value_counts().reset_index()
df_assignment_group_dist['percentage'] = (df_assignment_group_dist['Assignment group']/df_assignment_group_dist['Assignment group'].sum())*100
df_assignment_group_dist.head(20)
# Out:
#      index  Assignment group  percentage
# 0    GRP_0              3004    9.648926
# 1    GRP_8              2794    8.974400
# 2    GRP_2              1916    6.154241
# 3   GRP_12              1895    6.086789
# 4   GRP_19              1553    4.988276
# 5    GRP_3              1545    4.962580
# 6   GRP_24              1438    4.618893
# 7   GRP_13              1120    3.597469
# 8   GRP_25               970    3.115665
# 9   GRP_33               870    2.794462
# 10  GRP_14               866    2.781614
# 11   GRP_6               813    2.611377
# 12   GRP_9               762    2.447564
# 13  GRP_29               737    2.367263
# 14   GRP_4               724    2.325507
# 15  GRP_16               711    2.283750
# 16  GRP_18               675    2.168117
# 17  GRP_10               674    2.164905
# 18   GRP_5               567    1.821219
# 19   GRP_7               502    1.612437

# %%
# Plot to visualize the percentage data distribution across different groups
sns.set(style="whitegrid")
plt.figure(figsize=(20,5))
order = augmented_df["Assignment group"].value_counts().index

ax = sns.countplot(x="Assignment group", data=augmented_df, order=order, linewidth=2,
                  edgecolor = "k"*len(order), palette='Set1')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
for p in ax.patches:
  ax.annotate(str(format(p.get_height()/len(augmented_df.index)*100, '.2f')+"%"), 
              (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 'bottom',
              rotation=90, xytext = (0, 10), textcoords = 'offset points')
# Out:
# c:\programdata\anaconda3\envs\tfnightly_py38\lib\site-packages\seaborn\categorical.py:1604: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated since 3.2 and will be removed two minor releases later. Use an explicit list instead.
#   barfunc(barpos, self.statistic, self.width,

# %% [markdown]
# # The numbers look good after round 2

# %%
df2 = augmented_df
le = preprocessing.LabelEncoder()
df2["LabelEncodings"] = le.fit_transform(augmented_df["Assignment group"])
y_classes_len = len(le.classes_)
le.classes_
print(y_classes_len)
# Out:
# 74

# %%
y = np.asarray(df2['LabelEncodings'])

# %%
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(augmented_df['Combined Description Cleaned'])
print(X_train_counts.shape)
# Out:
# (31133, 4483)

# %%
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
print(X_train_tfidf.shape)
# Out:
# (31133, 4483)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_train_tfidf, y, test_size=0.3)

# %%
print(len(count_vect.vocabulary_))
# Out:
# 4483

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (21793, 4483)
# (21793,)

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (9340, 4483)
# (9340,)

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(solver='lbfgs', max_iter=1000, multi_class='multinomial').fit(X_train, y_train)
y_pred = clf.predict(X_test)

# %%
acc_score = accuracy_score(y_test, y_pred)
print("Logistic Regression Score: ", acc_score)
f1_score = metrics.f1_score(y_test, y_pred, average='weighted', labels=np.unique(y_pred))
print("Logistic Regression F1 Score: ", f1_score)
precision_score = metrics.precision_score(y_test, y_pred, average='weighted', labels=np.unique(y_pred))
recall_score = metrics.recall_score(y_test, y_pred, average='weighted', labels=np.unique(y_pred))
print('f1 score: {:.2%}'.format(f1_score))
print('Precison Score : {:.2%}'.format(precision_score))
print('Recall score: {:.2%}'.format(recall_score))
#dfObj = pd.DataFrame(columns=['Algorithm', 'Accuracy', 'f1', 'Precision Score', 'Recall Score'])
accuracy = accuracy_score(y_test, y_pred)
dfObj = dfObj.append({'Algorithm' : 'LR   {:.0%}'.format(test_size) + ' Test Data after Data Augmentation Word Embedding Round 2' ,
                      'Accuracy': '{:.2%}'.format(accuracy),
                      'f1':'{:.2%}'.format(f1_score),
                      'Precision Score': '{:.2%}'.format(precision_score),
                      'Recall Score': '{:.2%}'.format(recall_score) 
                     } , ignore_index=True)

sort_by=['Accuracy', 'f1']
dfObj = sort_df(dfObj,sort_by)
dfObj
# Out:
# Logistic Regression Score:  0.7658458244111349
# Logistic Regression F1 Score:  0.7632095101001816
# f1 score: 76.32%
# Precison Score : 78.94%
# Recall score: 77.05%
#                                                             Algorithm  \
# 1  SVC   30% Test Data after Data Augmentation Word Embedding Round 1
# 2   LR   30% Test Data after Data Augmentation Word Embedding Round 2
# 3   LR   30% Test Data after Data Augmentation Word Embedding Round 1
# 4                              LR   30% Raw Test Data after Cleansing
#
#   Accuracy      f1 Precision Score Recall Score
# 1   86.26%  86.38%          88.67%       85.84%
# 2   76.58%  76.32%          78.94%       77.05%
# 3   64.02%  63.26%          70.10%       65.48%
# 4   62.12%  56.91%          61.34%       67.72%

# %%
svc = SVC(C=10, gamma=1, probability=False, random_state=1)
clf = svc.fit(X_train,y_train)
y_pred = clf.predict(X_test)

# %%
f1_score_svc = metrics.f1_score(y_test, y_pred, average='weighted', labels=np.unique(y_pred))
precision_score_svc = metrics.precision_score(y_test, y_pred, average="macro")
recall_score_svc = metrics.recall_score(y_test, y_pred, average="macro")
print('f1 score: {:.2%}'.format(f1_score_svc))
print('Precison Score : {:.2%}'.format(precision_score_svc))
print('Recall score: {:.2%}'.format(recall_score_svc))
#dfObj = pd.DataFrame(columns=['Algorithm', 'Accuracy', 'f1', 'Precision Score', 'Recall Score'])
accuracy = metrics.accuracy_score(y_test, y_pred)
dfObj = dfObj.append({'Algorithm' : 'SVC   {:.0%}'.format(test_size) + ' Test Data after Data Augmentation Word Embedding Round 2' ,
                      'Accuracy': '{:.2%}'.format(accuracy),
                      'f1':'{:.2%}'.format(f1_score_svc),
                      'Precision Score': '{:.2%}'.format(precision_score_svc),
                      'Recall Score': '{:.2%}'.format(recall_score_svc) 
                     } , ignore_index=True)

sort_by=['Accuracy', 'f1']
dfObj = sort_df(dfObj,sort_by)
dfObj
# Out:
# f1 score: 91.42%
# Precison Score : 94.13%
# Recall score: 89.94%
# c:\programdata\anaconda3\envs\tfnightly_py38\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                                                             Algorithm  \
# 1  SVC   30% Test Data after Data Augmentation Word Embedding Round 2
# 2  SVC   30% Test Data after Data Augmentation Word Embedding Round 1
# 3   LR   30% Test Data after Data Augmentation Word Embedding Round 2
# 4   LR   30% Test Data after Data Augmentation Word Embedding Round 1
# 5                              LR   30% Raw Test Data after Cleansing
#
#   Accuracy      f1 Precision Score Recall Score
# 1   91.41%  91.42%          94.13%       89.94%
# 2   86.26%  86.38%          88.67%       85.84%
# 3   76.58%  76.32%          78.94%       77.05%
# 4   64.02%  63.26%          70.10%       65.48%
# 5   62.12%  56.91%          61.34%       67.72%

# %% [markdown]
# ### We will now save the dataset for ML Models to use

# %%
augmented_df.to_csv('datasets/input_data_after_data_for_ml__with_augmentation_knn_round2.csv')
